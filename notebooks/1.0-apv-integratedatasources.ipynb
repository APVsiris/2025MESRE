# %% [markdown]
# # Integrate different data sources

# %%
import requests
import json
from urllib.parse import urlencode
import pandas as pd
import orjson
from tqdm import tqdm
import ast
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### BSO

# %%
df_oa = []
for year in tqdm(range(2013, 2025)):
    df_oa_tmp = pd.read_csv(f'../data/interim/oa_initial_{year}.csv').drop(columns = 'Unnamed: 0')
    df_oa.append(df_oa_tmp)
df_oa = pd.concat((df_oa), ignore_index = True)
df_oa

# %%
df = pd.read_csv('../data/interim/bso.csv').drop(columns='Unnamed: 0')

df_oa['doi_corr'] = df_oa['doi'].apply(lambda x: x[16:])
df_oa_comb = df_oa.merge(df, left_on='doi_corr', right_on='doi', how='left')
df_oa_comb['BSO'] = df_oa_comb['openalex_id'].notna()
df_oa_comb = (df_oa_comb.drop(columns=['doi_y', 'bso_country_corrected', 'genre', 'openalex_id']).rename(columns={'doi_x': 'doi'}))

df_oa_comb
# Out:
#                                                   doi  publication_year  \
# 0          https://doi.org/10.1016/j.cell.2013.05.039              2013
# 1         https://doi.org/10.1051/0004-6361/201322068              2013
# 2          https://doi.org/10.2458/azu_js_rc.55.16947              2013
# 3                 https://doi.org/10.1038/nature12477              2013
# 4        https://doi.org/10.1097/ccm.0b013e31827e83af              2013
# ...                                               ...               ...
# 1545077    https://doi.org/10.1007/s10499-025-02358-1              2024
# 1545078         https://doi.org/10.37665/remcajp40761              2024
# 1545079                 https://doi.org/10.4000/15ara              2024
# 1545080                 https://doi.org/10.4000/11ndt              2024
# 1545081                  https://doi.org/10.2427/5975              2024
#
#         language                          field_name_top_topic  \
# 0             en  Biochemistry, Genetics and Molecular Biology
# 1             en                         Physics and Astronomy
# 2             en                  Earth and Planetary Sciences
# 3             en  Biochemistry, Genetics and Molecular Biology
# 4             en                                      Medicine
# ...          ...                                           ...
# 1545077       en          Agricultural and Biological Sciences
# 1545078      NaN                                   Engineering
# 1545079      NaN                               Social Sciences
# 1545080       fr                               Social Sciences
# 1545081       en           Economics, Econometrics and Finance
#
#                                                 journal   journal_id  \
# 0                                                  Cell   S110447773
# 1                            Astronomy and Astrophysics   S205231332
# 2                                           Radiocarbon    S35778795
# 3                                                Nature   S137773608
# 4                                                   NaN           {}
# ...                                                 ...          ...
# 1545077                                             NaN           {}
# 1545078                                             NaN           {}
# 1545079  Revue européenne de migrations internationales  S4210238526
# 1545080                              Histoire Politique  S4210214659
# 1545081                Italian Journal of Public Health  S2737641039
#
#             issn_l                   publisher publisher_id  \
# 0        0092-8674                  Cell Press  P4310315673
# 1        0004-6361                EDP Sciences  P4310319748
# 2        0033-8222  Cambridge University Press  P4310311721
# 3        0028-0836            Nature Portfolio  P4310319908
# 4              NaN                         NaN           {}
# ...            ...                         ...          ...
# 1545077        NaN                         NaN           {}
# 1545078        NaN                         NaN           {}
# 1545079  0765-0752      University of Poitiers  P4310311531
# 1545080  1954-3670                         NaN           {}
# 1545081  1723-7807                    Prex spa  P4310317659
#
#                                   display_name_institution  \
# 0        {'MRC Unit for Lifelong Health and Ageing', 'C...
# 1        {'European Southern Observatory', 'Louisiana S...
# 2        {'Irvine University', 'University of Hohenheim...
# 3        {'Christian-Albrechts-Universität zu Kiel', "R...
# 4        {'Denver Health Medical Center', "St Thomas' H...
# ...                                                    ...
# 1545077  {'University of Hong Kong', 'Vietnam Academy o...
# 1545078                                 {'Valeo (France)'}
# 1545079  {'Hill College', 'Loughborough University', 'É...
# 1545080               {'Centre d’histoire de Sciences Po'}
# 1545081  {'Organisation de Coopération et de Développem...
#
#                                             id_institution  \
# 0        {'I4210139815', 'I4210109141', 'I165339363', '...
# 1        {'I57206974', 'I188538660', 'I78577930', 'I451...
# 2        {'I1338293689', 'I31746571', 'I138006243', 'I9...
# 3        {'I4210111138', 'I2802476451', 'I4210133112', ...
# 4        {'I4210087865', 'I2801983979', 'I98251732', 'I...
# ...                                                    ...
# 1545077  {'I161346416', 'I154202486', 'I8991828', 'I421...
# 1545078                                     {'I220619192'}
# 1545079         {'I90669466', 'I2802994108', 'I143804889'}
# 1545080                                    {'I4210100301'}
# 1545081                                    {'I1288051870'}
#
#                                        display_name_author  \
# 0        {'Marı́a A. Blasco', 'Linda Partridge', 'Guido...
# 1        {'Steven M. Crawford', 'V. Zabalza', 'K. Azale...
# 2        {'Bronk Ramsey, Christopher', 'Heaton Timothy ...
# 3        {'Marcel Kool', 'Marit M. van Buuren', 'Peter ...
# 4        {'Djillali Annane', 'Charles L. Sprung', 'Fláv...
# ...                                                    ...
# 1545077  {'Hoang Huy Nguyen', 'Kim Hyun Woo', 'Angkasa ...
# 1545078                                   {'Maurice Dore'}
# 1545079         {'Audrey Lenoël', 'Christina Oelgemöller'}
# 1545080                                  {'Cédric Pellen'}
# 1545081                                       {'E Kelley'}
#
#                                                  id_author oa_status  \
# 0        {'A5087974982', 'A5075296559', 'A5085977927', ...    bronze
# 1        {'A5114376504', 'A5083524651', 'A5009129182', ...    bronze
# 2        {'A3135758542', 'A1987802516', 'A3096006163', ...    bronze
# 3        {'A5072873709', 'A5089677089', 'A5026738636', ...    bronze
# 4        {'A5007271096', 'A5110810503', 'A5003379719', ...    closed
# ...                                                    ...       ...
# 1545077  {'A5114100797', 'A2135394850', 'A2980939411', ...    closed
# 1545078                                    {'A5120490549'}    closed
# 1545079                      {'A292793731', 'A2540735368'}   diamond
# 1545080                                    {'A5079110810'}    bronze
# 1545081                                    {'A5113469121'}    hybrid
#
#                                                   apc_list apc_paid  \
# 0        {'value': 10100, 'currency': 'USD', 'value_usd...      NaN
# 1                                                      NaN      NaN
# 2                                                      NaN      NaN
# 3        {'value': 9750, 'currency': 'EUR', 'value_usd'...      NaN
# 4                                                      NaN      NaN
# ...                                                    ...      ...
# 1545077  {'value': 2790, 'currency': 'EUR', 'value_usd'...      NaN
# 1545078                                                NaN      NaN
# 1545079                                                NaN      NaN
# 1545080                                                NaN      NaN
# 1545081                                                NaN      NaN
#
#                                              corresponding  \
# 0                       [False, False, False, True, False]
# 1        [False, False, False, False, False, False, Fal...
# 2        [True, False, False, False, False, False, Fals...
# 3        [False, False, False, False, False, False, Fal...
# 4        [False, False, False, False, False, False, Fal...
# ...                                                    ...
# 1545077  [True, False, False, False, False, False, Fals...
# 1545078                                             [True]
# 1545079                        [True, False, False, False]
# 1545080                                             [True]
# 1545081                                             [True]
#
#                                                  countries  \
# 0           [['ES'], ['ES'], ['DE', 'GB'], ['ES'], ['FR']]
# 1        [['DE'], ['US'], ['FR', 'US'], ['FR', 'US'], [...
# 2        [['GB'], ['FR'], ['GB'], ['US'], ['GB'], ['GB'...
# 3        [['GB'], ['GB'], ['GB'], ['CA'], ['GB'], ['GB'...
# 4        [['US'], ['US'], ['GB'], ['FR'], ['DE'], ['US'...
# ...                                                    ...
# 1545077  [['VN'], ['HK'], ['VN'], ['CN'], ['TH'], ['VN'...
# 1545078                                           [['FR']]
# 1545079                     [['FR'], ['GB', 'US'], [], []]
# 1545080                                           [['FR']]
# 1545081                                           [['FR']]
#
#                              doi_corr    BSO
# 0          10.1016/j.cell.2013.05.039   True
# 1         10.1051/0004-6361/201322068   True
# 2          10.2458/azu_js_rc.55.16947   True
# 3                 10.1038/nature12477   True
# 4        10.1097/ccm.0b013e31827e83af  False
# ...                               ...    ...
# 1545077    10.1007/s10499-025-02358-1  False
# 1545078         10.37665/remcajp40761  False
# 1545079                 10.4000/15ara  False
# 1545080                 10.4000/11ndt  False
# 1545081                  10.2427/5975  False
#
# [1545082 rows x 20 columns]

# %% [markdown]
# ### Download missing

# %%
df_bso_oa = df[~df.openalex_id.isna()]
missing = df_bso_oa[~df_bso_oa.doi.isin(df_oa_comb.doi_corr)].doi.unique()

BASE_URL = "https://api.openalex.org/works"

selected_fields = ["doi", "publication_year", "language", "indexed_in", "primary_location", "best_oa_location", "open_access", "authorships", 
                   "corresponding_author_ids", "corresponding_institution_ids", "apc_list", "apc_paid", "cited_by_count", "primary_topic", "awards", "funders"]


def fetch_by_ids(id_list):
    # Normalize IDs to a string separated by |
    doi_filter = "doi:" + "|".join(id_list)

    filters = [
        doi_filter,
        "indexed_in:crossref",
        "type:article|review",
    ]

    params = {
        "filter": ",".join(filters),
        "select": ",".join(selected_fields),
        "per_page": 200
    }

    url = f"{BASE_URL}?{urlencode(params)}"
    try:
        r = requests.get(url, timeout=30)
        r.raise_for_status()
        data = r.json()
        return data.get("results", [])
    except requests.exceptions.JSONDecodeError:
        print("JSON decode error for URL:", url[:200])
        pass
    except requests.exceptions.RequestException as e:
        print("Request error:", e)
        pass

batch_size = 50  # try increasing, test carefully
all_fetched = []
for i in tqdm(range(0, len(missing), batch_size)):
    batch = missing[i:i+batch_size]
    results = fetch_by_ids(batch)
    all_fetched.extend(results)

    
output_file = "../data/interim/FranceInitialAPI/openalex_missing.jsonl"
with open(output_file, "w", encoding="utf-8") as f:
    for w in all_fetched:
        f.write(json.dumps(w) + "\n")

print(f"Saved {len(all_fetched)} records to {output_file}")

# %%
interest = ['doi', 'publication_year', 'language', 'authorships', 'best_oa_location', 'primary_topic', 'open_access', 'apc_list', 'apc_paid']
keys = ['doi', 'publication_year', 'language', 'field_name_top_topic', 'journal', 'journal_id','publisher', 'publisher_id', 'display_name_institution', 'id_institution', 'display_name_author', 'id_author',
        'oa_status', 'apc_list', 'apc_paid','corresponding', 'countries']

records = []
with open(f"../data/interim/FranceInitialAPI/openalex_missing.jsonl", "rb") as f:
    for line in f:
        rec = orjson.loads(line)
        if not rec.get("doi"): # Skip records without DOI
            continue
        filtered = {k: rec.get(k) for k in interest} # Keep only the fields we care about

        # Extract field_names from topics
        filtered["field_name_top_topic"] =  filtered.get("primary_topic") .get("field", {}).get("display_name") if isinstance(filtered.get("primary_topic") , dict) else {}

        # Extract journal and publisher from best_oa_location
        pl = filtered.get("best_oa_location") or {}
        source = pl.get("source") or {}
        filtered["journal"] = source.get("display_name")
        filtered["journal_id"] = source.get("id").split("/")[-1] if source.get("id") else {}
        filtered["publisher"] = source.get("host_organization_name")
        filtered["publisher_id"] = source.get("host_organization").split("/")[-1] if source.get("host_organization") else {}

        # Extract institution types and number of authors
        authorships = filtered.get("authorships") or []
        filtered["display_name_institution"] = {inst.get("display_name") for auth in authorships for inst in auth.get("institutions", []) if inst.get("display_name")}
        filtered["id_institution"] = {inst.get("id").split('/')[-1] for auth in authorships for inst in auth.get("institutions", []) if inst.get("id")}
        filtered["corresponding"] = [auth.get("is_corresponding") for auth in authorships]
        filtered["countries"] = [auth.get("countries") for auth in authorships]
        filtered["display_name_author"] = {auth["author"].get("display_name") for auth in authorships if auth.get("author", {}).get("display_name")}
        filtered["id_author"] = {auth["author"].get("id").split('/')[-1] for auth in authorships if auth.get("author", {}).get("id")}
            
        o_a = filtered.get("open_access") or {}
        filtered["oa_status"] = o_a.get("oa_status")

        records.append({k: filtered.get(k) for k in keys})

df_oa_missing = pd.DataFrame(records)
df_oa_missing
# Out:
#                                                doi  publication_year language  \
# 0        https://doi.org/10.1088/0004-637x/772/1/7              2013       en
# 1      https://doi.org/10.1016/j.datak.2013.06.002              2013       en
# 2      https://doi.org/10.1209/0295-5075/101/30006              2013       en
# 3             https://doi.org/10.3917/rtm.213.0071              2013       fr
# 4        https://doi.org/10.4000/africanistes.3563              2013       fr
# ...                                            ...               ...      ...
# 11632   https://doi.org/10.1109/tcpmt.2024.3370951              2024       en
# 11633  https://doi.org/10.1016/j.ymssp.2024.111486              2024       en
# 11634  https://doi.org/10.1016/j.finel.2024.104163              2024       en
# 11635   https://doi.org/10.54563/cahiers-duras.519              2024       fr
# 11636   https://doi.org/10.1038/s41467-024-51439-x              2024       en
#
#         field_name_top_topic  \
# 0      Physics and Astronomy
# 1           Computer Science
# 2      Physics and Astronomy
# 3            Social Sciences
# 4        Arts and Humanities
# ...                      ...
# 11632            Engineering
# 11633            Engineering
# 11634            Engineering
# 11635             Psychology
# 11636      Materials Science
#
#                                                  journal   journal_id  \
# 0                              The Astrophysical Journal     S1980519
# 1      HAL (Le Centre pour la Communication Scientifi...  S4306402512
# 2                             arXiv (Cornell University)  S4306400194
# 3                                            Tiers-Monde    S91700283
# 4                                                   None           {}
# ...                                                  ...          ...
# 11632                                               None           {}
# 11633           Mechanical Systems and Signal Processing   S128368299
# 11634                                               None           {}
# 11635  HAL (Le Centre pour la Communication Scientifi...  S4306402512
# 11636                              Nature Communications    S64187185
#
#                                           publisher publisher_id  \
# 0                                    IOP Publishing  P4310320083
# 1      Centre National de la Recherche Scientifique  I1294671590
# 2                                Cornell University   I205783295
# 3                       Publications de la Sorbonne  P4322697890
# 4                                              None           {}
# ...                                             ...          ...
# 11632                                          None           {}
# 11633                                   Elsevier BV  P4310320990
# 11634                                          None           {}
# 11635  Centre National de la Recherche Scientifique  I1294671590
# 11636                              Nature Portfolio  P4310319908
#
#                                 display_name_institution  \
# 0                                                     {}
# 1                                                     {}
# 2                                                     {}
# 3                                                     {}
# 4                                                     {}
# ...                                                  ...
# 11632        {Aalborg University, University of Alabama}
# 11633                     {Centre Lyonnais d'Acoustique}
# 11634    {Laboratoire de génie civil et génie mécanique}
# 11635                                                 {}
# 11636  {IT University of Copenhagen, University of Ma...
#
#                                        id_institution  \
# 0                                                  {}
# 1                                                  {}
# 2                                                  {}
# 3                                                  {}
# 4                                                  {}
# ...                                               ...
# 11632                         {I17301866, I891191580}
# 11633                                   {I4391767940}
# 11634                                   {I4387155956}
# 11635                                              {}
# 11636  {I4210136082, I66946132, I83467386, I62916508}
#
#                                      display_name_author  \
# 0      {Robert E. Rutledge, Sebastien Guillot, Mathie...
# 1      {Pierre Gançarski, Camille Kurtz, Anne Puissan...
# 2                             {Yvan Castin, C. Trefzger}
# 3                     {Marc-Antoine Pérouse de Montclos}
# 4                                      {Mélanie Bourlet}
# ...                                                  ...
# 11632  {Laurent Dupont, Szymon Bęczkowski, Nick Baker...
# 11633  {Adrien Marsick, Hugo André, Ilyes Khelf, Jérô...
# 11634          {Mohammed Hjiaj, Pisey Keo, Yassir Wardi}
# 11635                              {Marie-Hélène Boblet}
# 11636  {Daniel Stilck França, James D. Watson, Emilio...
#
#                                                id_author oa_status  \
# 0      {A2104225230, A2967441990, A3016840817, A21513...    bronze
# 1      {A5090167453, A5031872978, A5009754678, A50370...     green
# 2                             {A5031838262, A5062989403}     green
# 3                                          {A5017575945}    bronze
# 4                                          {A5033776478}    closed
# ...                                                  ...       ...
# 11632  {A5008783393, A5078667423, A5021726666, A50361...    closed
# 11633  {A5051979735, A5076879793, A5022853612, A50695...    hybrid
# 11634            {A5090408324, A5095881675, A5107447778}    closed
# 11635                                      {A5107548769}     green
# 11636  {A5012147817, A5090586058, A5036761166, A50275...      gold
#
#                                                 apc_list  \
# 0      {'value': 4499, 'currency': 'USD', 'value_usd'...
# 1      {'value': 2590, 'currency': 'USD', 'value_usd'...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 11632                                               None
# 11633  {'value': 4830, 'currency': 'USD', 'value_usd'...
# 11634  {'value': 3080, 'currency': 'USD', 'value_usd'...
# 11635                                               None
# 11636  {'value': 3920, 'currency': 'GBP', 'value_usd'...
#
#                                                 apc_paid  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 11632                                               None
# 11633  {'value': 4830, 'currency': 'USD', 'value_usd'...
# 11634                                               None
# 11635                                               None
# 11636  {'value': 3920, 'currency': 'GBP', 'value_usd'...
#
#                              corresponding                   countries
# 0              [True, False, False, False]            [[], [], [], []]
# 1             [False, False, False, False]            [[], [], [], []]
# 2                           [False, False]                    [[], []]
# 3                                   [True]                        [[]]
# 4                                   [True]                        [[]]
# ...                                    ...                         ...
# 11632         [False, False, False, False]      [[US], [], [DK], [DK]]
# 11633  [False, False, False, False, False]        [[], [], [], [], []]
# 11634                [False, False, False]                [[], [], []]
# 11635                               [True]                        [[]]
# 11636         [False, False, False, False]  [[], [DE, DK], [DE], [US]]
#
# [11637 rows x 17 columns]

# %%
df_oa_missing['doi_corr'] = df_oa_missing['doi'].apply(lambda x: x[16::])
df_oa_comb_2 = df_oa_missing.merge(df, left_on = 'doi_corr', right_on = 'doi', how = 'left')
df_oa_comb_2['BSO'] = df_oa_comb_2['openalex_id'].notna()
df_oa_comb_2 = df_oa_comb_2.drop(columns = ['doi_y', 'bso_country_corrected', 'genre', 'openalex_id']).rename(columns = {'doi_x' : 'doi'})

df_tmp = pd.concat((df_oa_comb, df_oa_comb_2)).reset_index(drop = True)
df_tmp
# Out:
#                                                   doi  publication_year  \
# 0          https://doi.org/10.1016/j.cell.2013.05.039              2013
# 1         https://doi.org/10.1051/0004-6361/201322068              2013
# 2          https://doi.org/10.2458/azu_js_rc.55.16947              2013
# 3                 https://doi.org/10.1038/nature12477              2013
# 4        https://doi.org/10.1097/ccm.0b013e31827e83af              2013
# ...                                               ...               ...
# 1556714    https://doi.org/10.1109/tcpmt.2024.3370951              2024
# 1556715   https://doi.org/10.1016/j.ymssp.2024.111486              2024
# 1556716   https://doi.org/10.1016/j.finel.2024.104163              2024
# 1556717    https://doi.org/10.54563/cahiers-duras.519              2024
# 1556718    https://doi.org/10.1038/s41467-024-51439-x              2024
#
#         language                          field_name_top_topic  \
# 0             en  Biochemistry, Genetics and Molecular Biology
# 1             en                         Physics and Astronomy
# 2             en                  Earth and Planetary Sciences
# 3             en  Biochemistry, Genetics and Molecular Biology
# 4             en                                      Medicine
# ...          ...                                           ...
# 1556714       en                                   Engineering
# 1556715       en                                   Engineering
# 1556716       en                                   Engineering
# 1556717       fr                                    Psychology
# 1556718       en                             Materials Science
#
#                                                    journal   journal_id  \
# 0                                                     Cell   S110447773
# 1                               Astronomy and Astrophysics   S205231332
# 2                                              Radiocarbon    S35778795
# 3                                                   Nature   S137773608
# 4                                                      NaN           {}
# ...                                                    ...          ...
# 1556714                                               None           {}
# 1556715           Mechanical Systems and Signal Processing   S128368299
# 1556716                                               None           {}
# 1556717  HAL (Le Centre pour la Communication Scientifi...  S4306402512
# 1556718                              Nature Communications    S64187185
#
#             issn_l                                     publisher publisher_id  \
# 0        0092-8674                                    Cell Press  P4310315673
# 1        0004-6361                                  EDP Sciences  P4310319748
# 2        0033-8222                    Cambridge University Press  P4310311721
# 3        0028-0836                              Nature Portfolio  P4310319908
# 4              NaN                                           NaN           {}
# ...            ...                                           ...          ...
# 1556714        NaN                                          None           {}
# 1556715        NaN                                   Elsevier BV  P4310320990
# 1556716        NaN                                          None           {}
# 1556717        NaN  Centre National de la Recherche Scientifique  I1294671590
# 1556718        NaN                              Nature Portfolio  P4310319908
#
#                                   display_name_institution  \
# 0        {'MRC Unit for Lifelong Health and Ageing', 'C...
# 1        {'European Southern Observatory', 'Louisiana S...
# 2        {'Irvine University', 'University of Hohenheim...
# 3        {'Christian-Albrechts-Universität zu Kiel', "R...
# 4        {'Denver Health Medical Center', "St Thomas' H...
# ...                                                    ...
# 1556714        {Aalborg University, University of Alabama}
# 1556715                     {Centre Lyonnais d'Acoustique}
# 1556716    {Laboratoire de génie civil et génie mécanique}
# 1556717                                                 {}
# 1556718  {IT University of Copenhagen, University of Ma...
#
#                                             id_institution  \
# 0        {'I4210139815', 'I4210109141', 'I165339363', '...
# 1        {'I57206974', 'I188538660', 'I78577930', 'I451...
# 2        {'I1338293689', 'I31746571', 'I138006243', 'I9...
# 3        {'I4210111138', 'I2802476451', 'I4210133112', ...
# 4        {'I4210087865', 'I2801983979', 'I98251732', 'I...
# ...                                                    ...
# 1556714                            {I17301866, I891191580}
# 1556715                                      {I4391767940}
# 1556716                                      {I4387155956}
# 1556717                                                 {}
# 1556718     {I4210136082, I66946132, I83467386, I62916508}
#
#                                        display_name_author  \
# 0        {'Marı́a A. Blasco', 'Linda Partridge', 'Guido...
# 1        {'Steven M. Crawford', 'V. Zabalza', 'K. Azale...
# 2        {'Bronk Ramsey, Christopher', 'Heaton Timothy ...
# 3        {'Marcel Kool', 'Marit M. van Buuren', 'Peter ...
# 4        {'Djillali Annane', 'Charles L. Sprung', 'Fláv...
# ...                                                    ...
# 1556714  {Laurent Dupont, Szymon Bęczkowski, Nick Baker...
# 1556715  {Adrien Marsick, Hugo André, Ilyes Khelf, Jérô...
# 1556716          {Mohammed Hjiaj, Pisey Keo, Yassir Wardi}
# 1556717                              {Marie-Hélène Boblet}
# 1556718  {Daniel Stilck França, James D. Watson, Emilio...
#
#                                                  id_author oa_status  \
# 0        {'A5087974982', 'A5075296559', 'A5085977927', ...    bronze
# 1        {'A5114376504', 'A5083524651', 'A5009129182', ...    bronze
# 2        {'A3135758542', 'A1987802516', 'A3096006163', ...    bronze
# 3        {'A5072873709', 'A5089677089', 'A5026738636', ...    bronze
# 4        {'A5007271096', 'A5110810503', 'A5003379719', ...    closed
# ...                                                    ...       ...
# 1556714  {A5008783393, A5078667423, A5021726666, A50361...    closed
# 1556715  {A5051979735, A5076879793, A5022853612, A50695...    hybrid
# 1556716            {A5090408324, A5095881675, A5107447778}    closed
# 1556717                                      {A5107548769}     green
# 1556718  {A5012147817, A5090586058, A5036761166, A50275...      gold
#
#                                                   apc_list  \
# 0        {'value': 10100, 'currency': 'USD', 'value_usd...
# 1                                                      NaN
# 2                                                      NaN
# 3        {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 4                                                      NaN
# ...                                                    ...
# 1556714                                               None
# 1556715  {'value': 4830, 'currency': 'USD', 'value_usd'...
# 1556716  {'value': 3080, 'currency': 'USD', 'value_usd'...
# 1556717                                               None
# 1556718  {'value': 3920, 'currency': 'GBP', 'value_usd'...
#
#                                                   apc_paid  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1556714                                               None
# 1556715  {'value': 4830, 'currency': 'USD', 'value_usd'...
# 1556716                                               None
# 1556717                                               None
# 1556718  {'value': 3920, 'currency': 'GBP', 'value_usd'...
#
#                                              corresponding  \
# 0                       [False, False, False, True, False]
# 1        [False, False, False, False, False, False, Fal...
# 2        [True, False, False, False, False, False, Fals...
# 3        [False, False, False, False, False, False, Fal...
# 4        [False, False, False, False, False, False, Fal...
# ...                                                    ...
# 1556714                       [False, False, False, False]
# 1556715                [False, False, False, False, False]
# 1556716                              [False, False, False]
# 1556717                                             [True]
# 1556718                       [False, False, False, False]
#
#                                                  countries  \
# 0           [['ES'], ['ES'], ['DE', 'GB'], ['ES'], ['FR']]
# 1        [['DE'], ['US'], ['FR', 'US'], ['FR', 'US'], [...
# 2        [['GB'], ['FR'], ['GB'], ['US'], ['GB'], ['GB'...
# 3        [['GB'], ['GB'], ['GB'], ['CA'], ['GB'], ['GB'...
# 4        [['US'], ['US'], ['GB'], ['FR'], ['DE'], ['US'...
# ...                                                    ...
# 1556714                             [[US], [], [DK], [DK]]
# 1556715                               [[], [], [], [], []]
# 1556716                                       [[], [], []]
# 1556717                                               [[]]
# 1556718                         [[], [DE, DK], [DE], [US]]
#
#                              doi_corr    BSO
# 0          10.1016/j.cell.2013.05.039   True
# 1         10.1051/0004-6361/201322068   True
# 2          10.2458/azu_js_rc.55.16947   True
# 3                 10.1038/nature12477   True
# 4        10.1097/ccm.0b013e31827e83af  False
# ...                               ...    ...
# 1556714    10.1109/tcpmt.2024.3370951   True
# 1556715   10.1016/j.ymssp.2024.111486   True
# 1556716   10.1016/j.finel.2024.104163   True
# 1556717    10.54563/cahiers-duras.519   True
# 1556718    10.1038/s41467-024-51439-x   True
#
# [1556719 rows x 20 columns]

# %% [markdown]
# ### Check if not in Oa is not in OA

# %%
missing = df[df.openalex_id.isna()].doi.unique()

BASE_URL = "https://api.openalex.org/works"

selected_fields = ["doi", "publication_year", "language", "indexed_in", "primary_location", "best_oa_location", "open_access", "authorships", 
                   "corresponding_author_ids", "corresponding_institution_ids", "apc_list", "apc_paid", "cited_by_count", "primary_topic", "awards", "funders"]

def fetch_by_ids(id_list):
    doi_filter = "doi:" + "|".join(id_list)
    filters = [
        doi_filter,
        "indexed_in:crossref",
        "type:article|review",
    ]
    params = {
        "filter": ",".join(filters),
        "select": ",".join(selected_fields),
        "per_page": 200
    }
    url = f"{BASE_URL}?{urlencode(params)}"
    
    try:
        r = requests.get(url, timeout=30)
        r.raise_for_status()
        data = r.json()
        return data.get("results", [])
    except requests.exceptions.JSONDecodeError:
        print("JSON decode error for URL:", url[:200])
        return []  # return empty list instead of None
    except requests.exceptions.RequestException as e:
        print("Request error:", e)
        return []  # return empty list instead of None

batch_size = 50  # try increasing, test carefully
all_fetched = []
for i in tqdm(range(0, len(missing), batch_size)):
    batch = missing[i:i+batch_size]
    results = fetch_by_ids(batch)
    all_fetched.extend(results)

    
output_file = "../data/interim/FranceInitialAPI/not_openalex.jsonl"
with open(output_file, "w", encoding="utf-8") as f:
    for w in all_fetched:
        f.write(json.dumps(w) + "\n")

print(f"Saved {len(all_fetched)} records to {output_file}")

# %%
interest = ['doi', 'publication_year', 'language', 'authorships', 'best_oa_location', 'primary_topic', 'open_access', 'apc_list', 'apc_paid']
keys = ['doi', 'publication_year', 'language', 'field_name_top_topic', 'journal', 'journal_id','publisher', 'publisher_id', 'display_name_institution', 'id_institution', 'display_name_author', 'id_author',
        'oa_status', 'apc_list', 'apc_paid','corresponding', 'countries']
records = []
with open(f"../data/interim/FranceInitialAPI/not_openalex.jsonl", "rb") as f:
    for line in f:
        rec = orjson.loads(line)
        if not rec.get("doi"): # Skip records without DOI
            continue
        filtered = {k: rec.get(k) for k in interest} # Keep only the fields we care about

        # Extract field_names from topics
        filtered["field_name_top_topic"] =  filtered.get("primary_topic") .get("field", {}).get("display_name") if isinstance(filtered.get("primary_topic") , dict) else {}

        # Extract journal and publisher from best_oa_location
        pl = filtered.get("best_oa_location") or {}
        source = pl.get("source") or {}
        filtered["journal"] = source.get("display_name")
        filtered["journal_id"] = source.get("id").split("/")[-1] if source.get("id") else {}
        filtered["publisher"] = source.get("host_organization_name")
        filtered["publisher_id"] = source.get("host_organization").split("/")[-1] if source.get("host_organization") else {}

        # Extract institution types and number of authors
        authorships = filtered.get("authorships") or []
        filtered["display_name_institution"] = {inst.get("display_name") for auth in authorships for inst in auth.get("institutions", []) if inst.get("display_name")}
        filtered["id_institution"] = {inst.get("id").split('/')[-1] for auth in authorships for inst in auth.get("institutions", []) if inst.get("id")}
        filtered["corresponding"] = [auth.get("is_corresponding") for auth in authorships]
        filtered["countries"] = [auth.get("countries") for auth in authorships]
        filtered["display_name_author"] = {auth["author"].get("display_name") for auth in authorships if auth.get("author", {}).get("display_name")}
        filtered["id_author"] = {auth["author"].get("id").split('/')[-1] for auth in authorships if auth.get("author", {}).get("id")}
            
        o_a = filtered.get("open_access") or {}
        filtered["oa_status"] = o_a.get("oa_status")

        records.append({k: filtered.get(k) for k in keys})

df_not_oa = pd.DataFrame(records)
df_not_oa
# Out:
#                                                       doi  publication_year  \
# 0           https://doi.org/10.1016/s0140-6736(12)62191-6              2013
# 1                     https://doi.org/10.1038/nature11913              2013
# 2                https://doi.org/10.3389/fimmu.2013.00297              2013
# 3                    https://doi.org/10.1162/coli_a_00178              2013
# 4               https://doi.org/10.1016/j.rse.2013.09.016              2013
# ...                                                   ...               ...
# 278545                      https://doi.org/10.4000/11z8h              2024
# 278546             https://doi.org/10.3917/regar.063.0105              2024
# 278547       https://doi.org/10.1016/j.optcom.2024.130895              2024
# 278548           https://doi.org/10.62229/aubllrlxxi/22/2              2024
# 278549  https://doi.org/10.1136/annrheumdis-2024-eular...              2024
#
#        language                          field_name_top_topic  \
# 0            en                                    Psychology
# 1            en  Biochemistry, Genetics and Molecular Biology
# 2            en          Agricultural and Biological Sciences
# 3            en                              Computer Science
# 4            en                  Earth and Planetary Sciences
# ...         ...                                           ...
# 278545       fr                           Arts and Humanities
# 278546       fr                               Social Sciences
# 278547       en                         Physics and Astronomy
# 278548       en           Business, Management and Accounting
# 278549       en                                      Medicine
#
#                                             journal   journal_id  \
# 0                                              None           {}
# 1                                              None           {}
# 2                           Frontiers in Immunology  S2595292759
# 3                         Computational Linguistics   S155526855
# 4       Open Research Exeter (University of Exeter)  S4306401998
# ...                                             ...          ...
# 278545                                         None           {}
# 278546                                         None           {}
# 278547                                         None           {}
# 278548                                         None           {}
# 278549                                         None           {}
#
#                                         publisher publisher_id  \
# 0                                            None           {}
# 1                                            None           {}
# 2                                 Frontiers Media  P4310320527
# 3       Association for Computational Linguistics  P4310320244
# 4                            University of Exeter    I23923803
# ...                                           ...          ...
# 278545                                       None           {}
# 278546                                       None           {}
# 278547                                       None           {}
# 278548                                       None           {}
# 278549                                       None           {}
#
#                                  display_name_institution  \
# 0       {Menlo School, University College London, Bena...
# 1       {Swiss Federal Institute of Aquatic Science an...
# 2                                                      {}
# 3                               {University of Edinburgh}
# 4       {Brockmann Consult (Germany), University of Be...
# ...                                                   ...
# 278545                                                 {}
# 278546                                                 {}
# 278547                                                 {}
# 278548                                                 {}
# 278549                                                 {}
#
#                                            id_institution  \
# 0       {I1297785818, I93593358, I4210103779, I4512925...
# 1                                  {I35440088, I63664421}
# 2                                                      {}
# 3                                             {I98677209}
# 4       {I147554453, I87339560, I154570441, I33434090,...
# ...                                                   ...
# 278545                                                 {}
# 278546                                                 {}
# 278547                                                 {}
# 278548                                                 {}
# 278549                                                 {}
#
#                                       display_name_author  \
# 0       {Geoffrey M. Reed, Mark van Ommeren, Cécile Ro...
# 1       {Médéric Diard, Wolf‐Dietrich Hardt, Víctor Ga...
# 2       {Florence Jacob, Saskia Vernaldi, Takaki Maekawa}
# 3                                        {Khaled Shaalan}
# 4       {Chuanmin Hu, Norman Fomferra, Andrew Horseman...
# ...                                                   ...
# 278545                                     {Jingjing Han}
# 278546                                  {Patrick Savidan}
# 278547                  {Jacob Szeftel, Jean-Claude Lévy}
# 278548                                {ALEXANDRU MARDALE}
# 278549  {Paul Bastard, Pascale Richard, Jean‐Laurent C...
#
#                                                 id_author oa_status  \
# 0       {A5031705704, A5082743440, A5025675403, A50525...    closed
# 1       {A5048213818, A5009994638, A5067932949, A50415...    closed
# 2                 {A5080440564, A5090760688, A5086360259}      gold
# 3                                           {A5066945309}    bronze
# 4       {A5079456188, A5039410024, A5058877813, A50278...     green
# ...                                                   ...       ...
# 278545                                      {A5101103010}      gold
# 278546                                      {A5104824994}    closed
# 278547                         {A5030357905, A5113997816}    closed
# 278548                                      {A5106111675}    closed
# 278549  {A5044024585, A5019057064, A5062601012, A50296...    closed
#
#                                                  apc_list  \
# 0       {'value': 6830, 'currency': 'USD', 'value_usd'...
# 1       {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 2       {'value': 2950, 'currency': 'USD', 'value_usd'...
# 3                                                    None
# 4       {'value': 4070, 'currency': 'USD', 'value_usd'...
# ...                                                   ...
# 278545                                               None
# 278546                                               None
# 278547  {'value': 2320, 'currency': 'USD', 'value_usd'...
# 278548                                               None
# 278549                                               None
#
#                                                  apc_paid  \
# 0                                                    None
# 1                                                    None
# 2       {'value': 1105, 'currency': 'EUR', 'value_usd'...
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 278545                                               None
# 278546                                               None
# 278547                                               None
# 278548                                               None
# 278549                                               None
#
#                                             corresponding  \
# 0       [False, False, False, False, False, False, Fal...
# 1       [False, False, False, False, False, False, False]
# 2                                   [False, False, False]
# 3                                                  [True]
# 4       [False, False, False, False, False, False, Fal...
# ...                                                   ...
# 278545                                             [True]
# 278546                                             [True]
# 278547                                     [False, False]
# 278548                                             [True]
# 278549  [False, False, False, False, False, False, Fal...
#
#                                                 countries
# 0       [[CH], [GB], [AU], [US], [CH], [CH], [PK], [US...
# 1              [[CH], [CH], [CH], [CH], [CH], [CH], [CH]]
# 2                                            [[], [], []]
# 3                                                  [[GB]]
# 4       [[GB], [GB], [DE], [DE], [], [CA], [DE], [DE],...
# ...                                                   ...
# 278545                                               [[]]
# 278546                                               [[]]
# 278547                                           [[], []]
# 278548                                               [[]]
# 278549               [[], [], [], [], [], [], [], [], []]
#
# [278550 rows x 17 columns]

# %%
df_not_oa['doi_corr'] = df_not_oa['doi'].apply(lambda x: x[16::])
df_not_oa['BSO'] = True

df_final = pd.concat((df_tmp, df_not_oa)).drop_duplicates('doi').reset_index(drop = True)
df_final.to_csv('../data/interim/initial_dataset.csv')
df_final
# Out:
#                                                        doi  publication_year  \
# 0               https://doi.org/10.1016/j.cell.2013.05.039              2013
# 1              https://doi.org/10.1051/0004-6361/201322068              2013
# 2               https://doi.org/10.2458/azu_js_rc.55.16947              2013
# 3                      https://doi.org/10.1038/nature12477              2013
# 4             https://doi.org/10.1097/ccm.0b013e31827e83af              2013
# ...                                                    ...               ...
# 1831082                      https://doi.org/10.4000/11z8h              2024
# 1831083             https://doi.org/10.3917/regar.063.0105              2024
# 1831084       https://doi.org/10.1016/j.optcom.2024.130895              2024
# 1831085           https://doi.org/10.62229/aubllrlxxi/22/2              2024
# 1831086  https://doi.org/10.1136/annrheumdis-2024-eular...              2024
#
#         language                          field_name_top_topic  \
# 0             en  Biochemistry, Genetics and Molecular Biology
# 1             en                         Physics and Astronomy
# 2             en                  Earth and Planetary Sciences
# 3             en  Biochemistry, Genetics and Molecular Biology
# 4             en                                      Medicine
# ...          ...                                           ...
# 1831082       fr                           Arts and Humanities
# 1831083       fr                               Social Sciences
# 1831084       en                         Physics and Astronomy
# 1831085       en           Business, Management and Accounting
# 1831086       en                                      Medicine
#
#                             journal  journal_id     issn_l  \
# 0                              Cell  S110447773  0092-8674
# 1        Astronomy and Astrophysics  S205231332  0004-6361
# 2                       Radiocarbon   S35778795  0033-8222
# 3                            Nature  S137773608  0028-0836
# 4                               NaN          {}        NaN
# ...                             ...         ...        ...
# 1831082                        None          {}        NaN
# 1831083                        None          {}        NaN
# 1831084                        None          {}        NaN
# 1831085                        None          {}        NaN
# 1831086                        None          {}        NaN
#
#                           publisher publisher_id  \
# 0                        Cell Press  P4310315673
# 1                      EDP Sciences  P4310319748
# 2        Cambridge University Press  P4310311721
# 3                  Nature Portfolio  P4310319908
# 4                               NaN           {}
# ...                             ...          ...
# 1831082                        None           {}
# 1831083                        None           {}
# 1831084                        None           {}
# 1831085                        None           {}
# 1831086                        None           {}
#
#                                   display_name_institution  \
# 0        {'MRC Unit for Lifelong Health and Ageing', 'C...
# 1        {'European Southern Observatory', 'Louisiana S...
# 2        {'Irvine University', 'University of Hohenheim...
# 3        {'Christian-Albrechts-Universität zu Kiel', "R...
# 4        {'Denver Health Medical Center', "St Thomas' H...
# ...                                                    ...
# 1831082                                                 {}
# 1831083                                                 {}
# 1831084                                                 {}
# 1831085                                                 {}
# 1831086                                                 {}
#
#                                             id_institution  \
# 0        {'I4210139815', 'I4210109141', 'I165339363', '...
# 1        {'I57206974', 'I188538660', 'I78577930', 'I451...
# 2        {'I1338293689', 'I31746571', 'I138006243', 'I9...
# 3        {'I4210111138', 'I2802476451', 'I4210133112', ...
# 4        {'I4210087865', 'I2801983979', 'I98251732', 'I...
# ...                                                    ...
# 1831082                                                 {}
# 1831083                                                 {}
# 1831084                                                 {}
# 1831085                                                 {}
# 1831086                                                 {}
#
#                                        display_name_author  \
# 0        {'Marı́a A. Blasco', 'Linda Partridge', 'Guido...
# 1        {'Steven M. Crawford', 'V. Zabalza', 'K. Azale...
# 2        {'Bronk Ramsey, Christopher', 'Heaton Timothy ...
# 3        {'Marcel Kool', 'Marit M. van Buuren', 'Peter ...
# 4        {'Djillali Annane', 'Charles L. Sprung', 'Fláv...
# ...                                                    ...
# 1831082                                     {Jingjing Han}
# 1831083                                  {Patrick Savidan}
# 1831084                  {Jacob Szeftel, Jean-Claude Lévy}
# 1831085                                {ALEXANDRU MARDALE}
# 1831086  {Paul Bastard, Pascale Richard, Jean‐Laurent C...
#
#                                                  id_author oa_status  \
# 0        {'A5087974982', 'A5075296559', 'A5085977927', ...    bronze
# 1        {'A5114376504', 'A5083524651', 'A5009129182', ...    bronze
# 2        {'A3135758542', 'A1987802516', 'A3096006163', ...    bronze
# 3        {'A5072873709', 'A5089677089', 'A5026738636', ...    bronze
# 4        {'A5007271096', 'A5110810503', 'A5003379719', ...    closed
# ...                                                    ...       ...
# 1831082                                      {A5101103010}      gold
# 1831083                                      {A5104824994}    closed
# 1831084                         {A5030357905, A5113997816}    closed
# 1831085                                      {A5106111675}    closed
# 1831086  {A5044024585, A5019057064, A5062601012, A50296...    closed
#
#                                                   apc_list apc_paid  \
# 0        {'value': 10100, 'currency': 'USD', 'value_usd...      NaN
# 1                                                      NaN      NaN
# 2                                                      NaN      NaN
# 3        {'value': 9750, 'currency': 'EUR', 'value_usd'...      NaN
# 4                                                      NaN      NaN
# ...                                                    ...      ...
# 1831082                                               None     None
# 1831083                                               None     None
# 1831084  {'value': 2320, 'currency': 'USD', 'value_usd'...     None
# 1831085                                               None     None
# 1831086                                               None     None
#
#                                              corresponding  \
# 0                       [False, False, False, True, False]
# 1        [False, False, False, False, False, False, Fal...
# 2        [True, False, False, False, False, False, Fals...
# 3        [False, False, False, False, False, False, Fal...
# 4        [False, False, False, False, False, False, Fal...
# ...                                                    ...
# 1831082                                             [True]
# 1831083                                             [True]
# 1831084                                     [False, False]
# 1831085                                             [True]
# 1831086  [False, False, False, False, False, False, Fal...
#
#                                                  countries  \
# 0           [['ES'], ['ES'], ['DE', 'GB'], ['ES'], ['FR']]
# 1        [['DE'], ['US'], ['FR', 'US'], ['FR', 'US'], [...
# 2        [['GB'], ['FR'], ['GB'], ['US'], ['GB'], ['GB'...
# 3        [['GB'], ['GB'], ['GB'], ['CA'], ['GB'], ['GB'...
# 4        [['US'], ['US'], ['GB'], ['FR'], ['DE'], ['US'...
# ...                                                    ...
# 1831082                                               [[]]
# 1831083                                               [[]]
# 1831084                                           [[], []]
# 1831085                                               [[]]
# 1831086               [[], [], [], [], [], [], [], [], []]
#
#                                     doi_corr    BSO
# 0                 10.1016/j.cell.2013.05.039   True
# 1                10.1051/0004-6361/201322068   True
# 2                 10.2458/azu_js_rc.55.16947   True
# 3                        10.1038/nature12477   True
# 4               10.1097/ccm.0b013e31827e83af  False
# ...                                      ...    ...
# 1831082                        10.4000/11z8h   True
# 1831083               10.3917/regar.063.0105   True
# 1831084         10.1016/j.optcom.2024.130895   True
# 1831085             10.62229/aubllrlxxi/22/2   True
# 1831086  10.1136/annrheumdis-2024-eular.1992   True
#
# [1831087 rows x 20 columns]

# %% [markdown]
# ## Construct Inclusive option (any corresponding french and non-corresponding last or first french [less 50 authors])

# %%
def safe_literal_eval(x):
    if isinstance(x, str):
        try:
            return ast.literal_eval(x)
        except Exception:
            return []
    return []

chunks = pd.read_csv('../data/interim/initial_dataset.csv', chunksize=100000)


df_interest_parts = []
for chunk in tqdm(chunks):
    chunk = chunk.drop(columns='Unnamed: 0')

    chunk['corresponding'] = chunk['corresponding'].apply(safe_literal_eval)
    chunk['countries'] = chunk['countries'].apply(safe_literal_eval)

    # Positions of French authors
    chunk['french_position'] = chunk['countries'].apply(lambda lst: [i for i, inner in enumerate(lst) if 'FR' in inner])

    # No-corresponding vs with-corresponding
    no_corr_mask = chunk['corresponding'].apply(lambda x: all(v is False for v in x))
    chunk_nocorresponding = chunk[no_corr_mask]
    chunk_corresponding = chunk[~no_corr_mask]

    # -------------------------
    # CASE 1: ANY corresponding French author
    # -------------------------
    chunk_corresponding['CA_positions'] = chunk_corresponding['corresponding'].apply(lambda lst: [i for i, v in enumerate(lst) if v])
    chunk_corresponding_anyfrench = chunk_corresponding[chunk_corresponding.apply(lambda row: bool(set(row['CA_positions']) & set(row['french_position'])), axis = 1)]

    # -------------------------
    # CASE 2: No corresponding author First or last author French nb authors < 50
    # -------------------------
    chunk_nocorresponding['n_authors'] = chunk_nocorresponding['corresponding'].str.len()
    chunk_nocorresponding_50 = chunk_nocorresponding[(chunk_nocorresponding['n_authors'] > 0) & (chunk_nocorresponding['n_authors'] < 50)]
    chunk_nocorresponding_50_ca_fr = chunk_nocorresponding_50[chunk_nocorresponding_50.apply(lambda row: ((0 in row['french_position']) or (len(row['french_position']) > 0 and
                                                              max(row['french_position']) == row['n_authors'] - 1)), axis = 1)]

    df_interest_parts.append(pd.concat([chunk_corresponding_anyfrench, chunk_nocorresponding_50_ca_fr], ignore_index = False))

df_interest = (pd.concat(df_interest_parts, ignore_index = True).drop(columns=['doi_corr', 'french_position', 'CA_positions', 'n_authors']))
df_interest = df_interest[df_interest['publication_year'].between(2013, 2024)].reset_index(drop=True)
df_interest.to_csv('../data/interim/inclusive_branch.csv', index = False)
df_interest
# Out:
# 19it [02:05,  6.62s/it]
#                                                        doi  publication_year  \
# 0               https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 1             https://doi.org/10.1016/j.immuni.2013.10.003              2013
# 2               https://doi.org/10.1016/j.jacc.2013.10.029              2013
# 3                 https://doi.org/10.1093/eurheartj/eht273              2013
# 4           https://doi.org/10.1016/j.jbusvent.2013.07.003              2013
# ...                                                    ...               ...
# 1157984            https://doi.org/10.26532/jh.v40i1.37175              2024
# 1157985  https://doi.org/10.1109/icacite60783.2024.1126...              2024
# 1157986             https://doi.org/10.1055/s-0044-1791345              2024
# 1157987             https://doi.org/10.3390/quantum1020022              2019
# 1157988    https://doi.org/10.1109/iolts50870.2020.9159750              2020
#
#         language                          field_name_top_topic  \
# 0             en                                      Medicine
# 1             en                                      Medicine
# 2             en                                      Medicine
# 3             en                                      Medicine
# 4             en           Business, Management and Accounting
# ...          ...                                           ...
# 1157984       fr                                            {}
# 1157985      NaN                                            {}
# 1157986       en                                            {}
# 1157987       en                         Physics and Astronomy
# 1157988       en  Biochemistry, Genetics and Molecular Biology
#
#                              journal   journal_id     issn_l  \
# 0         European Journal of Cancer    S16731738  0959-8049
# 1                           Immunity   S199671312  1074-7613
# 2                                NaN           {}        NaN
# 3             European Heart Journal   S181568219  0195-668X
# 4        Digital Access to Libraries  S4306400166        NaN
# ...                              ...          ...        ...
# 1157984                 Jurnal Hukum  S4210234340  1412-2723
# 1157985                          NaN           {}        NaN
# 1157986                          NaN           {}        NaN
# 1157987              Quantum Reports  S4210211996        NaN
# 1157988   arXiv (Cornell University)  S4306400194        NaN
#
#                                               publisher publisher_id  \
# 0                                           Elsevier BV  P4310320990
# 1                                            Cell Press  P4310315673
# 2                                                   NaN           {}
# 3                               Oxford University Press  P4310311648
# 4                          Harris County Public Library  I2800384882
# ...                                                 ...          ...
# 1157984                                             NaN           {}
# 1157985                                             NaN           {}
# 1157986                                             NaN           {}
# 1157987  Multidisciplinary Digital Publishing Institute  P4310310987
# 1157988                              Cornell University   I205783295
#
#                                   display_name_institution  \
# 0        {'National Cancer Registry', 'Piedmont Referen...
# 1        {'Centre de Recherche des Cordeliers', 'Sorbon...
# 2        {'Bicêtre Hospital', 'Université Paris-Sud', '...
# 3        {'University of Milan', 'Pitié-Salpêtrière Hos...
# 4         {'UCLouvain', 'Université Lille Nord de France'}
# ...                                                    ...
# 1157984  {'Universitas Kristen Indonesia Paulus', 'Univ...
# 1157985  {'Uttaranchal University', 'School of Business...
# 1157986           {"École Nationale Vétérinaire d'Alfort"}
# 1157987                               {'Fudan University'}
# 1157988                                              set()
#
#                                             id_institution  \
# 0        {'I4210152360', 'I2801952686', 'I42237331', 'I...
# 1        {'I39804081', 'I4210092322', 'I4210097159', 'I...
# 2        {'I154425047', 'I45129253', 'I4210131615', 'I1...
# 3        {'I4210107246', 'I177877127', 'I4210121705', '...
# 4                               {'I59807433', 'I95674353'}
# ...                                                    ...
# 1157984                       {'I51101395', 'I4210130201'}
# 1157985  {'I4210107574', 'I3131779051', 'I85461943', 'I...
# 1157986                                      {'I17606148'}
# 1157987                               {'I-1', 'I24943067'}
# 1157988                                            {'I-1'}
#
#                                        display_name_author  \
# 0        {'Freddie Bray', 'Harry Comber', 'D Forman', '...
# 1        {'Patrick Bruneval', 'Helen K. Angell', 'Micha...
# 2        {'Horst Olschewski', 'Raman Kumar', 'Ian Adati...
# 3        {'A.F.H. Stalenhoef', 'Gerald F. Watts', 'Maur...
# 4        {'Paul Belleflamme', 'Armin Schwienbacher', 'T...
# ...                                                    ...
# 1157984        {'Bernard Nainggolan', 'Anatoliy Kostruba'}
# 1157985  {'V Narasimha', 'Laith Jasim', 'A. Madeswaran'...
# 1157986                      {'Duron Loïc', 'Marc Romain'}
# 1157987              {'Chris Fields', 'Antonino Marciano'}
# 1157988  {'Aneesh Balakrishnan', 'Dan Alexandrescu', 'T...
#
#                                                  id_author oa_status  \
# 0        {'A5003542814', 'A5033644402', 'A5001567293', ...    bronze
# 1        {'A5011043959', 'A5062402346', 'A5028555797', ...    bronze
# 2        {'A5019628091', 'A5085067589', 'A5112000467', ...    closed
# 3        {'A5013598309', 'A5091523473', 'A5046743882', ...    bronze
# 4            {'A5083569548', 'A5027223667', 'A5029048208'}     green
# ...                                                    ...       ...
# 1157984                     {'A5059110458', 'A5090710975'}   diamond
# 1157985  {'A5017279275', 'A5098676093', 'A5009026788', ...    closed
# 1157986                     {'A5033250907', 'A5107010455'}    closed
# 1157987                     {'A2461076406', 'A2209647467'}      gold
# 1157988  {'A2965014352', 'A2099473666', 'A1837905640', ...     green
#
#                                                   apc_list  \
# 0        {'value': 3800, 'currency': 'USD', 'value_usd'...
# 1        {'value': 9080, 'currency': 'USD', 'value_usd'...
# 2        {'value': 6500, 'currency': 'USD', 'value_usd'...
# 3        {'value': 4238, 'currency': 'EUR', 'value_usd'...
# 4        {'value': 4080, 'currency': 'USD', 'value_usd'...
# ...                                                    ...
# 1157984                                                NaN
# 1157985                                                NaN
# 1157986                                                NaN
# 1157987  {'value': 1200, 'currency': 'CHF', 'value_usd'...
# 1157988                                                NaN
#
#                                                   apc_paid  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1157984                                                NaN
# 1157985                                                NaN
# 1157986                                                NaN
# 1157987  {'value': 1200, 'currency': 'CHF', 'value_usd'...
# 1157988                                                NaN
#
#                                              corresponding  \
# 0        [True, False, False, False, False, False, Fals...
# 1        [False, False, False, False, False, False, Fal...
# 2        [True, False, False, False, False, False, Fals...
# 3        [True, True, False, False, False, False, False...
# 4                                     [False, False, True]
# ...                                                    ...
# 1157984                                     [False, False]
# 1157985                [False, False, False, False, False]
# 1157986                                     [False, False]
# 1157987                        [True, False, False, False]
# 1157988  [True, False, False, False, False, False, Fals...
#
#                                                  countries    BSO
# 0         [[FR], [FR], [FR], [IT], [NL], [IE], [FR], [FR]]   True
# 1        [[FR], [FR], [FR], [FR], [DE, FR], [AT], [FR],...   True
# 2        [[FR], [GB], [CA], [AU], [GB], [DE], [ES], [IN...   True
# 3        [[DK], [FR], [GB], [US], [ES], [BE], [SE], [CA...   True
# 4                                   [[BE], [BE, FR], [FR]]   True
# ...                                                    ...    ...
# 1157984                                       [[ID], [FR]]  False
# 1157985                 [[FR, IN], [IN], [IN], [IQ], [IN]]  False
# 1157986                                       [[FR], [FR]]  False
# 1157987                           [[FR], [CN], [FR], [CN]]   True
# 1157988           [[FR], [FR], [FR], [FR], [], [], [], []]   True
#
# [1157989 rows x 19 columns]

# %% [markdown]
# ## Integrate National Agreements

# %%
df_interest = pd.read_csv('../data/interim/inclusive_branch.csv')
df_interest
# Out:
#                                                        doi  publication_year  \
# 0               https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 1             https://doi.org/10.1016/j.immuni.2013.10.003              2013
# 2               https://doi.org/10.1016/j.jacc.2013.10.029              2013
# 3                 https://doi.org/10.1093/eurheartj/eht273              2013
# 4           https://doi.org/10.1016/j.jbusvent.2013.07.003              2013
# ...                                                    ...               ...
# 1157984            https://doi.org/10.26532/jh.v40i1.37175              2024
# 1157985  https://doi.org/10.1109/icacite60783.2024.1126...              2024
# 1157986             https://doi.org/10.1055/s-0044-1791345              2024
# 1157987             https://doi.org/10.3390/quantum1020022              2019
# 1157988    https://doi.org/10.1109/iolts50870.2020.9159750              2020
#
#         language                          field_name_top_topic  \
# 0             en                                      Medicine
# 1             en                                      Medicine
# 2             en                                      Medicine
# 3             en                                      Medicine
# 4             en           Business, Management and Accounting
# ...          ...                                           ...
# 1157984       fr                                            {}
# 1157985      NaN                                            {}
# 1157986       en                                            {}
# 1157987       en                         Physics and Astronomy
# 1157988       en  Biochemistry, Genetics and Molecular Biology
#
#                              journal   journal_id     issn_l  \
# 0         European Journal of Cancer    S16731738  0959-8049
# 1                           Immunity   S199671312  1074-7613
# 2                                NaN           {}        NaN
# 3             European Heart Journal   S181568219  0195-668X
# 4        Digital Access to Libraries  S4306400166        NaN
# ...                              ...          ...        ...
# 1157984                 Jurnal Hukum  S4210234340  1412-2723
# 1157985                          NaN           {}        NaN
# 1157986                          NaN           {}        NaN
# 1157987              Quantum Reports  S4210211996        NaN
# 1157988   arXiv (Cornell University)  S4306400194        NaN
#
#                                               publisher publisher_id  \
# 0                                           Elsevier BV  P4310320990
# 1                                            Cell Press  P4310315673
# 2                                                   NaN           {}
# 3                               Oxford University Press  P4310311648
# 4                          Harris County Public Library  I2800384882
# ...                                                 ...          ...
# 1157984                                             NaN           {}
# 1157985                                             NaN           {}
# 1157986                                             NaN           {}
# 1157987  Multidisciplinary Digital Publishing Institute  P4310310987
# 1157988                              Cornell University   I205783295
#
#                                   display_name_institution  \
# 0        {'National Cancer Registry', 'Piedmont Referen...
# 1        {'Centre de Recherche des Cordeliers', 'Sorbon...
# 2        {'Bicêtre Hospital', 'Université Paris-Sud', '...
# 3        {'University of Milan', 'Pitié-Salpêtrière Hos...
# 4         {'UCLouvain', 'Université Lille Nord de France'}
# ...                                                    ...
# 1157984  {'Universitas Kristen Indonesia Paulus', 'Univ...
# 1157985  {'Uttaranchal University', 'School of Business...
# 1157986           {"École Nationale Vétérinaire d'Alfort"}
# 1157987                               {'Fudan University'}
# 1157988                                              set()
#
#                                             id_institution  \
# 0        {'I4210152360', 'I2801952686', 'I42237331', 'I...
# 1        {'I39804081', 'I4210092322', 'I4210097159', 'I...
# 2        {'I154425047', 'I45129253', 'I4210131615', 'I1...
# 3        {'I4210107246', 'I177877127', 'I4210121705', '...
# 4                               {'I59807433', 'I95674353'}
# ...                                                    ...
# 1157984                       {'I51101395', 'I4210130201'}
# 1157985  {'I4210107574', 'I3131779051', 'I85461943', 'I...
# 1157986                                      {'I17606148'}
# 1157987                               {'I-1', 'I24943067'}
# 1157988                                            {'I-1'}
#
#                                        display_name_author  \
# 0        {'Freddie Bray', 'Harry Comber', 'D Forman', '...
# 1        {'Patrick Bruneval', 'Helen K. Angell', 'Micha...
# 2        {'Horst Olschewski', 'Raman Kumar', 'Ian Adati...
# 3        {'A.F.H. Stalenhoef', 'Gerald F. Watts', 'Maur...
# 4        {'Paul Belleflamme', 'Armin Schwienbacher', 'T...
# ...                                                    ...
# 1157984        {'Bernard Nainggolan', 'Anatoliy Kostruba'}
# 1157985  {'V Narasimha', 'Laith Jasim', 'A. Madeswaran'...
# 1157986                      {'Duron Loïc', 'Marc Romain'}
# 1157987              {'Chris Fields', 'Antonino Marciano'}
# 1157988  {'Aneesh Balakrishnan', 'Dan Alexandrescu', 'T...
#
#                                                  id_author oa_status  \
# 0        {'A5003542814', 'A5033644402', 'A5001567293', ...    bronze
# 1        {'A5011043959', 'A5062402346', 'A5028555797', ...    bronze
# 2        {'A5019628091', 'A5085067589', 'A5112000467', ...    closed
# 3        {'A5013598309', 'A5091523473', 'A5046743882', ...    bronze
# 4            {'A5083569548', 'A5027223667', 'A5029048208'}     green
# ...                                                    ...       ...
# 1157984                     {'A5059110458', 'A5090710975'}   diamond
# 1157985  {'A5017279275', 'A5098676093', 'A5009026788', ...    closed
# 1157986                     {'A5033250907', 'A5107010455'}    closed
# 1157987                     {'A2461076406', 'A2209647467'}      gold
# 1157988  {'A2965014352', 'A2099473666', 'A1837905640', ...     green
#
#                                                   apc_list  \
# 0        {'value': 3800, 'currency': 'USD', 'value_usd'...
# 1        {'value': 9080, 'currency': 'USD', 'value_usd'...
# 2        {'value': 6500, 'currency': 'USD', 'value_usd'...
# 3        {'value': 4238, 'currency': 'EUR', 'value_usd'...
# 4        {'value': 4080, 'currency': 'USD', 'value_usd'...
# ...                                                    ...
# 1157984                                                NaN
# 1157985                                                NaN
# 1157986                                                NaN
# 1157987  {'value': 1200, 'currency': 'CHF', 'value_usd'...
# 1157988                                                NaN
#
#                                                   apc_paid  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1157984                                                NaN
# 1157985                                                NaN
# 1157986                                                NaN
# 1157987  {'value': 1200, 'currency': 'CHF', 'value_usd'...
# 1157988                                                NaN
#
#                                              corresponding  \
# 0        [True, False, False, False, False, False, Fals...
# 1        [False, False, False, False, False, False, Fal...
# 2        [True, False, False, False, False, False, Fals...
# 3        [True, True, False, False, False, False, False...
# 4                                     [False, False, True]
# ...                                                    ...
# 1157984                                     [False, False]
# 1157985                [False, False, False, False, False]
# 1157986                                     [False, False]
# 1157987                        [True, False, False, False]
# 1157988  [True, False, False, False, False, False, Fals...
#
#                                                  countries    BSO
# 0        [['FR'], ['FR'], ['FR'], ['IT'], ['NL'], ['IE'...   True
# 1        [['FR'], ['FR'], ['FR'], ['FR'], ['DE', 'FR'],...   True
# 2        [['FR'], ['GB'], ['CA'], ['AU'], ['GB'], ['DE'...   True
# 3        [['DK'], ['FR'], ['GB'], ['US'], ['ES'], ['BE'...   True
# 4                           [['BE'], ['BE', 'FR'], ['FR']]   True
# ...                                                    ...    ...
# 1157984                                   [['ID'], ['FR']]  False
# 1157985     [['FR', 'IN'], ['IN'], ['IN'], ['IQ'], ['IN']]  False
# 1157986                                   [['FR'], ['FR']]  False
# 1157987                   [['FR'], ['CN'], ['FR'], ['CN']]   True
# 1157988   [['FR'], ['FR'], ['FR'], ['FR'], [], [], [], []]   True
#
# [1157989 rows x 19 columns]

# %% [markdown]
# ### Elsevier

# %%
df_interest['doi_corr'] = df_interest['doi'].str[16:]

col = 'Publication VoR date'
interest_status = ['Accepted', 'Not yet in EOAP', 'Pending']

df_elsevier = (pd.read_csv('../data/external/Elsevier_EOAP_2225_Décembre.csv').dropna(subset = [col]))
df_elsevier['year'] = pd.to_datetime(df_elsevier[col], dayfirst = True, errors = 'coerce').dt.year
df_elsevier = df_elsevier[(df_elsevier['year'] < 2025) &(df_elsevier['Status'].isin(interest_status))]

matched_mask = df_elsevier['Article DOI'].isin(df_interest['doi_corr'])
print(df_elsevier.loc[matched_mask, 'Article DOI'].nunique() / df_elsevier['Article DOI'].nunique())
df_elsevier_filtered = df_elsevier.loc[matched_mask].reset_index(drop=True)

df_elsevier_filtered
# Out:
# 0.8644775288715737
#             Article PII         Corresponding author name  \
# 0     S0732889324000312  de Villiers de la Noue, Valentin
# 1     S1879981724002997                       Garot, Elsa
# 2     S2214250922000403                  Eloy, Philippine
# 3     S2214250923000859                   Manchon, Romain
# 4     S1201971224003965                     Buyck, Julien
# ...                 ...                               ...
# 6208  S0925231224006325           Zeghina, Assaad Oussama
# 6209  S1542356524006062                  Cariou, Bertrand
# 6210  S0300908424001408                     Coux, Olivier
# 6211  S1542356522005547                 Shimakawa, Yusuke
# 6212  S0308521X22001603          Bellon-Maurel, Veronique
#
#                  Corresponding author email  \
# 0      vde-villiers-de-la-noue@chu-reims.fr
# 1                  elsa.garot@u-bordeaux.fr
# 2                   philippine.eloy@aphp.fr
# 3                    romain.manchon@aphp.fr
# 4             julien.buyck@univ-poitiers.fr
# ...                                     ...
# 6208  assaad-oussama.zeghina@etu.unistra.fr
# 6209         bertrand.cariou@univ-nantes.fr
# 6210                   olivier.coux@cnrs.fr
# 6211            yusuke.shimakawa@pasteur.fr
# 6212              veronique.bellon@inrae.fr
#
#                     Corresponding author institute name  \
# 0                 University of Reims Champagne-Ardenne
# 1     University of Bordeaux College of Health Sciences
# 2                     Public Assistance Hospitals Paris
# 3                                      Beaujon Hospital
# 4                                University of Poitiers
# ...                                                 ...
# 6208                           University of Strasbourg
# 6209                                   Thorax Institute
# 6210     Institute of Molecular Genetics of Montpellier
# 6211                                   Institut Pasteur
# 6212  French National Institute for Agricultural Res...
#
#      Corresponding author institute ECR  \
# 0                             ECR-25656
# 1                          ECR-10250482
# 2                            ECR-213123
# 3                          ECR-10353746
# 4                             ECR-25646
# ...                                 ...
# 6208                          ECR-25630
# 6209                       ECR-33534174
# 6210                       ECR-10214327
# 6211                          ECR-26852
# 6212                          ECR-26854
#
#                            Article Payer Institute Name  \
# 0                 University of Reims Champagne-Ardenne
# 1                                University of Bordeaux
# 2                     Public Assistance Hospitals Paris
# 3                     Public Assistance Hospitals Paris
# 4                                University of Poitiers
# ...                                                 ...
# 6208                           University of Strasbourg
# 6209                                             INSERM
# 6210                          University of Montpellier
# 6211                                   Institut Pasteur
# 6212  French National Institute for Agricultural Res...
#
#      Article Payer Institute ECR Article publishing model User license  \
# 0                      ECR-25656       Hybrid open access  CC BY-NC-ND
# 1                      ECR-25642       Hybrid open access        CC BY
# 2                     ECR-213123         Full open access  CC BY-NC-ND
# 3                     ECR-213123         Full open access        CC BY
# 4                      ECR-25646         Full open access        CC BY
# ...                          ...                      ...          ...
# 6208                   ECR-25630       Hybrid open access        CC BY
# 6209                   ECR-26853       Hybrid open access        CC BY
# 6210                  ECR-330768       Hybrid open access        CC BY
# 6211                   ECR-26852       Hybrid open access        CC BY
# 6212                   ECR-26854       Hybrid open access        CC BY
#
#      Journal ISSN  ... Acceptance date Author journey completion date  \
# 0       0732-8893  ...      30/01/2024                     30/01/2024
# 1       1879-9817  ...      23/06/2024                     01/07/2024
# 2       2214-2509  ...      20/01/2022                     08/02/2022
# 3       2214-2509  ...      01/04/2023                     10/04/2023
# 4       1201-9712  ...      26/11/2024                     29/11/2024
# ...           ...  ...             ...                            ...
# 6208    0925-2312  ...      13/05/2024                     15/05/2024
# 6209    1542-3565  ...      21/06/2024                     06/07/2024
# 6210    0300-9084  ...      14/06/2024                     18/06/2024
# 6211    1542-3565  ...      13/05/2022                     09/06/2022
# 6212    0308-521X  ...      21/09/2022                     25/10/2022
#
#      Publication VoR date                                 Research funder  \
# 0              02/02/2024           University of Reims Champagne-Ardenne
# 1              16/07/2024                          University of Bordeaux
# 2              02/02/2022                                        REACTing
# 3              03/04/2023               Public Assistance Hospitals Paris
# 4              16/12/2024             Nouvelle-Aquitaine Regional Council
# ...                   ...                                             ...
# 6208           23/05/2024                 French National Research Agency
# 6209           20/12/2024                 French National Research Agency
# 6210           06/11/2024  European Cooperation in Science and Technology
# 6211           21/06/2023                             European Commission
# 6212           07/10/2022                  #Digitag Convergence Institute
#
#         Status                                            SD Link  \
# 0     Accepted  https://www.sciencedirect.com/science/article/...
# 1     Accepted  https://www.sciencedirect.com/science/article/...
# 2     Accepted  https://www.sciencedirect.com/science/article/...
# 3     Accepted  https://www.sciencedirect.com/science/article/...
# 4     Accepted  https://www.sciencedirect.com/science/article/...
# ...        ...                                                ...
# 6208  Accepted  https://www.sciencedirect.com/science/article/...
# 6209  Accepted  https://www.sciencedirect.com/science/article/...
# 6210  Accepted  https://www.sciencedirect.com/science/article/...
# 6211  Accepted  https://www.sciencedirect.com/science/article/...
# 6212  Accepted  https://www.sciencedirect.com/science/article/...
#
#      Agreement currency APC list price APC price after discount  year
# 0                   EUR          2 830                      NaN  2024
# 1                   EUR          1 740                      NaN  2024
# 2                   EUR            610                      406  2022
# 3                   EUR            820                      484  2023
# 4                   EUR            620                      NaN  2024
# ...                 ...            ...                      ...   ...
# 6208                EUR          2 250                      NaN  2024
# 6209                EUR          3 690                      NaN  2024
# 6210                EUR          2 630                      NaN  2024
# 6211                EUR          2 630                    1 698  2023
# 6212                EUR          3 340                    2 157  2022
#
# [6213 rows x 28 columns]

# %% [markdown]
# **Reconcile mails using Open Refine**

# %%
df_mails = (df_elsevier_filtered[['Corresponding author email']].drop_duplicates().copy())
df_mails = df_mails.assign(email_exploded = df_mails['Corresponding author email'].str.split(r'[;,]')).explode('email_exploded')
df_mails['email_exploded'] = df_mails['email_exploded'].str.strip()
df_mails = df_mails[df_mails['email_exploded'] != '']
df_mails = df_mails.drop_duplicates(subset = 'email_exploded').reset_index(drop = True)
df_mails[['email_exploded']].to_csv('elsevier_mails.csv', index = False)
df_mails

# %%
interest_cols = ['Article DOI', 'Corresponding author email', 'APC list price', 'APC price after discount']

df_elsevier_filtered = df_elsevier_filtered.assign(email_exploded = df_elsevier_filtered['Corresponding author email'].str.split(r'[;,]')).explode('email_exploded')
df_elsevier_filtered['email_exploded'] = df_elsevier_filtered['email_exploded'].str.strip()

df_mails_recon = pd.read_csv('elsevier_mails_recon.csv').drop(columns=['Column'], errors='ignore')

df_merged = df_elsevier_filtered.merge(df_mails_recon[['Corresponding author email_exp_2', 'Corresponding author email_exp_2_recon']], left_on = 'email_exploded',
                                       right_on = 'Corresponding author email_exp_2', how = 'left')
df_agg = (df_merged.groupby('Article DOI')['Corresponding author email_exp_2_recon'].apply(lambda x: ' | '.join(x.dropna().astype(str))).to_frame(name='Corresponding author email_recon'))

df_tmp = df_elsevier_filtered.drop(columns = ['Corresponding author email']).drop_duplicates(subset=['Article DOI'])
df_tmp = df_tmp.merge(df_agg, on = 'Article DOI', how = 'left')

df_tmp = df_tmp.assign(NationalAgreement = 'Elsevier')[['Article DOI', 'Corresponding author email_recon', 'APC list price', 'APC price after discount', 'NationalAgreement']]

df_interest_1 = df_interest.merge(df_tmp, left_on = 'doi_corr', right_on = 'Article DOI', how = 'left').drop(columns = ['Article DOI'])
df_interest_1
# Out:
#                                                        doi  publication_year  \
# 0               https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 1             https://doi.org/10.1016/j.immuni.2013.10.003              2013
# 2               https://doi.org/10.1016/j.jacc.2013.10.029              2013
# 3                 https://doi.org/10.1093/eurheartj/eht273              2013
# 4           https://doi.org/10.1016/j.jbusvent.2013.07.003              2013
# ...                                                    ...               ...
# 1157984            https://doi.org/10.26532/jh.v40i1.37175              2024
# 1157985  https://doi.org/10.1109/icacite60783.2024.1126...              2024
# 1157986             https://doi.org/10.1055/s-0044-1791345              2024
# 1157987             https://doi.org/10.3390/quantum1020022              2019
# 1157988    https://doi.org/10.1109/iolts50870.2020.9159750              2020
#
#         language                          field_name_top_topic  \
# 0             en                                      Medicine
# 1             en                                      Medicine
# 2             en                                      Medicine
# 3             en                                      Medicine
# 4             en           Business, Management and Accounting
# ...          ...                                           ...
# 1157984       fr                                            {}
# 1157985      NaN                                            {}
# 1157986       en                                            {}
# 1157987       en                         Physics and Astronomy
# 1157988       en  Biochemistry, Genetics and Molecular Biology
#
#                              journal   journal_id     issn_l  \
# 0         European Journal of Cancer    S16731738  0959-8049
# 1                           Immunity   S199671312  1074-7613
# 2                                NaN           {}        NaN
# 3             European Heart Journal   S181568219  0195-668X
# 4        Digital Access to Libraries  S4306400166        NaN
# ...                              ...          ...        ...
# 1157984                 Jurnal Hukum  S4210234340  1412-2723
# 1157985                          NaN           {}        NaN
# 1157986                          NaN           {}        NaN
# 1157987              Quantum Reports  S4210211996        NaN
# 1157988   arXiv (Cornell University)  S4306400194        NaN
#
#                                               publisher publisher_id  \
# 0                                           Elsevier BV  P4310320990
# 1                                            Cell Press  P4310315673
# 2                                                   NaN           {}
# 3                               Oxford University Press  P4310311648
# 4                          Harris County Public Library  I2800384882
# ...                                                 ...          ...
# 1157984                                             NaN           {}
# 1157985                                             NaN           {}
# 1157986                                             NaN           {}
# 1157987  Multidisciplinary Digital Publishing Institute  P4310310987
# 1157988                              Cornell University   I205783295
#
#                                   display_name_institution  ...  \
# 0        {'National Cancer Registry', 'Piedmont Referen...  ...
# 1        {'Centre de Recherche des Cordeliers', 'Sorbon...  ...
# 2        {'Bicêtre Hospital', 'Université Paris-Sud', '...  ...
# 3        {'University of Milan', 'Pitié-Salpêtrière Hos...  ...
# 4         {'UCLouvain', 'Université Lille Nord de France'}  ...
# ...                                                    ...  ...
# 1157984  {'Universitas Kristen Indonesia Paulus', 'Univ...  ...
# 1157985  {'Uttaranchal University', 'School of Business...  ...
# 1157986           {"École Nationale Vétérinaire d'Alfort"}  ...
# 1157987                               {'Fudan University'}  ...
# 1157988                                              set()  ...
#
#                                                   apc_list  \
# 0        {'value': 3800, 'currency': 'USD', 'value_usd'...
# 1        {'value': 9080, 'currency': 'USD', 'value_usd'...
# 2        {'value': 6500, 'currency': 'USD', 'value_usd'...
# 3        {'value': 4238, 'currency': 'EUR', 'value_usd'...
# 4        {'value': 4080, 'currency': 'USD', 'value_usd'...
# ...                                                    ...
# 1157984                                                NaN
# 1157985                                                NaN
# 1157986                                                NaN
# 1157987  {'value': 1200, 'currency': 'CHF', 'value_usd'...
# 1157988                                                NaN
#
#                                                   apc_paid  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1157984                                                NaN
# 1157985                                                NaN
# 1157986                                                NaN
# 1157987  {'value': 1200, 'currency': 'CHF', 'value_usd'...
# 1157988                                                NaN
#
#                                              corresponding  \
# 0        [True, False, False, False, False, False, Fals...
# 1        [False, False, False, False, False, False, Fal...
# 2        [True, False, False, False, False, False, Fals...
# 3        [True, True, False, False, False, False, False...
# 4                                     [False, False, True]
# ...                                                    ...
# 1157984                                     [False, False]
# 1157985                [False, False, False, False, False]
# 1157986                                     [False, False]
# 1157987                        [True, False, False, False]
# 1157988  [True, False, False, False, False, False, Fals...
#
#                                                  countries    BSO  \
# 0        [['FR'], ['FR'], ['FR'], ['IT'], ['NL'], ['IE'...   True
# 1        [['FR'], ['FR'], ['FR'], ['FR'], ['DE', 'FR'],...   True
# 2        [['FR'], ['GB'], ['CA'], ['AU'], ['GB'], ['DE'...   True
# 3        [['DK'], ['FR'], ['GB'], ['US'], ['ES'], ['BE'...   True
# 4                           [['BE'], ['BE', 'FR'], ['FR']]   True
# ...                                                    ...    ...
# 1157984                                   [['ID'], ['FR']]  False
# 1157985     [['FR', 'IN'], ['IN'], ['IN'], ['IQ'], ['IN']]  False
# 1157986                                   [['FR'], ['FR']]  False
# 1157987                   [['FR'], ['CN'], ['FR'], ['CN']]   True
# 1157988   [['FR'], ['FR'], ['FR'], ['FR'], [], [], [], []]   True
#
#                                    doi_corr Corresponding author email_recon  \
# 0                10.1016/j.ejca.2012.12.027                              NaN
# 1              10.1016/j.immuni.2013.10.003                              NaN
# 2                10.1016/j.jacc.2013.10.029                              NaN
# 3                  10.1093/eurheartj/eht273                              NaN
# 4            10.1016/j.jbusvent.2013.07.003                              NaN
# ...                                     ...                              ...
# 1157984             10.26532/jh.v40i1.37175                              NaN
# 1157985  10.1109/icacite60783.2024.11269084                              NaN
# 1157986              10.1055/s-0044-1791345                              NaN
# 1157987              10.3390/quantum1020022                              NaN
# 1157988     10.1109/iolts50870.2020.9159750                              NaN
#
#         APC list price  APC price after discount NationalAgreement
# 0                  NaN                       NaN               NaN
# 1                  NaN                       NaN               NaN
# 2                  NaN                       NaN               NaN
# 3                  NaN                       NaN               NaN
# 4                  NaN                       NaN               NaN
# ...                ...                       ...               ...
# 1157984            NaN                       NaN               NaN
# 1157985            NaN                       NaN               NaN
# 1157986            NaN                       NaN               NaN
# 1157987            NaN                       NaN               NaN
# 1157988            NaN                       NaN               NaN
#
# [1157989 rows x 24 columns]

# %% [markdown]
# ### Wiley

# %%
df_interest['doi_corr'] = df_interest['doi'].str[16:]

col = 'Request Date'

df_willey = (pd.read_csv('../data/external/Wiley_2225_Novembre.csv').dropna(subset = [col]))
df_willey['year'] = df_willey[col].apply(lambda x: int(x.split('-')[-1]))
df_willey = df_willey[(df_willey['year'] < 2025) & (df_willey['Request Status'] != 'Denied')]

matched_mask = df_willey['DOI'].isin(df_interest['doi_corr'])
print(df_willey.loc[matched_mask, 'DOI'].nunique() / df_willey['DOI'].nunique())
df_willey_filtered = df_willey.loc[matched_mask].reset_index(drop=True)

df_willey_filtered
# Out:
# 0.8110681755451283
#      WOA ID                                           WOA Name  eCore WOAC ID  \
# 0      U080                COUPERIN CY23 - Sorbonne Universite            NaN
# 1      U042  COUPERIN CY23 - Commissariat a l'energie atomi...            NaN
# 2      FR08           COUPERIN CY23 - Universite de Strasbourg            NaN
# 3      U083             COUPERIN CY23 - Universite Cote d'Azur            NaN
# 4      U084                COUPERIN CY23 - Universite d'Angers            NaN
# ...     ...                                                ...            ...
# 6279   P026         DEFUNCT - COUPERIN hybrid - Institut Curie            NaN
# 6280   P016  DEFUNCT - COUPERIN hybrid - Hospices Civils de...            NaN
# 6281   P113    DEFUNCT - COUPERIN hybrid - Universite de Tours            NaN
# 6282   P132  DEFUNCT - COUPERIN hybrid - Centre hospitalier...            NaN
# 6283   P084    DEFUNCT - COUPERIN hybrid - Sorbonne Universite            NaN
#
#       eCore WOAC Name Account Revenue model WOA Advance Cash?  Request Date  \
# 0                 NaN                  BOTH                 N  31-déc.-2024
# 1                 NaN                  BOTH                 N  31-déc.-2024
# 2                 NaN                  BOTH                 N  31-déc.-2024
# 3                 NaN                  BOTH                 N  30-déc.-2024
# 4                 NaN                  BOTH                 N  29-déc.-2024
# ...               ...                   ...               ...           ...
# 6279              NaN                   NaN                 N  20-avr.-2022
# 6280              NaN                   NaN                 N  20-avr.-2022
# 6281              NaN                   NaN                 N  19-avr.-2022
# 6282              NaN                   NaN                 N  19-avr.-2022
# 6283              NaN                   NaN                 N  19-avr.-2022
#
#          Request Status Request Status (internal) Journal Group Code  ...  \
# 0     Funding Confirmed         Funding Confirmed               ANIE  ...
# 1     Funding Confirmed         Funding Confirmed               CHEM  ...
# 2     Funding Confirmed         Funding Confirmed               SMLL  ...
# 3     Funding Confirmed         Funding Confirmed                VNL  ...
# 4     Funding Confirmed         Funding Confirmed                HED  ...
# ...                 ...                       ...                ...  ...
# 6279  Funding Confirmed         Funding Confirmed               2111  ...
# 6280  Funding Confirmed         Funding Confirmed                EJH  ...
# 6281  Funding Confirmed         Funding Confirmed               2328  ...
# 6282  Funding Confirmed         Funding Confirmed               IJLH  ...
# 6283  Funding Confirmed         Funding Confirmed                DOM  ...
#
#      Production Received Date EV Published Date Published in Issue Date  \
# 0                 4-déc.-2024     27-janv.-2025           17-févr.-2025
# 1                21-oct.-2024      9-janv.-2025           20-févr.-2025
# 2                 7-nov.-2024      29-déc.-2024           25-févr.-2025
# 3                12-nov.-2024      22-déc.-2024              1-mai-2025
# 4                30-juin-2024      26-déc.-2024           12-févr.-2025
# ...                       ...               ...                     ...
# 6279                      NaN       11-mai-2022            22-juin-2022
# 6280             10-avr.-2022      29-avr.-2022            12-juin-2022
# 6281             13-avr.-2022        3-mai-2022            13-juin-2022
# 6282             29-mars-2022      21-avr.-2022            15-nov.-2022
# 6283             17-avr.-2022       11-mai-2022            6-juil.-2022
#
#       Publication Status                                       Institutions  \
# 0     Published in Issue                        Sorbonne Universite (27063)
# 1     Published in Issue  Commissariat a l'energie atomique et aux energ...
# 2     Published in Issue                   Universite de Strasbourg (27083)
# 3     Published in Issue  Institut de Chimie de Nice (131888); \nUnivers...
# 4     Published in Issue  Centre Hospitalier Universitaire d'Angers Pole...
# ...                  ...                                                ...
# 6279  Published in Issue  Institut Curie Centre de Recherche Orsay (1647...
# 6280  Published in Issue                    Hospices Civils de Lyon (26900)
# 6281  Published in Issue  Universite de Tours (27092); \nINSERM, TOURS, ...
# 6282  Published in Issue  Centre Hospitalier Regional Universitaire de N...
# 6283  Published in Issue  Centre de Recherche Saint-Antoine (551865); \n...
#
#      Admin Notes User Notes Flip Status Revenue Model  year
# 0            NaN        NaN         NaN   Online Open  2024
# 1            NaN        NaN         NaN   Online Open  2024
# 2            NaN        NaN         NaN   Online Open  2024
# 3            NaN        NaN         NaN   Online Open  2024
# 4            NaN        NaN         NaN   Online Open  2024
# ...          ...        ...         ...           ...   ...
# 6279         NaN        NaN         NaN   Online Open  2022
# 6280         NaN        NaN         NaN   Online Open  2022
# 6281         NaN        NaN         NaN   Online Open  2022
# 6282         NaN        NaN         NaN   Online Open  2022
# 6283         NaN        NaN         NaN   Online Open  2022
#
# [6284 rows x 47 columns]

# %% [markdown]
# **Reconcile mails using Open Refine**

# %%
df_mails = (df_willey_filtered[['Responsible Corresponding author email']].drop_duplicates().copy())
df_mails = df_mails.assign(email_exploded = df_mails['Responsible Corresponding author email'].str.split(r'[;,]')).explode('email_exploded')
df_mails['email_exploded'] = df_mails['email_exploded'].str.strip()
df_mails = df_mails[df_mails['email_exploded'] != '']
df_mails = df_mails.drop_duplicates(subset = 'email_exploded').reset_index(drop = True)
df_mails[['email_exploded']].to_csv('willey_mails.csv', index = False)
df_mails

# %%
interest_cols = ['DOI', 'Responsible Corresponding author email', 'Full APC', 'Discount', 'Amount Charged']

df_willey_filtered = df_willey_filtered.assign(email_exploded = df_willey_filtered['Responsible Corresponding author email'].str.split(r'[;,]')).explode('email_exploded')
df_willey_filtered['email_exploded'] = df_willey_filtered['email_exploded'].str.strip()

df_mails_recon = pd.read_csv('willey_mails_recon.csv').drop(columns=['Column'], errors='ignore')

df_merged = df_willey_filtered.merge(df_mails_recon[['Responsible Corresponding author email_exp_2', 'Responsible Corresponding author email_exp_2_recon']], left_on = 'email_exploded',
                                       right_on = 'Responsible Corresponding author email_exp_2', how = 'left')
df_agg = (df_merged.groupby('DOI')['Responsible Corresponding author email_exp_2_recon'].apply(lambda x: ' | '.join(x.dropna().astype(str))).to_frame(name='Corresponding author email_recon'))

df_tmp = df_willey_filtered.drop(columns = ['Responsible Corresponding author email']).drop_duplicates(subset=['DOI'])
df_tmp = df_tmp.merge(df_agg, on = 'DOI', how = 'left')

df_tmp = df_tmp.assign(NationalAgreement = 'Wiley')[['DOI', 'Corresponding author email_recon', 'Full APC', 'Discount', 'Amount Charged', 'NationalAgreement']]

df_interest_2 = df_interest_1.merge(df_tmp, left_on = 'doi_corr', right_on = 'DOI', how = 'left').drop(columns = ['DOI'])

df_interest_2
# Out:
#                                                        doi  publication_year  \
# 0               https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 1             https://doi.org/10.1016/j.immuni.2013.10.003              2013
# 2               https://doi.org/10.1016/j.jacc.2013.10.029              2013
# 3                 https://doi.org/10.1093/eurheartj/eht273              2013
# 4           https://doi.org/10.1016/j.jbusvent.2013.07.003              2013
# ...                                                    ...               ...
# 1157984            https://doi.org/10.26532/jh.v40i1.37175              2024
# 1157985  https://doi.org/10.1109/icacite60783.2024.1126...              2024
# 1157986             https://doi.org/10.1055/s-0044-1791345              2024
# 1157987             https://doi.org/10.3390/quantum1020022              2019
# 1157988    https://doi.org/10.1109/iolts50870.2020.9159750              2020
#
#         language                          field_name_top_topic  \
# 0             en                                      Medicine
# 1             en                                      Medicine
# 2             en                                      Medicine
# 3             en                                      Medicine
# 4             en           Business, Management and Accounting
# ...          ...                                           ...
# 1157984       fr                                            {}
# 1157985      NaN                                            {}
# 1157986       en                                            {}
# 1157987       en                         Physics and Astronomy
# 1157988       en  Biochemistry, Genetics and Molecular Biology
#
#                              journal   journal_id     issn_l  \
# 0         European Journal of Cancer    S16731738  0959-8049
# 1                           Immunity   S199671312  1074-7613
# 2                                NaN           {}        NaN
# 3             European Heart Journal   S181568219  0195-668X
# 4        Digital Access to Libraries  S4306400166        NaN
# ...                              ...          ...        ...
# 1157984                 Jurnal Hukum  S4210234340  1412-2723
# 1157985                          NaN           {}        NaN
# 1157986                          NaN           {}        NaN
# 1157987              Quantum Reports  S4210211996        NaN
# 1157988   arXiv (Cornell University)  S4306400194        NaN
#
#                                               publisher publisher_id  \
# 0                                           Elsevier BV  P4310320990
# 1                                            Cell Press  P4310315673
# 2                                                   NaN           {}
# 3                               Oxford University Press  P4310311648
# 4                          Harris County Public Library  I2800384882
# ...                                                 ...          ...
# 1157984                                             NaN           {}
# 1157985                                             NaN           {}
# 1157986                                             NaN           {}
# 1157987  Multidisciplinary Digital Publishing Institute  P4310310987
# 1157988                              Cornell University   I205783295
#
#                                   display_name_institution  ...  \
# 0        {'National Cancer Registry', 'Piedmont Referen...  ...
# 1        {'Centre de Recherche des Cordeliers', 'Sorbon...  ...
# 2        {'Bicêtre Hospital', 'Université Paris-Sud', '...  ...
# 3        {'University of Milan', 'Pitié-Salpêtrière Hos...  ...
# 4         {'UCLouvain', 'Université Lille Nord de France'}  ...
# ...                                                    ...  ...
# 1157984  {'Universitas Kristen Indonesia Paulus', 'Univ...  ...
# 1157985  {'Uttaranchal University', 'School of Business...  ...
# 1157986           {"École Nationale Vétérinaire d'Alfort"}  ...
# 1157987                               {'Fudan University'}  ...
# 1157988                                              set()  ...
#
#                                    doi_corr  \
# 0                10.1016/j.ejca.2012.12.027
# 1              10.1016/j.immuni.2013.10.003
# 2                10.1016/j.jacc.2013.10.029
# 3                  10.1093/eurheartj/eht273
# 4            10.1016/j.jbusvent.2013.07.003
# ...                                     ...
# 1157984             10.26532/jh.v40i1.37175
# 1157985  10.1109/icacite60783.2024.11269084
# 1157986              10.1055/s-0044-1791345
# 1157987              10.3390/quantum1020022
# 1157988     10.1109/iolts50870.2020.9159750
#
#         Corresponding author email_recon_x APC list price  \
# 0                                      NaN            NaN
# 1                                      NaN            NaN
# 2                                      NaN            NaN
# 3                                      NaN            NaN
# 4                                      NaN            NaN
# ...                                    ...            ...
# 1157984                                NaN            NaN
# 1157985                                NaN            NaN
# 1157986                                NaN            NaN
# 1157987                                NaN            NaN
# 1157988                                NaN            NaN
#
#         APC price after discount NationalAgreement_x  \
# 0                            NaN                 NaN
# 1                            NaN                 NaN
# 2                            NaN                 NaN
# 3                            NaN                 NaN
# 4                            NaN                 NaN
# ...                          ...                 ...
# 1157984                      NaN                 NaN
# 1157985                      NaN                 NaN
# 1157986                      NaN                 NaN
# 1157987                      NaN                 NaN
# 1157988                      NaN                 NaN
#
#         Corresponding author email_recon_y Full APC Discount  Amount Charged  \
# 0                                      NaN      NaN      NaN             NaN
# 1                                      NaN      NaN      NaN             NaN
# 2                                      NaN      NaN      NaN             NaN
# 3                                      NaN      NaN      NaN             NaN
# 4                                      NaN      NaN      NaN             NaN
# ...                                    ...      ...      ...             ...
# 1157984                                NaN      NaN      NaN             NaN
# 1157985                                NaN      NaN      NaN             NaN
# 1157986                                NaN      NaN      NaN             NaN
# 1157987                                NaN      NaN      NaN             NaN
# 1157988                                NaN      NaN      NaN             NaN
#
#         NationalAgreement_y
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1157984                 NaN
# 1157985                 NaN
# 1157986                 NaN
# 1157987                 NaN
# 1157988                 NaN
#
# [1157989 rows x 29 columns]

# %%
df_interest_2 = df_interest_2.assign(NationalAgreement = df_interest_2['NationalAgreement_x'].combine_first(df_interest_2['NationalAgreement_y']),
                                    Corresponding_author_email_recon = df_interest_2['Corresponding author email_recon_x'].combine_first(df_interest_2['Corresponding author email_recon_y']))

cols_to_drop = ['NationalAgreement_x', 'NationalAgreement_y', 'Corresponding author email_recon_x', 'Corresponding author email_recon_y']
df_interest_2 = df_interest_2.drop(columns = cols_to_drop)
df_interest_2
# Out:
#                                                        doi  publication_year  \
# 0               https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 1             https://doi.org/10.1016/j.immuni.2013.10.003              2013
# 2               https://doi.org/10.1016/j.jacc.2013.10.029              2013
# 3                 https://doi.org/10.1093/eurheartj/eht273              2013
# 4           https://doi.org/10.1016/j.jbusvent.2013.07.003              2013
# ...                                                    ...               ...
# 1157984            https://doi.org/10.26532/jh.v40i1.37175              2024
# 1157985  https://doi.org/10.1109/icacite60783.2024.1126...              2024
# 1157986             https://doi.org/10.1055/s-0044-1791345              2024
# 1157987             https://doi.org/10.3390/quantum1020022              2019
# 1157988    https://doi.org/10.1109/iolts50870.2020.9159750              2020
#
#         language                          field_name_top_topic  \
# 0             en                                      Medicine
# 1             en                                      Medicine
# 2             en                                      Medicine
# 3             en                                      Medicine
# 4             en           Business, Management and Accounting
# ...          ...                                           ...
# 1157984       fr                                            {}
# 1157985      NaN                                            {}
# 1157986       en                                            {}
# 1157987       en                         Physics and Astronomy
# 1157988       en  Biochemistry, Genetics and Molecular Biology
#
#                              journal   journal_id     issn_l  \
# 0         European Journal of Cancer    S16731738  0959-8049
# 1                           Immunity   S199671312  1074-7613
# 2                                NaN           {}        NaN
# 3             European Heart Journal   S181568219  0195-668X
# 4        Digital Access to Libraries  S4306400166        NaN
# ...                              ...          ...        ...
# 1157984                 Jurnal Hukum  S4210234340  1412-2723
# 1157985                          NaN           {}        NaN
# 1157986                          NaN           {}        NaN
# 1157987              Quantum Reports  S4210211996        NaN
# 1157988   arXiv (Cornell University)  S4306400194        NaN
#
#                                               publisher publisher_id  \
# 0                                           Elsevier BV  P4310320990
# 1                                            Cell Press  P4310315673
# 2                                                   NaN           {}
# 3                               Oxford University Press  P4310311648
# 4                          Harris County Public Library  I2800384882
# ...                                                 ...          ...
# 1157984                                             NaN           {}
# 1157985                                             NaN           {}
# 1157986                                             NaN           {}
# 1157987  Multidisciplinary Digital Publishing Institute  P4310310987
# 1157988                              Cornell University   I205783295
#
#                                   display_name_institution  ...  \
# 0        {'National Cancer Registry', 'Piedmont Referen...  ...
# 1        {'Centre de Recherche des Cordeliers', 'Sorbon...  ...
# 2        {'Bicêtre Hospital', 'Université Paris-Sud', '...  ...
# 3        {'University of Milan', 'Pitié-Salpêtrière Hos...  ...
# 4         {'UCLouvain', 'Université Lille Nord de France'}  ...
# ...                                                    ...  ...
# 1157984  {'Universitas Kristen Indonesia Paulus', 'Univ...  ...
# 1157985  {'Uttaranchal University', 'School of Business...  ...
# 1157986           {"École Nationale Vétérinaire d'Alfort"}  ...
# 1157987                               {'Fudan University'}  ...
# 1157988                                              set()  ...
#
#                                                  countries    BSO  \
# 0        [['FR'], ['FR'], ['FR'], ['IT'], ['NL'], ['IE'...   True
# 1        [['FR'], ['FR'], ['FR'], ['FR'], ['DE', 'FR'],...   True
# 2        [['FR'], ['GB'], ['CA'], ['AU'], ['GB'], ['DE'...   True
# 3        [['DK'], ['FR'], ['GB'], ['US'], ['ES'], ['BE'...   True
# 4                           [['BE'], ['BE', 'FR'], ['FR']]   True
# ...                                                    ...    ...
# 1157984                                   [['ID'], ['FR']]  False
# 1157985     [['FR', 'IN'], ['IN'], ['IN'], ['IQ'], ['IN']]  False
# 1157986                                   [['FR'], ['FR']]  False
# 1157987                   [['FR'], ['CN'], ['FR'], ['CN']]   True
# 1157988   [['FR'], ['FR'], ['FR'], ['FR'], [], [], [], []]   True
#
#                                    doi_corr APC list price  \
# 0                10.1016/j.ejca.2012.12.027            NaN
# 1              10.1016/j.immuni.2013.10.003            NaN
# 2                10.1016/j.jacc.2013.10.029            NaN
# 3                  10.1093/eurheartj/eht273            NaN
# 4            10.1016/j.jbusvent.2013.07.003            NaN
# ...                                     ...            ...
# 1157984             10.26532/jh.v40i1.37175            NaN
# 1157985  10.1109/icacite60783.2024.11269084            NaN
# 1157986              10.1055/s-0044-1791345            NaN
# 1157987              10.3390/quantum1020022            NaN
# 1157988     10.1109/iolts50870.2020.9159750            NaN
#
#         APC price after discount Full APC Discount Amount Charged  \
# 0                            NaN      NaN      NaN            NaN
# 1                            NaN      NaN      NaN            NaN
# 2                            NaN      NaN      NaN            NaN
# 3                            NaN      NaN      NaN            NaN
# 4                            NaN      NaN      NaN            NaN
# ...                          ...      ...      ...            ...
# 1157984                      NaN      NaN      NaN            NaN
# 1157985                      NaN      NaN      NaN            NaN
# 1157986                      NaN      NaN      NaN            NaN
# 1157987                      NaN      NaN      NaN            NaN
# 1157988                      NaN      NaN      NaN            NaN
#
#          NationalAgreement Corresponding_author_email_recon
# 0                      NaN                              NaN
# 1                      NaN                              NaN
# 2                      NaN                              NaN
# 3                      NaN                              NaN
# 4                      NaN                              NaN
# ...                    ...                              ...
# 1157984                NaN                              NaN
# 1157985                NaN                              NaN
# 1157986                NaN                              NaN
# 1157987                NaN                              NaN
# 1157988                NaN                              NaN
#
# [1157989 rows x 27 columns]

# %% [markdown]
# ### Add cost hypothesis

# %% [markdown]
# **fixed amount of 1000€**

# %%
df_interest_2['apc_hyp_1'] = df_interest_2.NationalAgreement.fillna(0).apply(lambda x: 1000 if x != 0 else np.nan)
df_interest_2
# Out:
#                                                        doi  publication_year  \
# 0               https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 1             https://doi.org/10.1016/j.immuni.2013.10.003              2013
# 2               https://doi.org/10.1016/j.jacc.2013.10.029              2013
# 3                 https://doi.org/10.1093/eurheartj/eht273              2013
# 4           https://doi.org/10.1016/j.jbusvent.2013.07.003              2013
# ...                                                    ...               ...
# 1157984            https://doi.org/10.26532/jh.v40i1.37175              2024
# 1157985  https://doi.org/10.1109/icacite60783.2024.1126...              2024
# 1157986             https://doi.org/10.1055/s-0044-1791345              2024
# 1157987             https://doi.org/10.3390/quantum1020022              2019
# 1157988    https://doi.org/10.1109/iolts50870.2020.9159750              2020
#
#         language                          field_name_top_topic  \
# 0             en                                      Medicine
# 1             en                                      Medicine
# 2             en                                      Medicine
# 3             en                                      Medicine
# 4             en           Business, Management and Accounting
# ...          ...                                           ...
# 1157984       fr                                            {}
# 1157985      NaN                                            {}
# 1157986       en                                            {}
# 1157987       en                         Physics and Astronomy
# 1157988       en  Biochemistry, Genetics and Molecular Biology
#
#                              journal   journal_id     issn_l  \
# 0         European Journal of Cancer    S16731738  0959-8049
# 1                           Immunity   S199671312  1074-7613
# 2                                NaN           {}        NaN
# 3             European Heart Journal   S181568219  0195-668X
# 4        Digital Access to Libraries  S4306400166        NaN
# ...                              ...          ...        ...
# 1157984                 Jurnal Hukum  S4210234340  1412-2723
# 1157985                          NaN           {}        NaN
# 1157986                          NaN           {}        NaN
# 1157987              Quantum Reports  S4210211996        NaN
# 1157988   arXiv (Cornell University)  S4306400194        NaN
#
#                                               publisher publisher_id  \
# 0                                           Elsevier BV  P4310320990
# 1                                            Cell Press  P4310315673
# 2                                                   NaN           {}
# 3                               Oxford University Press  P4310311648
# 4                          Harris County Public Library  I2800384882
# ...                                                 ...          ...
# 1157984                                             NaN           {}
# 1157985                                             NaN           {}
# 1157986                                             NaN           {}
# 1157987  Multidisciplinary Digital Publishing Institute  P4310310987
# 1157988                              Cornell University   I205783295
#
#                                   display_name_institution  ...    BSO  \
# 0        {'National Cancer Registry', 'Piedmont Referen...  ...   True
# 1        {'Centre de Recherche des Cordeliers', 'Sorbon...  ...   True
# 2        {'Bicêtre Hospital', 'Université Paris-Sud', '...  ...   True
# 3        {'University of Milan', 'Pitié-Salpêtrière Hos...  ...   True
# 4         {'UCLouvain', 'Université Lille Nord de France'}  ...   True
# ...                                                    ...  ...    ...
# 1157984  {'Universitas Kristen Indonesia Paulus', 'Univ...  ...  False
# 1157985  {'Uttaranchal University', 'School of Business...  ...  False
# 1157986           {"École Nationale Vétérinaire d'Alfort"}  ...  False
# 1157987                               {'Fudan University'}  ...   True
# 1157988                                              set()  ...   True
#
#                                    doi_corr APC list price  \
# 0                10.1016/j.ejca.2012.12.027            NaN
# 1              10.1016/j.immuni.2013.10.003            NaN
# 2                10.1016/j.jacc.2013.10.029            NaN
# 3                  10.1093/eurheartj/eht273            NaN
# 4            10.1016/j.jbusvent.2013.07.003            NaN
# ...                                     ...            ...
# 1157984             10.26532/jh.v40i1.37175            NaN
# 1157985  10.1109/icacite60783.2024.11269084            NaN
# 1157986              10.1055/s-0044-1791345            NaN
# 1157987              10.3390/quantum1020022            NaN
# 1157988     10.1109/iolts50870.2020.9159750            NaN
#
#         APC price after discount Full APC Discount Amount Charged  \
# 0                            NaN      NaN      NaN            NaN
# 1                            NaN      NaN      NaN            NaN
# 2                            NaN      NaN      NaN            NaN
# 3                            NaN      NaN      NaN            NaN
# 4                            NaN      NaN      NaN            NaN
# ...                          ...      ...      ...            ...
# 1157984                      NaN      NaN      NaN            NaN
# 1157985                      NaN      NaN      NaN            NaN
# 1157986                      NaN      NaN      NaN            NaN
# 1157987                      NaN      NaN      NaN            NaN
# 1157988                      NaN      NaN      NaN            NaN
#
#         NationalAgreement  Corresponding_author_email_recon apc_hyp_1
# 0                     NaN                               NaN       NaN
# 1                     NaN                               NaN       NaN
# 2                     NaN                               NaN       NaN
# 3                     NaN                               NaN       NaN
# 4                     NaN                               NaN       NaN
# ...                   ...                               ...       ...
# 1157984               NaN                               NaN       NaN
# 1157985               NaN                               NaN       NaN
# 1157986               NaN                               NaN       NaN
# 1157987               NaN                               NaN       NaN
# 1157988               NaN                               NaN       NaN
#
# [1157989 rows x 28 columns]

# %% [markdown]
# **Divided the cost by number of papers**

# %%
def clean_apc(value):
    if pd.isna(value):
        return np.nan
    cleaned = ''.join(filter(str.isdigit, str(value)))
    return int(cleaned) if cleaned else np.nan 

df_filtered = df_interest_2[df_interest_2.NationalAgreement == 'Elsevier']
df_filtered['APC_list_price_clean'] = df_filtered['APC list price'].apply(clean_apc)

total_apc = df_filtered['APC_list_price_clean'].sum()
total_apc_paper  = total_apc / df_filtered.shape[0]
print('Elsevier', total_apc, total_apc_paper)
df_interest_2['apc_hyp_2'] = df_interest_2.NationalAgreement.apply(lambda x: total_apc_paper if x == 'Elsevier' else np.nan)

df_filtered = df_interest_2[df_interest_2.NationalAgreement == 'Wiley']
df_filtered['Full_APC_clean'] = df_filtered['Full APC'].apply(clean_apc)

total_apc = df_filtered['Full_APC_clean'].sum()
total_apc_paper  = total_apc / df_filtered.shape[0]
print('Wiley', total_apc, total_apc_paper)
df_interest_2['apc_hyp_2'] = df_interest_2.NationalAgreement.apply(lambda x: total_apc_paper if x == 'Wiley' else np.nan)
df_interest_2.to_csv('../data/interim/initial_dataset_elsevierwiliey.csv', index = False)
df_interest_2
# Out:
# Elsevier 17271583.0 2779.9103492676645
# Wiley 8183167.0 1392.4054789858772
#                                                        doi  publication_year  \
# 0               https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 1             https://doi.org/10.1016/j.immuni.2013.10.003              2013
# 2               https://doi.org/10.1016/j.jacc.2013.10.029              2013
# 3                 https://doi.org/10.1093/eurheartj/eht273              2013
# 4           https://doi.org/10.1016/j.jbusvent.2013.07.003              2013
# ...                                                    ...               ...
# 1157984            https://doi.org/10.26532/jh.v40i1.37175              2024
# 1157985  https://doi.org/10.1109/icacite60783.2024.1126...              2024
# 1157986             https://doi.org/10.1055/s-0044-1791345              2024
# 1157987             https://doi.org/10.3390/quantum1020022              2019
# 1157988    https://doi.org/10.1109/iolts50870.2020.9159750              2020
#
#         language                          field_name_top_topic  \
# 0             en                                      Medicine
# 1             en                                      Medicine
# 2             en                                      Medicine
# 3             en                                      Medicine
# 4             en           Business, Management and Accounting
# ...          ...                                           ...
# 1157984       fr                                            {}
# 1157985      NaN                                            {}
# 1157986       en                                            {}
# 1157987       en                         Physics and Astronomy
# 1157988       en  Biochemistry, Genetics and Molecular Biology
#
#                              journal   journal_id     issn_l  \
# 0         European Journal of Cancer    S16731738  0959-8049
# 1                           Immunity   S199671312  1074-7613
# 2                                NaN           {}        NaN
# 3             European Heart Journal   S181568219  0195-668X
# 4        Digital Access to Libraries  S4306400166        NaN
# ...                              ...          ...        ...
# 1157984                 Jurnal Hukum  S4210234340  1412-2723
# 1157985                          NaN           {}        NaN
# 1157986                          NaN           {}        NaN
# 1157987              Quantum Reports  S4210211996        NaN
# 1157988   arXiv (Cornell University)  S4306400194        NaN
#
#                                               publisher publisher_id  \
# 0                                           Elsevier BV  P4310320990
# 1                                            Cell Press  P4310315673
# 2                                                   NaN           {}
# 3                               Oxford University Press  P4310311648
# 4                          Harris County Public Library  I2800384882
# ...                                                 ...          ...
# 1157984                                             NaN           {}
# 1157985                                             NaN           {}
# 1157986                                             NaN           {}
# 1157987  Multidisciplinary Digital Publishing Institute  P4310310987
# 1157988                              Cornell University   I205783295
#
#                                   display_name_institution  ...  \
# 0        {'National Cancer Registry', 'Piedmont Referen...  ...
# 1        {'Centre de Recherche des Cordeliers', 'Sorbon...  ...
# 2        {'Bicêtre Hospital', 'Université Paris-Sud', '...  ...
# 3        {'University of Milan', 'Pitié-Salpêtrière Hos...  ...
# 4         {'UCLouvain', 'Université Lille Nord de France'}  ...
# ...                                                    ...  ...
# 1157984  {'Universitas Kristen Indonesia Paulus', 'Univ...  ...
# 1157985  {'Uttaranchal University', 'School of Business...  ...
# 1157986           {"École Nationale Vétérinaire d'Alfort"}  ...
# 1157987                               {'Fudan University'}  ...
# 1157988                                              set()  ...
#
#                                    doi_corr APC list price  \
# 0                10.1016/j.ejca.2012.12.027            NaN
# 1              10.1016/j.immuni.2013.10.003            NaN
# 2                10.1016/j.jacc.2013.10.029            NaN
# 3                  10.1093/eurheartj/eht273            NaN
# 4            10.1016/j.jbusvent.2013.07.003            NaN
# ...                                     ...            ...
# 1157984             10.26532/jh.v40i1.37175            NaN
# 1157985  10.1109/icacite60783.2024.11269084            NaN
# 1157986              10.1055/s-0044-1791345            NaN
# 1157987              10.3390/quantum1020022            NaN
# 1157988     10.1109/iolts50870.2020.9159750            NaN
#
#         APC price after discount Full APC Discount Amount Charged  \
# 0                            NaN      NaN      NaN            NaN
# 1                            NaN      NaN      NaN            NaN
# 2                            NaN      NaN      NaN            NaN
# 3                            NaN      NaN      NaN            NaN
# 4                            NaN      NaN      NaN            NaN
# ...                          ...      ...      ...            ...
# 1157984                      NaN      NaN      NaN            NaN
# 1157985                      NaN      NaN      NaN            NaN
# 1157986                      NaN      NaN      NaN            NaN
# 1157987                      NaN      NaN      NaN            NaN
# 1157988                      NaN      NaN      NaN            NaN
#
#         NationalAgreement Corresponding_author_email_recon  apc_hyp_1  \
# 0                     NaN                              NaN        NaN
# 1                     NaN                              NaN        NaN
# 2                     NaN                              NaN        NaN
# 3                     NaN                              NaN        NaN
# 4                     NaN                              NaN        NaN
# ...                   ...                              ...        ...
# 1157984               NaN                              NaN        NaN
# 1157985               NaN                              NaN        NaN
# 1157986               NaN                              NaN        NaN
# 1157987               NaN                              NaN        NaN
# 1157988               NaN                              NaN        NaN
#
#         apc_hyp_2
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 1157984       NaN
# 1157985       NaN
# 1157986       NaN
# 1157987       NaN
# 1157988       NaN
#
# [1157989 rows x 29 columns]

# %% [markdown]
# ## Integrate Open Apc

# %%
interest_cols = ['doi', 'euro', 'issn_l', 'period']
df_open_apc = pd.read_csv('../data/external/apc_de.csv')[interest_cols]

df_interest = pd.read_csv('../data/interim/initial_dataset_elsevierwiliey.csv')

df_tmp = df_interest.merge(df_open_apc.rename(columns={'doi': 'doi_apc'}), left_on = 'doi_corr', right_on = 'doi_apc', how = 'left')
df_tmp = df_tmp.drop(columns=['doi_apc', 'period']).rename(columns={'doi_x': 'doi'})

valid_issns = df_tmp['issn_l_y'].dropna().unique()
median_apc = (df_open_apc[df_open_apc['issn_l'].isin(valid_issns)].groupby(['issn_l', 'period'])['euro'].median())
counts = (df_open_apc[df_open_apc['issn_l'].isin(df_tmp['issn_l_y'].dropna().unique())].groupby(['issn_l', 'period'])['euro'].count())

df_tmp['median'] = pd.Series(list(zip(df_tmp['issn_l_x'], df_tmp['publication_year']))).map(median_apc)
df_tmp = df_tmp.drop(columns=['issn_l_y']).rename(columns={'issn_l_x': 'issn_l'})
print(df_tmp.query('apc_paid.notna() and median.notna()')['doi'].nunique())
df_tmp.to_csv('../data/interim/initial_dataset_elsevierwiliey_openapc.csv', index = False)
df_tmp
# Out:
# 129116
#                                                        doi  publication_year  \
# 0               https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 1             https://doi.org/10.1016/j.immuni.2013.10.003              2013
# 2               https://doi.org/10.1016/j.jacc.2013.10.029              2013
# 3                 https://doi.org/10.1093/eurheartj/eht273              2013
# 4           https://doi.org/10.1016/j.jbusvent.2013.07.003              2013
# ...                                                    ...               ...
# 1157984            https://doi.org/10.26532/jh.v40i1.37175              2024
# 1157985  https://doi.org/10.1109/icacite60783.2024.1126...              2024
# 1157986             https://doi.org/10.1055/s-0044-1791345              2024
# 1157987             https://doi.org/10.3390/quantum1020022              2019
# 1157988    https://doi.org/10.1109/iolts50870.2020.9159750              2020
#
#         language                          field_name_top_topic  \
# 0             en                                      Medicine
# 1             en                                      Medicine
# 2             en                                      Medicine
# 3             en                                      Medicine
# 4             en           Business, Management and Accounting
# ...          ...                                           ...
# 1157984       fr                                            {}
# 1157985      NaN                                            {}
# 1157986       en                                            {}
# 1157987       en                         Physics and Astronomy
# 1157988       en  Biochemistry, Genetics and Molecular Biology
#
#                              journal   journal_id     issn_l  \
# 0         European Journal of Cancer    S16731738  0959-8049
# 1                           Immunity   S199671312  1074-7613
# 2                                NaN           {}        NaN
# 3             European Heart Journal   S181568219  0195-668X
# 4        Digital Access to Libraries  S4306400166        NaN
# ...                              ...          ...        ...
# 1157984                 Jurnal Hukum  S4210234340  1412-2723
# 1157985                          NaN           {}        NaN
# 1157986                          NaN           {}        NaN
# 1157987              Quantum Reports  S4210211996        NaN
# 1157988   arXiv (Cornell University)  S4306400194        NaN
#
#                                               publisher publisher_id  \
# 0                                           Elsevier BV  P4310320990
# 1                                            Cell Press  P4310315673
# 2                                                   NaN           {}
# 3                               Oxford University Press  P4310311648
# 4                          Harris County Public Library  I2800384882
# ...                                                 ...          ...
# 1157984                                             NaN           {}
# 1157985                                             NaN           {}
# 1157986                                             NaN           {}
# 1157987  Multidisciplinary Digital Publishing Institute  P4310310987
# 1157988                              Cornell University   I205783295
#
#                                   display_name_institution  ...  \
# 0        {'National Cancer Registry', 'Piedmont Referen...  ...
# 1        {'Centre de Recherche des Cordeliers', 'Sorbon...  ...
# 2        {'Bicêtre Hospital', 'Université Paris-Sud', '...  ...
# 3        {'University of Milan', 'Pitié-Salpêtrière Hos...  ...
# 4         {'UCLouvain', 'Université Lille Nord de France'}  ...
# ...                                                    ...  ...
# 1157984  {'Universitas Kristen Indonesia Paulus', 'Univ...  ...
# 1157985  {'Uttaranchal University', 'School of Business...  ...
# 1157986           {"École Nationale Vétérinaire d'Alfort"}  ...
# 1157987                               {'Fudan University'}  ...
# 1157988                                              set()  ...
#
#         APC price after discount Full APC Discount Amount Charged  \
# 0                            NaN      NaN      NaN            NaN
# 1                            NaN      NaN      NaN            NaN
# 2                            NaN      NaN      NaN            NaN
# 3                            NaN      NaN      NaN            NaN
# 4                            NaN      NaN      NaN            NaN
# ...                          ...      ...      ...            ...
# 1157984                      NaN      NaN      NaN            NaN
# 1157985                      NaN      NaN      NaN            NaN
# 1157986                      NaN      NaN      NaN            NaN
# 1157987                      NaN      NaN      NaN            NaN
# 1157988                      NaN      NaN      NaN            NaN
#
#         NationalAgreement Corresponding_author_email_recon apc_hyp_1  \
# 0                     NaN                              NaN       NaN
# 1                     NaN                              NaN       NaN
# 2                     NaN                              NaN       NaN
# 3                     NaN                              NaN       NaN
# 4                     NaN                              NaN       NaN
# ...                   ...                              ...       ...
# 1157984               NaN                              NaN       NaN
# 1157985               NaN                              NaN       NaN
# 1157986               NaN                              NaN       NaN
# 1157987               NaN                              NaN       NaN
# 1157988               NaN                              NaN       NaN
#
#         apc_hyp_2  euro   median
# 0             NaN   NaN  2676.26
# 1             NaN   NaN  4487.84
# 2             NaN   NaN      NaN
# 3             NaN   NaN      NaN
# 4             NaN   NaN      NaN
# ...           ...   ...      ...
# 1157984       NaN   NaN      NaN
# 1157985       NaN   NaN      NaN
# 1157986       NaN   NaN      NaN
# 1157987       NaN   NaN      NaN
# 1157988       NaN   NaN      NaN
#
# [1157989 rows x 31 columns]

# %%
threshold = 5 
counts_filtered = counts[counts > threshold]

len(counts_filtered) / len(counts)
# Out:
# 0.3026795185168104
