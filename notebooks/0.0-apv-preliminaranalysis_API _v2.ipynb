# %% [markdown]
# # Preliminar Analysis

# %%
import requests
import time
import json
from urllib.parse import urlencode
import pandas as pd
import orjson
from tqdm import tqdm

# %% [markdown]
# ### Download all articles where there are one or more french authors

# %%
BASE_URL = "https://api.openalex.org/works"

selected_fields = ["doi", "is_xpac", "publication_year", "language", "indexed_in", "primary_location", "open_access", "authorships", "institutions", 
                   "corresponding_author_ids", "corresponding_institution_ids", "apc_list", "apc_paid", "cited_by_count", "primary_topic", "topics", 
                   "concepts", "grants", "awards", "funders"]

def fetch_page(cursor, filters):
    params = filters.copy()
    params["cursor"] = cursor
    params["per_page"] = 200
    url = f"{BASE_URL}?{urlencode(params)}"
    r = requests.get(url, timeout=30)
    r.raise_for_status()
    return r.json()

for year in range(2013, 2014): # anar modificant l'initial year
    print(f"\n=== YEAR {year} ===")

    filters = {
        "filter": ",".join([
            "type:article",
            "primary_location.source.type:journal",
            "authorships.institutions.country_code:FR",
            f"from_publication_date:{year}-01-01",
            f"to_publication_date:{year}-12-31"
        ]),
        "select": ",".join(selected_fields)
    }

    cursor = "*"
    count = 0
    output_file = f"../data/interim/FranceInitialAPI/openalex_french_authors_{year}_v2.jsonl"

    with open(output_file, "w", encoding="utf-8") as f:
        pbar = tqdm(unit="works", dynamic_ncols=True)
        while True:
            data = fetch_page(cursor, filters)

            works = data.get("results", [])
            next_cursor = data.get("meta", {}).get("next_cursor", None)

            for w in works:
                f.write(json.dumps(w) + "\n")
                count += 1

            pbar.update(len(works))
            
            if not next_cursor:
                break
            cursor = next_cursor
            time.sleep(1)

        pbar.close()
    print(f"\nSaved: {output_file}  (total {count})")

print("\n=== COMPLETED ===")
# Out:
# === YEAR 2013 ===
# 107221works [23:40, 75.46works/s]
# Saved: ../data/interim/FranceInitialAPI/openalex_french_authors_2013_v2.jsonl  (total 107221)
#
# === COMPLETED ===

# %% [markdown]
# ### Phase 1: Whole France

# %% [markdown]
# **Number of unique DOI in France (NON Datacite)**

# %%
unique_doi_france = 0
for year in tqdm(range(2013, 2025)):
    doi_set_france = set()
    with open(f"../data/interim/FranceInitialAPI/openalex_french_authors_{year}_v2.jsonl", "rb") as f:
        for line in f:
            rec = orjson.loads(line)
            doi = rec.get("doi")
            if doi:
                doi_set_france.add(doi)
    unique_doi_france += len(doi_set_france)

print("Total unique DOIs:", unique_doi_france)
# Out:
# 100%|██████████| 12/12 [01:06<00:00,  5.54s/it]
# Total unique DOIs: 1243928

# %% [markdown]
# **Number of unique DOI in France (ONLY Datacite) + dataset construction**

# %%
### I SHOULD REDO THE DOWNLOAD; ASK IF NEEDED GIVEN THAT WE WON'T USE IT

# %% [markdown]
# ### Phase 2: Ingest, or not, BSO

# %%
df_bso = pd.read_parquet("../data/external/open-access-monitor-france.parquet", engine = "pyarrow").dropna(subset = ["doi"])
df_bso
# Out:
#        observation_date                                    id  \
# 0                2024Q4      doi10.1080/10408398.2022.2033684
# 1                2024Q4          doi10.1016/j.gie.2021.12.048
# 2                2024Q4  doi10.1016/j.compositesa.2022.107165
# 3                2024Q4             doi10.1002/ejoc.202200123
# 4                2024Q4      doi10.3410/f.721705664.793594159
# ...                 ...                                   ...
# 937570           2024Q4           doi10.1021/acs.jpcc.9b10824
# 937571           2024Q4          doi10.1017/s007543582000012x
# 937575           2024Q4             doi10.1075/aila.00030.haa
# 937576           2024Q4         doi10.1007/s13592-020-00743-8
# 937577           2024Q4         doi10.1007/s10844-020-00608-7
#
#                                       doi      pmid  \
# 0           10.1080/10408398.2022.2033684  35152807
# 1               10.1016/j.gie.2021.12.048      None
# 2       10.1016/j.compositesa.2022.107165      None
# 3                  10.1002/ejoc.202200123      None
# 4           10.3410/f.721705664.793594159      None
# ...                                   ...       ...
# 937570           10.1021/acs.jpcc.9b10824      None
# 937571          10.1017/s007543582000012x      None
# 937575             10.1075/aila.00030.haa      None
# 937576         10.1007/s13592-020-00743-8      None
# 937577         10.1007/s10844-020-00608-7      None
#
#                                            hal_id  year  \
# 0                                    hal-03777046  2022
# 1                                            None  2022
# 2       Preprint-Carpier-et-al-CompPartA-2022.pdf  2022
# 3                                TEXT%20FINAL.pdf  2022
# 4                                            None  2022
# ...                                           ...   ...
# 937570                               hal-03017908  2020
# 937571                                       None  2020
# 937575                                       None  2020
# 937576                               hal-03161695  2020
# 937577                             manuscript.pdf  2020
#
#                                                     title  \
# 0       The impact of nano/micro-plastics toxicity on ...
# 1       Real-time use of artificial intelligence at co...
# 2       Meso-structure-based thermomechanical modellin...
# 3       Electrochemical Trifluoromethylselenolation of...
# 4       Faculty Opinions recommendation of On the gene...
# ...                                                   ...
# 937570  The Dissolution Anisotropy of Pyroxenes: Exper...
# 937571  LAUREL FULKERSON, A LITERARY COMMENTARY ON THE...
# 937575              Recycling a genre for news automation
# 937576  Short-term hyperthermia at larval age reduces ...
# 937577  On data lake architectures and metadata manage...
#
#                         journal_issns journal_issn_l  \
# 0                 1040-8398,1549-7852      1040-8398
# 1       0016-5107,1085-8741,1097-6779      0016-5107
# 2                 1359-835X,1878-5840      1359-835X
# 3                 1099-0690,1434-193X      1099-0690
# 4                                None           None
# ...                               ...            ...
# 937570            1932-7447,1932-7455      1932-7447
# 937571            0075-4358,1753-528X      0075-4358
# 937575            1461-0213,1570-5595      1461-0213
# 937576            0044-8435,1297-9678      0044-8435
# 937577            0925-9902,1573-7675      0925-9902
#
#                                              journal_name  ... software_used  \
# 0          Critical Reviews in Food Science and Nutrition  ...          None
# 1                              Gastrointestinal Endoscopy  ...          None
# 2       Composites Part A Applied Science and Manufact...  ...          True
# 3                   European Journal of Organic Chemistry  ...         False
# 4       Faculty Opinions – Post-Publication Peer Revie...  ...          None
# ...                                                   ...  ...           ...
# 937570                The Journal of Physical Chemistry C  ...         False
# 937571                       The Journal of Roman Studies  ...          None
# 937575                                        AILA Review  ...          None
# 937576                                         Apidologie  ...          None
# 937577         Journal of Intelligent Information Systems  ...          True
#
#        software_created software_shared data_used data_created  data_shared  \
# 0                  None            None      None         None         None
# 1                  None            None      None         None         None
# 2                 False           False      True         True        False
# 3                 False           False      True        False        False
# 4                  None            None      None         None         None
# ...                 ...             ...       ...          ...          ...
# 937570            False           False      True         True        False
# 937571             None            None      None         None         None
# 937575             None            None      None         None         None
# 937576             None            None      None         None         None
# 937577             True           False      True         True        False
#
#        missing_doi_in_hal has_doi_in_hal                         doi_in_hal  \
# 0                     NaN              1      10.1080/10408398.2022.2033684
# 1                     NaN           None                               None
# 2                     NaN              1  10.1016/j.compositesa.2022.107165
# 3                     NaN              1             10.1002/ejoc.202200123
# 4                     NaN           None                               None
# ...                   ...            ...                                ...
# 937570                NaN              1           10.1021/acs.jpcc.9b10824
# 937571                NaN           None                               None
# 937575                NaN           None                               None
# 937576                NaN              1         10.1007/s13592-020-00743-8
# 937577                NaN              1         10.1007/s10844-020-00608-7
#
#        bso_country
# 0               fr
# 1             None
# 2         fr,other
# 3         fr,other
# 4               fr
# ...            ...
# 937570    fr,other
# 937571          fr
# 937575      europe
# 937576       other
# 937577    fr,other
#
# [611769 rows x 46 columns]

# %%
df['doi_clean'] = df['doi'].apply(lambda x: x[16::])
df_bso_article = df_bso[(df_bso.genre == "journal-article") | (df_bso.genre == "proceedings")]
df_bso_not_in_oa = df_bso_article[~df_bso_article["doi"].isin(df.doi_clean.unique())].reset_index(drop = True)
df_bso_not_in_oa.to_parquet("../data/interim/bso_article_notoa.parquet", engine = "pyarrow")
df_bso_not_in_oa
# Out:
#        observation_date                                                 id  \
# 0                2024Q4                   doi10.1080/10408398.2022.2033684
# 1                2024Q4                       doi10.1016/j.gie.2021.12.048
# 2                2024Q4                     doi10.1016/j.jscai.2022.100218
# 3                2024Q4             doi10.1136/bmjebm-2022-podabstracts.81
# 4                2024Q4                         doi10.1145/3490148.3538552
# ...                 ...                                                ...
# 206370           2024Q4                 doi10.1016/j.scitotenv.2020.137673
# 206371           2024Q4  doi10.1164/ajrccm-conference.2020.201.1_meetin...
# 206372           2024Q4                              doi10.1111/ajco.13497
# 206373           2024Q4                          doi10.1075/aila.00030.haa
# 206374           2024Q4                      doi10.1007/s13592-020-00743-8
#
#                                                       doi      pmid  \
# 0                           10.1080/10408398.2022.2033684  35152807
# 1                               10.1016/j.gie.2021.12.048      None
# 2                             10.1016/j.jscai.2022.100218      None
# 3                     10.1136/bmjebm-2022-podabstracts.81      None
# 4                                 10.1145/3490148.3538552      None
# ...                                                   ...       ...
# 206370                    10.1016/j.scitotenv.2020.137673  32208236
# 206371  10.1164/ajrccm-conference.2020.201.1_meetingab...      None
# 206372                                 10.1111/ajco.13497      None
# 206373                             10.1075/aila.00030.haa      None
# 206374                         10.1007/s13592-020-00743-8      None
#
#                hal_id  year  \
# 0        hal-03777046  2022
# 1                None  2022
# 2                None  2022
# 3       jrsm.1413.pdf  2022
# 4        hal-03950351  2022
# ...               ...   ...
# 206370   hal-03143548  2020
# 206371           None  2020
# 206372           None  2020
# 206373           None  2020
# 206374   hal-03161695  2020
#
#                                                     title  \
# 0       The impact of nano/micro-plastics toxicity on ...
# 1       Real-time use of artificial intelligence at co...
# 2       D-10 , Procedural Characteristics of Patients ...
# 3       160 Visualizing the evolution of evidence: cum...
# 4                                      Brief Announcement
# ...                                                   ...
# 206370  Towards a spatiotemporally explicit toxicokine...
# 206371  The Polyvalent Role of Mandibular Movement Sig...
# 206372                                     Oral Abstracts
# 206373              Recycling a genre for news automation
# 206374  Short-term hyperthermia at larval age reduces ...
#
#                         journal_issns journal_issn_l  \
# 0                 1040-8398,1549-7852      1040-8398
# 1       0016-5107,1085-8741,1097-6779      0016-5107
# 2                           2772-9303      2772-9303
# 3                                None           None
# 4                                None           None
# ...                               ...            ...
# 206370            0048-9697,1879-1026      0048-9697
# 206371                           None           None
# 206372            1743-7555,1743-7563      1743-7555
# 206373            1461-0213,1570-5595      1461-0213
# 206374            0044-8435,1297-9678      0044-8435
#
#                                              journal_name  ... software_used  \
# 0          Critical Reviews in Food Science and Nutrition  ...          None
# 1                              Gastrointestinal Endoscopy  ...          None
# 2       Journal of the Society for Cardiovascular Angi...  ...          None
# 3                                    DS scholar abstracts  ...          True
# 4       Proceedings of the 34th ACM Symposium on Paral...  ...         False
# ...                                                   ...  ...           ...
# 206370               The Science of The Total Environment  ...         False
# 206371  C109. SRN: INNOVATIVE WAYS TO ASSESS SDB AND P...  ...         False
# 206372          Asia-Pacific Journal of Clinical Oncology  ...         False
# 206373                                        AILA Review  ...          None
# 206374                                         Apidologie  ...          None
#
#        software_created software_shared data_used data_created  data_shared  \
# 0                  None            None      None         None         None
# 1                  None            None      None         None         None
# 2                  None            None      None         None         None
# 3                  True            True      True         True         True
# 4                 False           False      True        False        False
# ...                 ...             ...       ...          ...          ...
# 206370            False           False      True         True        False
# 206371            False           False     False        False        False
# 206372            False           False      True         True        False
# 206373             None            None      None         None         None
# 206374             None            None      None         None         None
#
#        missing_doi_in_hal has_doi_in_hal                       doi_in_hal  \
# 0                     NaN              1    10.1080/10408398.2022.2033684
# 1                     NaN           None                             None
# 2                     NaN           None                             None
# 3                     1.0           None                             None
# 4                     NaN              1          10.1145/3490148.3538552
# ...                   ...            ...                              ...
# 206370                NaN              1  10.1016/j.scitotenv.2020.137673
# 206371                NaN           None                             None
# 206372                NaN           None                             None
# 206373                NaN           None                             None
# 206374                NaN              1       10.1007/s13592-020-00743-8
#
#        bso_country
# 0               fr
# 1             None
# 2             None
# 3         fr,other
# 4         fr,other
# ...            ...
# 206370    fr,other
# 206371    fr,other
# 206372    other,fr
# 206373      europe
# 206374       other
#
# [206375 rows x 46 columns]

# %%
### WAITING FOR THE RESPONSE OF THE TECHNICAL TEAM

# %% [markdown]
# ### Phase 3: Corresponding

# %%
interest = ['doi', 'publication_year', 'language', 'authorships', 'primary_location', 'topics', 'open_access', 'apc_list']
keys = ['doi', 'publication_year', 'language', 'field_names', 'journal', 'publisher', 'ins_type', '#_authors', 'oa_status', 'apc_list', 'corresponding', 'countries']
records = []
for year in tqdm(range(2013, 2025)):
    with open(f"../data/interim/FranceInitialAPI/openalex_french_authors_{year}_v2.jsonl", "rb") as f:
        for line in f:
            rec = orjson.loads(line)
            if not rec.get("doi"): # Skip records without DOI
                continue
            filtered = {k: rec.get(k) for k in interest} # Keep only the fields we care about

            # Extract field_names from topics
            topics = filtered.get("topics") or []
            filtered["field_names"] = {c.get("field", {}).get("display_name") for c in topics if c.get("field")}

            # Extract journal and publisher from primary_location
            pl = filtered.get("primary_location") or {}
            source = pl.get("source") or {}
            filtered["journal"] = source.get("display_name")
            filtered["publisher"] = source.get("host_organization_name")

            # Extract institution types and number of authors
            authorships = filtered.get("authorships") or []
            filtered["ins_type"] = {inst.get("type") 
                                    for auth in authorships 
                                    for inst in auth.get("institutions", []) if inst.get("type")}
            filtered["corresponding"] = [auth.get("is_corresponding") for auth in authorships]
            filtered["countries"] = [auth.get("countries") for auth in authorships]
            filtered["#_authors"] = len(authorships)
            
            o_a = filtered.get("open_access") or {}
            filtered["oa_status"] = o_a.get("oa_status")

            records.append({k: filtered.get(k) for k in keys})

df = pd.DataFrame(records)
df
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [01:48<00:00,  9.02s/it]
#                                                        doi  publication_year  \
# 0              https://doi.org/10.1051/0004-6361/201322068              2013
# 1                      https://doi.org/10.1038/nature12477              2013
# 2             https://doi.org/10.1097/ccm.0b013e31827e83af              2013
# 3                https://doi.org/10.1007/s00134-012-2769-8              2013
# 4                    https://doi.org/10.1038/nnano.2013.46              2013
# ...                                                    ...               ...
# 1349313  https://doi.org/10.20914/2310-1202-2024-4-178-184              2024
# 1349314                  https://doi.org/10.7202/1121520ar              2024
# 1349315                  https://doi.org/10.7202/1121518ar              2024
# 1349316                      https://doi.org/10.4000/11ndt              2024
# 1349317                       https://doi.org/10.2427/5975              2024
#
#         language                                        field_names  \
# 0             en          {Physics and Astronomy, Computer Science}
# 1             en  {Biochemistry, Genetics and Molecular Biology,...
# 2             en                                         {Medicine}
# 3             en                                         {Medicine}
# 4             en                                {Materials Science}
# ...          ...                                                ...
# 1349313     None  {Environmental Science, Agricultural and Biolo...
# 1349314       fr             {Arts and Humanities, Social Sciences}
# 1349315       fr                                  {Social Sciences}
# 1349316       fr                                  {Social Sciences}
# 1349317       en  {Health Professions, Economics, Econometrics a...
#
#                                                    journal  \
# 0                               Astronomy and Astrophysics
# 1                                                   Nature
# 2                                   Critical Care Medicine
# 3                                  Intensive Care Medicine
# 4                                    Nature Nanotechnology
# ...                                                    ...
# 1349313  Proceedings of the Voronezh State University o...
# 1349314           Revue d histoire de l Amérique française
# 1349315           Revue d histoire de l Amérique française
# 1349316                                 Histoire Politique
# 1349317                   Italian Journal of Public Health
#
#                                                  publisher  \
# 0                                             EDP Sciences
# 1                                         Nature Portfolio
# 2                            Lippincott Williams & Wilkins
# 3                          Springer Science+Business Media
# 4                                         Nature Portfolio
# ...                                                    ...
# 1349313  Voronezh State University of Engineering Techn...
# 1349314        Institut d'histoire de l'Amérique française
# 1349315        Institut d'histoire de l'Amérique française
# 1349316                                               None
# 1349317                                           Prex spa
#
#                                                   ins_type  #_authors  \
# 0             {facility, government, education, nonprofit}         44
# 1        {facility, nonprofit, other, healthcare, gover...         70
# 2                         {healthcare, company, education}         23
# 3                                  {healthcare, education}         23
# 4                                               {facility}          2
# ...                                                    ...        ...
# 1349313                              {facility, education}          5
# 1349314                                        {education}          1
# 1349315                                        {education}          1
# 1349316                                         {facility}          1
# 1349317                                       {government}          1
#
#         oa_status                                           apc_list  \
# 0          bronze                                               None
# 1          bronze  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 2          closed                                               None
# 3          bronze  {'value': 3690, 'currency': 'EUR', 'value_usd'...
# 4           green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# ...           ...                                                ...
# 1349313   diamond                                               None
# 1349314   diamond                                               None
# 1349315   diamond                                               None
# 1349316    bronze                                               None
# 1349317    hybrid                                               None
#
#                                              corresponding  \
# 0        [False, False, False, False, False, False, Fal...
# 1        [False, False, False, False, False, False, Fal...
# 2        [False, False, False, False, False, False, Fal...
# 3        [True, False, False, False, False, False, Fals...
# 4                                           [False, False]
# ...                                                    ...
# 1349313                 [True, False, False, False, False]
# 1349314                                             [True]
# 1349315                                             [True]
# 1349316                                             [True]
# 1349317                                             [True]
#
#                                                  countries
# 0        [[DE], [US], [FR, US], [FR, US], [FR, US], [US...
# 1        [[GB], [GB], [GB], [CA], [GB], [GB], [GB], [GB...
# 2        [[US], [US], [GB], [FR], [DE], [US], [US], [IL...
# 3        [[US], [US], [GB], [FR], [DE], [US], [US], [IL...
# 4                                               [[], [FR]]
# ...                                                    ...
# 1349313                     [[RU], [RU], [FR], [RU], [RU]]
# 1349314                                             [[FR]]
# 1349315                                             [[FR]]
# 1349316                                             [[FR]]
# 1349317                                             [[FR]]
#
# [1349318 rows x 12 columns]

# %% [markdown]
# **No corresponding**

# %%
df_nocorresponding = df[df['corresponding'].apply(lambda x: all(v is False for v in x))].reset_index(drop = True)
df_nocorresponding
# Out:
#                                                  doi  publication_year  \
# 0        https://doi.org/10.1051/0004-6361/201322068              2013
# 1                https://doi.org/10.1038/nature12477              2013
# 2       https://doi.org/10.1097/ccm.0b013e31827e83af              2013
# 3              https://doi.org/10.1038/nnano.2013.46              2013
# 4                https://doi.org/10.1093/nar/gkt1178              2013
# ...                                              ...               ...
# 683493             https://doi.org/10.7202/1120388ar              2024
# 683494             https://doi.org/10.7202/1120383ar              2024
# 683495             https://doi.org/10.7202/1120375ar              2024
# 683496             https://doi.org/10.7202/1120374ar              2024
# 683497     https://doi.org/10.1017/s0021875825000179              2024
#
#        language                                        field_names  \
# 0            en          {Physics and Astronomy, Computer Science}
# 1            en  {Biochemistry, Genetics and Molecular Biology,...
# 2            en                                         {Medicine}
# 3            en                                {Materials Science}
# 4            en  {Engineering, Biochemistry, Genetics and Molec...
# ...         ...                                                ...
# 683493       fr                                                 {}
# 683494       fr                                                 {}
# 683495       fr                                                 {}
# 683496       fr                                                 {}
# 683497       en                                                 {}
#
#                             journal                      publisher  \
# 0        Astronomy and Astrophysics                   EDP Sciences
# 1                            Nature               Nature Portfolio
# 2            Critical Care Medicine  Lippincott Williams & Wilkins
# 3             Nature Nanotechnology               Nature Portfolio
# 4            Nucleic Acids Research        Oxford University Press
# ...                             ...                            ...
# 683493         Études/Inuit/Studies                     Q114618608
# 683494         Études/Inuit/Studies                     Q114618608
# 683495         Études/Inuit/Studies                     Q114618608
# 683496         Études/Inuit/Studies                     Q114618608
# 683497  Journal of American Studies     Cambridge University Press
#
#                                                  ins_type  #_authors  \
# 0            {education, facility, nonprofit, government}         44
# 1       {education, facility, healthcare, government, ...         70
# 2                        {company, education, healthcare}         23
# 3                                              {facility}          2
# 4                                            {government}          5
# ...                                                   ...        ...
# 683493                              {education, facility}          2
# 683494                              {education, facility}          3
# 683495                              {education, facility}          3
# 683496                              {education, facility}          3
# 683497                                        {education}          6
#
#        oa_status                                           apc_list  \
# 0         bronze                                               None
# 1         bronze  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 2         closed                                               None
# 3          green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 4           gold  {'value': 3630, 'currency': 'USD', 'value_usd'...
# ...          ...                                                ...
# 683493   diamond                                               None
# 683494   diamond                                               None
# 683495   diamond                                               None
# 683496   diamond                                               None
# 683497    closed                                               None
#
#                                             corresponding  \
# 0       [False, False, False, False, False, False, Fal...
# 1       [False, False, False, False, False, False, Fal...
# 2       [False, False, False, False, False, False, Fal...
# 3                                          [False, False]
# 4                     [False, False, False, False, False]
# ...                                                   ...
# 683493                                     [False, False]
# 683494                              [False, False, False]
# 683495                              [False, False, False]
# 683496                              [False, False, False]
# 683497         [False, False, False, False, False, False]
#
#                                                 countries
# 0       [[DE], [US], [FR, US], [FR, US], [FR, US], [US...
# 1       [[GB], [GB], [GB], [CA], [GB], [GB], [GB], [GB...
# 2       [[US], [US], [GB], [FR], [DE], [US], [US], [IL...
# 3                                              [[], [FR]]
# 4                          [[FR], [FR], [FR], [FR], [FR]]
# ...                                                   ...
# 683493                                         [[], [FR]]
# 683494                               [[], [CA, FR], [CA]]
# 683495                               [[], [CA, FR], [CA]]
# 683496                               [[], [CA, FR], [CA]]
# 683497                 [[GB], [], [FR], [FR], [FR], [FR]]
#
# [683498 rows x 12 columns]

# %% [markdown]
# Single author

# %%
df_nocorresponding_one = df_nocorresponding[df_nocorresponding['#_authors'] == 1].reset_index(drop = True)
df_nocorresponding_one
# Out:
# Empty DataFrame
# Columns: [doi, publication_year, language, field_names, journal, publisher, ins_type, #_authors, oa_status, apc_list, corresponding, countries]
# Index: []

# %% [markdown]
# French language

# %%
df_nocorresponding_french = df_nocorresponding[df_nocorresponding.language == 'fr'].reset_index(drop = True)
df_nocorresponding_french.to_parquet("../data/interim/preliminary/fr_p4B_french_language.parquet", index = False)
df_nocorresponding_french.groupby('publication_year').count()[['doi']]
# Out:
#                     doi
# publication_year
# 2013              10172
# 2014              11715
# 2015               7002
# 2016               5159
# 2017               5181
# 2018               6029
# 2019               5645
# 2020               6021
# 2021               5866
# 2022               6540
# 2023               5204
# 2024               4052

# %% [markdown]
# All missing

# %%
df_nocorresponding['missing'] = df_nocorresponding.countries.apply(lambda lst: all(len(x) == 0 for x in lst))
df_nocorresponding_missing = df_nocorresponding[df_nocorresponding['missing'] == True].reset_index(drop = True)
df_nocorresponding_missing
# Out:
# Empty DataFrame
# Columns: [doi, publication_year, language, field_names, journal, publisher, ins_type, #_authors, oa_status, apc_list, corresponding, countries, missing]
# Index: []

# %% [markdown]
# **Corresponding**

# %%
df_corresponding = df[~df.doi.isin(df_nocorresponding.doi)].reset_index(drop = True)
df_corresponding
# Out:
#                                                       doi  publication_year  \
# 0               https://doi.org/10.1007/s00134-012-2769-8              2013
# 1              https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 2           https://doi.org/10.1016/s1474-4422(13)70124-8              2013
# 3                     https://doi.org/10.1038/nature12506              2013
# 4            https://doi.org/10.1016/j.immuni.2013.10.003              2013
# ...                                                   ...               ...
# 665813  https://doi.org/10.20914/2310-1202-2024-4-178-184              2024
# 665814                  https://doi.org/10.7202/1121520ar              2024
# 665815                  https://doi.org/10.7202/1121518ar              2024
# 665816                      https://doi.org/10.4000/11ndt              2024
# 665817                       https://doi.org/10.2427/5975              2024
#
#        language                                        field_names  \
# 0            en                                         {Medicine}
# 1            en                                         {Medicine}
# 2            en                                         {Medicine}
# 3            en  {Biochemistry, Genetics and Molecular Biology,...
# 4            en            {Immunology and Microbiology, Medicine}
# ...         ...                                                ...
# 665813     None  {Environmental Science, Agricultural and Biolo...
# 665814       fr             {Arts and Humanities, Social Sciences}
# 665815       fr                                  {Social Sciences}
# 665816       fr                                  {Social Sciences}
# 665817       en  {Health Professions, Economics, Econometrics a...
#
#                                                   journal  \
# 0                                 Intensive Care Medicine
# 1                              European Journal of Cancer
# 2                                    The Lancet Neurology
# 3                                                  Nature
# 4                                                Immunity
# ...                                                   ...
# 665813  Proceedings of the Voronezh State University o...
# 665814           Revue d histoire de l Amérique française
# 665815           Revue d histoire de l Amérique française
# 665816                                 Histoire Politique
# 665817                   Italian Journal of Public Health
#
#                                                 publisher  \
# 0                         Springer Science+Business Media
# 1                                             Elsevier BV
# 2                                             Elsevier BV
# 3                                        Nature Portfolio
# 4                                              Cell Press
# ...                                                   ...
# 665813  Voronezh State University of Engineering Techn...
# 665814        Institut d'histoire de l'Amérique française
# 665815        Institut d'histoire de l'Amérique française
# 665816                                               None
# 665817                                           Prex spa
#
#                                                  ins_type  #_authors  \
# 0                                 {education, healthcare}         23
# 1              {education, other, government, healthcare}          8
# 2           {education, facility, government, healthcare}         36
# 3       {education, facility, healthcare, government, ...         82
# 4           {education, facility, government, healthcare}         17
# ...                                                   ...        ...
# 665813                              {education, facility}          5
# 665814                                        {education}          1
# 665815                                        {education}          1
# 665816                                         {facility}          1
# 665817                                       {government}          1
#
#        oa_status                                           apc_list  \
# 0         bronze  {'value': 3690, 'currency': 'EUR', 'value_usd'...
# 1         bronze  {'value': 3800, 'currency': 'USD', 'value_usd'...
# 2          green  {'value': 6300, 'currency': 'USD', 'value_usd'...
# 3          green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 4         bronze  {'value': 9080, 'currency': 'USD', 'value_usd'...
# ...          ...                                                ...
# 665813   diamond                                               None
# 665814   diamond                                               None
# 665815   diamond                                               None
# 665816    bronze                                               None
# 665817    hybrid                                               None
#
#                                             corresponding  \
# 0       [True, False, False, False, False, False, Fals...
# 1       [True, False, False, False, False, False, Fals...
# 2       [True, False, False, False, False, False, Fals...
# 3       [False, False, False, False, False, False, Fal...
# 4       [False, False, False, False, False, False, Fal...
# ...                                                   ...
# 665813                 [True, False, False, False, False]
# 665814                                             [True]
# 665815                                             [True]
# 665816                                             [True]
# 665817                                             [True]
#
#                                                 countries
# 0       [[US], [US], [GB], [FR], [DE], [US], [US], [IL...
# 1        [[FR], [FR], [FR], [IT], [NL], [IE], [FR], [FR]]
# 2       [[GB], [CA], [NL], [FR], [AT], [CA], [AU], [GB...
# 3       [[MA], [DK], [CN], [MA], [BE], [BE], [MA], [CN...
# 4       [[FR], [FR], [FR], [FR], [DE, FR], [AT], [FR],...
# ...                                                   ...
# 665813                     [[RU], [RU], [FR], [RU], [RU]]
# 665814                                             [[FR]]
# 665815                                             [[FR]]
# 665816                                             [[FR]]
# 665817                                             [[FR]]
#
# [665818 rows x 12 columns]

# %% [markdown]
# All missing

# %%
df_corresponding['missing'] = df_corresponding.countries.apply(lambda lst: all(len(x) == 0 for x in lst))
df_corresponding_missing = df_corresponding[df_corresponding['missing'] == True].reset_index(drop = True)
df_corresponding_missing
# Out:
# Empty DataFrame
# Columns: [doi, publication_year, language, field_names, journal, publisher, ins_type, #_authors, oa_status, apc_list, corresponding, countries, missing]
# Index: []

# %% [markdown]
# ### Phase 4

# %% [markdown]
# **Corresponding**

# %%
df_corresponding
# Out:
#                                                       doi  publication_year  \
# 0               https://doi.org/10.1007/s00134-012-2769-8              2013
# 1              https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 2           https://doi.org/10.1016/s1474-4422(13)70124-8              2013
# 3                     https://doi.org/10.1038/nature12506              2013
# 4            https://doi.org/10.1016/j.immuni.2013.10.003              2013
# ...                                                   ...               ...
# 665813  https://doi.org/10.20914/2310-1202-2024-4-178-184              2024
# 665814                  https://doi.org/10.7202/1121520ar              2024
# 665815                  https://doi.org/10.7202/1121518ar              2024
# 665816                      https://doi.org/10.4000/11ndt              2024
# 665817                       https://doi.org/10.2427/5975              2024
#
#        language                                        field_names  \
# 0            en                                         {Medicine}
# 1            en                                         {Medicine}
# 2            en                                         {Medicine}
# 3            en  {Biochemistry, Genetics and Molecular Biology,...
# 4            en            {Immunology and Microbiology, Medicine}
# ...         ...                                                ...
# 665813     None  {Environmental Science, Agricultural and Biolo...
# 665814       fr             {Arts and Humanities, Social Sciences}
# 665815       fr                                  {Social Sciences}
# 665816       fr                                  {Social Sciences}
# 665817       en  {Health Professions, Economics, Econometrics a...
#
#                                                   journal  \
# 0                                 Intensive Care Medicine
# 1                              European Journal of Cancer
# 2                                    The Lancet Neurology
# 3                                                  Nature
# 4                                                Immunity
# ...                                                   ...
# 665813  Proceedings of the Voronezh State University o...
# 665814           Revue d histoire de l Amérique française
# 665815           Revue d histoire de l Amérique française
# 665816                                 Histoire Politique
# 665817                   Italian Journal of Public Health
#
#                                                 publisher  \
# 0                         Springer Science+Business Media
# 1                                             Elsevier BV
# 2                                             Elsevier BV
# 3                                        Nature Portfolio
# 4                                              Cell Press
# ...                                                   ...
# 665813  Voronezh State University of Engineering Techn...
# 665814        Institut d'histoire de l'Amérique française
# 665815        Institut d'histoire de l'Amérique française
# 665816                                               None
# 665817                                           Prex spa
#
#                                                  ins_type  #_authors  \
# 0                                 {education, healthcare}         23
# 1              {education, other, government, healthcare}          8
# 2           {education, facility, government, healthcare}         36
# 3       {education, facility, healthcare, government, ...         82
# 4           {education, facility, government, healthcare}         17
# ...                                                   ...        ...
# 665813                              {education, facility}          5
# 665814                                        {education}          1
# 665815                                        {education}          1
# 665816                                         {facility}          1
# 665817                                       {government}          1
#
#        oa_status                                           apc_list  \
# 0         bronze  {'value': 3690, 'currency': 'EUR', 'value_usd'...
# 1         bronze  {'value': 3800, 'currency': 'USD', 'value_usd'...
# 2          green  {'value': 6300, 'currency': 'USD', 'value_usd'...
# 3          green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 4         bronze  {'value': 9080, 'currency': 'USD', 'value_usd'...
# ...          ...                                                ...
# 665813   diamond                                               None
# 665814   diamond                                               None
# 665815   diamond                                               None
# 665816    bronze                                               None
# 665817    hybrid                                               None
#
#                                             corresponding  \
# 0       [True, False, False, False, False, False, Fals...
# 1       [True, False, False, False, False, False, Fals...
# 2       [True, False, False, False, False, False, Fals...
# 3       [False, False, False, False, False, False, Fal...
# 4       [False, False, False, False, False, False, Fal...
# ...                                                   ...
# 665813                 [True, False, False, False, False]
# 665814                                             [True]
# 665815                                             [True]
# 665816                                             [True]
# 665817                                             [True]
#
#                                                 countries  missing
# 0       [[US], [US], [GB], [FR], [DE], [US], [US], [IL...    False
# 1        [[FR], [FR], [FR], [IT], [NL], [IE], [FR], [FR]]    False
# 2       [[GB], [CA], [NL], [FR], [AT], [CA], [AU], [GB...    False
# 3       [[MA], [DK], [CN], [MA], [BE], [BE], [MA], [CN...    False
# 4       [[FR], [FR], [FR], [FR], [DE, FR], [AT], [FR],...    False
# ...                                                   ...      ...
# 665813                     [[RU], [RU], [FR], [RU], [RU]]    False
# 665814                                             [[FR]]    False
# 665815                                             [[FR]]    False
# 665816                                             [[FR]]    False
# 665817                                             [[FR]]    False
#
# [665818 rows x 13 columns]

# %% [markdown]
# All CA french (strict)

# %%
df_corresponding['french_position'] = df_corresponding.countries.apply(lambda lst:[i for i, inner in enumerate(lst) if 'FR' in inner])
df_corresponding['CA_positions'] = df_corresponding.corresponding.apply(lambda lst:[i for i, val in enumerate(lst) if val is True])

df_corresponding_allfrench = df_corresponding[df_corresponding.apply(lambda row: all(pos in row['french_position'] for pos in row['CA_positions']), axis=1)].reset_index(drop=True)

total_corresponding_allfrench = df_corresponding_allfrench.groupby('publication_year')['doi'].nunique()

total_corresponding_allfrench_oa = df_corresponding_allfrench[df_corresponding_allfrench.oa_status != 'closed'].groupby('publication_year')['doi'].nunique()
total_corresponding_allfrench_apc = df_corresponding_allfrench[~df_corresponding_allfrench.apc_list.isna()].groupby('publication_year')['doi'].nunique()

grouped = pd.concat([total_corresponding_allfrench.rename('# pubs'), total_corresponding_allfrench_oa.rename('# openaccess'), total_corresponding_allfrench_apc.rename('# apc_list')], axis = 1)
grouped
# Out:
#                   # pubs  # openaccess  # apc_list
# publication_year
# 2013               29681         14320       12129
# 2014               28579         13210       12417
# 2015               33822         14943       15711
# 2016               43453         17376       22526
# 2017               41506         18000       21172
# 2018               43227         19860       20950
# 2019               40651         22065       19447
# 2020               42381         24566       21408
# 2021               43465         24735       21386
# 2022               40607         22936       20136
# 2023               41445         22412       21811
# 2024               26953         15584       14711

# %% [markdown]
# At least CA french author and others missing (medium)

# %%
df_corresponding['french_or_missing_position'] = df_corresponding.countries.apply(lambda lst:[i for i, inner in enumerate(lst) if ('FR' in inner or len(inner) == 0)])

df_corresponding_french_or_missing_position = df_corresponding[df_corresponding.apply(lambda row: all(pos in row['french_or_missing_position'] for pos in row['CA_positions']), axis=1)].reset_index(drop=True)

total_corresponding_french_or_missing_position = df_corresponding_french_or_missing_position.groupby('publication_year')['doi'].nunique()

total_corresponding_french_or_missing_position_oa = df_corresponding_french_or_missing_position[df_corresponding_french_or_missing_position.oa_status != 'closed'].groupby('publication_year')['doi'].nunique()
total_corresponding_french_or_missing_position_apc = df_corresponding_french_or_missing_position[~df_corresponding_french_or_missing_position.apc_list.isna()].groupby('publication_year')['doi'].nunique()

grouped = pd.concat([total_corresponding_french_or_missing_position.rename('# pubs'), total_corresponding_french_or_missing_position_oa.rename('# openaccess'), total_corresponding_french_or_missing_position_apc.rename('# apc_list')], axis = 1)
grouped
# Out:
#                   # pubs  # openaccess  # apc_list
# publication_year
# 2013               30466         14595       12610
# 2014               29418         13533       12930
# 2015               35025         15308       16546
# 2016               45217         17888       23827
# 2017               43157         18523       22329
# 2018               45049         20423       22258
# 2019               42245         22724       20620
# 2020               44041         25230       22638
# 2021               45250         25547       22545
# 2022               42026         23691       21171
# 2023               43079         23138       23034
# 2024               28116         16193       15579

# %% [markdown]
# At least CA french  (inclusive)

# %%
df_corresponding['french_position'] = df_corresponding.countries.apply(lambda lst:[i for i, inner in enumerate(lst) if 'FR' in inner])
df_corresponding['CA_positions'] = df_corresponding.corresponding.apply(lambda lst:[i for i, val in enumerate(lst) if val is True])

df_corresponding_anyfrench = df_corresponding[df_corresponding.apply(lambda row: any(pos in row['french_position'] for pos in row['CA_positions']), axis=1)].reset_index(drop=True)

total_corresponding_anyfrench = df_corresponding_anyfrench.groupby('publication_year')['doi'].nunique()

total_corresponding_anyfrench_oa = df_corresponding_anyfrench[df_corresponding_anyfrench.oa_status != 'closed'].groupby('publication_year')['doi'].nunique()
total_corresponding_anyfrench_apc = df_corresponding_anyfrench[~df_corresponding_anyfrench.apc_list.isna()].groupby('publication_year')['doi'].nunique()

grouped = pd.concat([total_corresponding_anyfrench.rename('# pubs'), total_corresponding_anyfrench_oa.rename('# openaccess'), total_corresponding_anyfrench_apc.rename('# apc_list')], axis = 1)
grouped
# Out:
#                   # pubs  # openaccess  # apc_list
# publication_year
# 2013               31091         15212       13249
# 2014               30142         14189       13627
# 2015               35806         16182       17181
# 2016               46405         19154       24724
# 2017               44453         19873       23289
# 2018               46589         21859       23352
# 2019               43699         24198       21524
# 2020               45868         27167       23805
# 2021               46839         27229       23800
# 2022               43828         25358       22392
# 2023               44679         24779       24158
# 2024               29330         17386       16470

# %% [markdown]
# **No Corresponding**

# %%
df_nocorresponding
# Out:
#                                                  doi  publication_year  \
# 0        https://doi.org/10.1051/0004-6361/201322068              2013
# 1                https://doi.org/10.1038/nature12477              2013
# 2       https://doi.org/10.1097/ccm.0b013e31827e83af              2013
# 3              https://doi.org/10.1038/nnano.2013.46              2013
# 4                https://doi.org/10.1093/nar/gkt1178              2013
# ...                                              ...               ...
# 683493             https://doi.org/10.7202/1120388ar              2024
# 683494             https://doi.org/10.7202/1120383ar              2024
# 683495             https://doi.org/10.7202/1120375ar              2024
# 683496             https://doi.org/10.7202/1120374ar              2024
# 683497     https://doi.org/10.1017/s0021875825000179              2024
#
#        language                                        field_names  \
# 0            en          {Physics and Astronomy, Computer Science}
# 1            en  {Biochemistry, Genetics and Molecular Biology,...
# 2            en                                         {Medicine}
# 3            en                                {Materials Science}
# 4            en  {Engineering, Biochemistry, Genetics and Molec...
# ...         ...                                                ...
# 683493       fr                                                 {}
# 683494       fr                                                 {}
# 683495       fr                                                 {}
# 683496       fr                                                 {}
# 683497       en                                                 {}
#
#                             journal                      publisher  \
# 0        Astronomy and Astrophysics                   EDP Sciences
# 1                            Nature               Nature Portfolio
# 2            Critical Care Medicine  Lippincott Williams & Wilkins
# 3             Nature Nanotechnology               Nature Portfolio
# 4            Nucleic Acids Research        Oxford University Press
# ...                             ...                            ...
# 683493         Études/Inuit/Studies                     Q114618608
# 683494         Études/Inuit/Studies                     Q114618608
# 683495         Études/Inuit/Studies                     Q114618608
# 683496         Études/Inuit/Studies                     Q114618608
# 683497  Journal of American Studies     Cambridge University Press
#
#                                                  ins_type  #_authors  \
# 0            {education, facility, nonprofit, government}         44
# 1       {education, facility, healthcare, government, ...         70
# 2                        {company, education, healthcare}         23
# 3                                              {facility}          2
# 4                                            {government}          5
# ...                                                   ...        ...
# 683493                              {education, facility}          2
# 683494                              {education, facility}          3
# 683495                              {education, facility}          3
# 683496                              {education, facility}          3
# 683497                                        {education}          6
#
#        oa_status                                           apc_list  \
# 0         bronze                                               None
# 1         bronze  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 2         closed                                               None
# 3          green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 4           gold  {'value': 3630, 'currency': 'USD', 'value_usd'...
# ...          ...                                                ...
# 683493   diamond                                               None
# 683494   diamond                                               None
# 683495   diamond                                               None
# 683496   diamond                                               None
# 683497    closed                                               None
#
#                                             corresponding  \
# 0       [False, False, False, False, False, False, Fal...
# 1       [False, False, False, False, False, False, Fal...
# 2       [False, False, False, False, False, False, Fal...
# 3                                          [False, False]
# 4                     [False, False, False, False, False]
# ...                                                   ...
# 683493                                     [False, False]
# 683494                              [False, False, False]
# 683495                              [False, False, False]
# 683496                              [False, False, False]
# 683497         [False, False, False, False, False, False]
#
#                                                 countries  missing
# 0       [[DE], [US], [FR, US], [FR, US], [FR, US], [US...    False
# 1       [[GB], [GB], [GB], [CA], [GB], [GB], [GB], [GB...    False
# 2       [[US], [US], [GB], [FR], [DE], [US], [US], [IL...    False
# 3                                              [[], [FR]]    False
# 4                          [[FR], [FR], [FR], [FR], [FR]]    False
# ...                                                   ...      ...
# 683493                                         [[], [FR]]    False
# 683494                               [[], [CA, FR], [CA]]    False
# 683495                               [[], [CA, FR], [CA]]    False
# 683496                               [[], [CA, FR], [CA]]    False
# 683497                 [[GB], [], [FR], [FR], [FR], [FR]]    False
#
# [683498 rows x 13 columns]

# %% [markdown]
# All authors french (strict)

# %%
df_nocorresponding['whole_french'] = df_nocorresponding.countries.apply(lambda lst: all('FR' in x for x in lst))
df_nocorresponding_wholefrench = df_nocorresponding[df_nocorresponding['whole_french'] == True].reset_index(drop = True)

total_wholefrench= df_nocorresponding_wholefrench.groupby('publication_year')['doi'].nunique()

total_wholefrench_oa = df_nocorresponding_wholefrench[df_nocorresponding_wholefrench.oa_status != 'closed'].groupby('publication_year')['doi'].nunique()
total_wholefrench_apc = df_nocorresponding_wholefrench[~df_nocorresponding_wholefrench.apc_list.isna()].groupby('publication_year')['doi'].nunique()

grouped = pd.concat([total_wholefrench.rename('# pubs'), total_wholefrench_oa.rename('openaccess'), total_wholefrench_apc.rename('apc_list')], axis = 1)
grouped
# Out:
#                   # pubs  openaccess  apc_list
# publication_year
# 2013               27843       10238     14884
# 2014               28549       10036     15172
# 2015               23937       10295     11914
# 2016               18787        9723      7801
# 2017               18499       10436      8300
# 2018               18067       10988      8249
# 2019               18126       12395      8834
# 2020               19242       14031      9879
# 2021               18866       13843      9901
# 2022               18700       13297      9600
# 2023               16853       11768      8227
# 2024               17391       11294      9239

# %% [markdown]
# At least french author and others missing (medium)

# %%
df_nocorresponding['any_french_or_missing'] = df_nocorresponding['countries'].apply(lambda lst: all(all(c == 'FR' for c in inner) or len(inner) == 0 for inner in lst))
df_nocorresponding_anyfrenchormissing = df_nocorresponding[df_nocorresponding['any_french_or_missing'] == True].reset_index(drop = True)

total_anyfrenchormissing = df_nocorresponding_anyfrenchormissing.groupby('publication_year')['doi'].nunique()

total_anyfrenchormissing_oa = df_nocorresponding_anyfrenchormissing[df_nocorresponding_anyfrenchormissing.oa_status != 'closed'].groupby('publication_year')['doi'].nunique()
total_anyfrenchormissing_apc = df_nocorresponding_anyfrenchormissing[~df_nocorresponding_anyfrenchormissing.apc_list.isna()].groupby('publication_year')['doi'].nunique()

grouped = pd.concat([total_anyfrenchormissing.rename('# pubs'), total_anyfrenchormissing_oa.rename('openaccess'), total_anyfrenchormissing_apc.rename('apc_list')], axis = 1)
grouped
# Out:
#                   # pubs  openaccess  apc_list
# publication_year
# 2013               33263       11462     17609
# 2014               34070       11426     17871
# 2015               28229       11663     14066
# 2016               23168       11528     10076
# 2017               22992       12358     10639
# 2018               22572       13178     10380
# 2019               22565       14721     11116
# 2020               23825       16511     12223
# 2021               23353       16320     12136
# 2022               23552       15722     12141
# 2023               20766       13771     10130
# 2024               22003       13782     11804

# %% [markdown]
# At least french (inclusive)

# %%
df_nocorresponding['any_french'] = df_nocorresponding.countries.apply(lambda lst: any('FR' in x for x in lst))
df_nocorresponding_anyfrench = df_nocorresponding[df_nocorresponding['any_french'] == True].reset_index(drop = True)

total_anyfrench= df_nocorresponding_anyfrench.groupby('publication_year')['doi'].nunique()

total_anyfrench_oa = df_nocorresponding_anyfrench[df_nocorresponding_anyfrench.oa_status != 'closed'].groupby('publication_year')['doi'].nunique()
total_anyfrench_apc = df_nocorresponding_anyfrench[~df_nocorresponding_anyfrench.apc_list.isna()].groupby('publication_year')['doi'].nunique()

grouped = pd.concat([total_anyfrench.rename('# pubs'), total_anyfrench_oa.rename('openaccess'), total_anyfrench_apc.rename('apc_list')], axis = 1)
grouped
# Out:
#                   # pubs  openaccess  apc_list
# publication_year
# 2013               69063       29860     36872
# 2014               72644       31214     38555
# 2015               64419       31505     33000
# 2016               50922       28395     22333
# 2017               51752       30739     23533
# 2018               51049       32131     23491
# 2019               52346       35829     25881
# 2020               55644       39992     28335
# 2021               54475       39244     28363
# 2022               54081       37997     27748
# 2023               51540       36553     25509
# 2024               55563       36597     30503

# %% [markdown]
# ### Most inclusive

# %%
inclusive = pd.concat([df_corresponding_anyfrench, df_nocorresponding_anyfrench], ignore_index = True)
total_inclusive= inclusive.groupby('publication_year')['doi'].nunique()

total_inclusive_oa = inclusive[inclusive.oa_status != 'closed'].groupby('publication_year')['doi'].nunique()
total_inclusive_apc = inclusive[~inclusive.apc_list.isna()].groupby('publication_year')['doi'].nunique()
grouped = pd.concat([total_inclusive.rename('# pubs'), total_inclusive_oa.rename('openaccess'), total_inclusive_apc.rename('apc_list')], axis = 1)
grouped
# Out:
#                   # pubs  openaccess  apc_list
# publication_year
# 2013              100154       45072     50121
# 2014              102786       45403     52182
# 2015              100225       47687     50181
# 2016               97327       47549     47057
# 2017               96205       50612     46822
# 2018               97638       53990     46843
# 2019               96045       60027     47405
# 2020              101512       67159     52140
# 2021              101314       66473     52163
# 2022               97909       63355     50140
# 2023               96219       61332     49667
# 2024               84893       53983     46973

# %% [markdown]
# ### Most restrictive

# %%
exclusive = pd.concat([df_corresponding_allfrench, df_nocorresponding_wholefrench], ignore_index = True)
total_exclusive= exclusive.groupby('publication_year')['doi'].nunique()

total_exclusive_oa = exclusive[exclusive.oa_status != 'closed'].groupby('publication_year')['doi'].nunique()
total_exclusive_apc = exclusive[~exclusive.apc_list.isna()].groupby('publication_year')['doi'].nunique()

grouped = pd.concat([total_exclusive.rename('# pubs'), total_exclusive_oa.rename('openaccess'), total_exclusive_apc.rename('apc_list')], axis = 1)
grouped
# Out:
#                   # pubs  openaccess  apc_list
# publication_year
# 2013               57524       24558     27013
# 2014               57128       23246     27589
# 2015               57759       25238     27625
# 2016               62240       27099     30327
# 2017               60005       28436     29472
# 2018               61294       30848     29199
# 2019               58777       34460     28281
# 2020               61623       38597     31287
# 2021               62331       38578     31287
# 2022               59307       36233     29736
# 2023               58298       34180     30038
# 2024               44344       26878     23950
