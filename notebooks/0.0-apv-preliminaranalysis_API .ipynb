# %% [markdown]
# # Preliminar Analysis

# %%
import requests
import time
import json
from urllib.parse import urlencode
import pandas as pd
import orjson
from tqdm import tqdm

# %% [markdown]
# ### Download all articles where there are one or more french authors

# %%
BASE_URL = "https://api.openalex.org/works"

selected_fields = ["doi", "is_xpac", "publication_year", "language", "indexed_in", "primary_location", "open_access", "authorships", "institutions", 
                   "corresponding_author_ids", "corresponding_institution_ids", "apc_list", "apc_paid", "cited_by_count", "primary_topic", "topics", 
                   "concepts", "grants", "awards", "funders"]

def fetch_page(cursor, filters):
    params = filters.copy()
    params["cursor"] = cursor
    params["per_page"] = 200
    url = f"{BASE_URL}?{urlencode(params)}"
    r = requests.get(url, timeout=30)
    r.raise_for_status()
    return r.json()

for year in range(2018, 2025): # anar modificant l'initial year
    print(f"\n=== YEAR {year} ===")

    filters = {
        "filter": ",".join([
            "type:article",
            "primary_location.source.type:journal",
            "authorships.institutions.country_code:FR",
            f"from_publication_date:{year}-01-01",
            f"to_publication_date:{year}-12-31"
        ]),
        "select": ",".join(selected_fields)
    }

    cursor = "*"
    count = 0
    output_file = f"../data/interim/FranceInitialAPI/openalex_french_authors_{year}_v2.jsonl"

    with open(output_file, "w", encoding="utf-8") as f:
        pbar = tqdm(unit="works", dynamic_ncols=True)
        while True:
            data = fetch_page(cursor, filters)

            works = data.get("results", [])
            next_cursor = data.get("meta", {}).get("next_cursor", None)

            for w in works:
                f.write(json.dumps(w) + "\n")
                count += 1

            pbar.update(len(works))
            
            if not next_cursor:
                break
            cursor = next_cursor
            time.sleep(1)

        pbar.close()
    print(f"\nSaved: {output_file}  (total {count})")

print("\n=== COMPLETED ===")
# Out:
# === YEAR 2013 ===
# 200works [00:03, 65.37works/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 50
#      48             break
#      49         cursor = next_cursor
# ---> 50         time.sleep(1)
#      52     pbar.close()
#      53 print(f"\nSaved: {output_file}  (total {count})")
#
# KeyboardInterrupt:
# 200works [00:19, 65.37works/s]

# %% [markdown]
# ### Phase 1: Whole France

# %% [markdown]
# **Number of unique DOI in France (NON Datacite)**

# %%
unique_doi_france = 0
for year in tqdm(range(2013, 2025)):
    doi_set_france = set()
    with open(f"../data/interim/FranceInitialAPI/openalex_french_authors_{year}_v2.jsonl", "rb") as f:
        for line in f:
            rec = orjson.loads(line)
            doi = rec.get("doi")
            if doi:
                doi_set_france.add(doi)
    unique_doi_france += len(doi_set_france)

print("Total unique DOIs:", unique_doi_france)
# Out:
# 100%|██████████| 12/12 [01:06<00:00,  5.54s/it]
# Total unique DOIs: 1243928

# %% [markdown]
# **Number of unique DOI in France (ONLY Datacite) + dataset construction**

# %%
### I SHOULD REDO THE DOWNLOAD; ASK IF NEEDED GIVEN THAT WE WON'T USE IT

# %% [markdown]
# ### Phase 2: Ingest, or not, BSO

# %%
df_bso = pd.read_parquet("../data/external/open-access-monitor-france.parquet", engine = "pyarrow").dropna(subset = ["doi"])
df_bso
# Out:
#        observation_date                                    id  \
# 0                2024Q4      doi10.1080/10408398.2022.2033684
# 1                2024Q4          doi10.1016/j.gie.2021.12.048
# 2                2024Q4  doi10.1016/j.compositesa.2022.107165
# 3                2024Q4             doi10.1002/ejoc.202200123
# 4                2024Q4      doi10.3410/f.721705664.793594159
# ...                 ...                                   ...
# 937570           2024Q4           doi10.1021/acs.jpcc.9b10824
# 937571           2024Q4          doi10.1017/s007543582000012x
# 937575           2024Q4             doi10.1075/aila.00030.haa
# 937576           2024Q4         doi10.1007/s13592-020-00743-8
# 937577           2024Q4         doi10.1007/s10844-020-00608-7
#
#                                       doi      pmid  \
# 0           10.1080/10408398.2022.2033684  35152807
# 1               10.1016/j.gie.2021.12.048      None
# 2       10.1016/j.compositesa.2022.107165      None
# 3                  10.1002/ejoc.202200123      None
# 4           10.3410/f.721705664.793594159      None
# ...                                   ...       ...
# 937570           10.1021/acs.jpcc.9b10824      None
# 937571          10.1017/s007543582000012x      None
# 937575             10.1075/aila.00030.haa      None
# 937576         10.1007/s13592-020-00743-8      None
# 937577         10.1007/s10844-020-00608-7      None
#
#                                            hal_id  year  \
# 0                                    hal-03777046  2022
# 1                                            None  2022
# 2       Preprint-Carpier-et-al-CompPartA-2022.pdf  2022
# 3                                TEXT%20FINAL.pdf  2022
# 4                                            None  2022
# ...                                           ...   ...
# 937570                               hal-03017908  2020
# 937571                                       None  2020
# 937575                                       None  2020
# 937576                               hal-03161695  2020
# 937577                             manuscript.pdf  2020
#
#                                                     title  \
# 0       The impact of nano/micro-plastics toxicity on ...
# 1       Real-time use of artificial intelligence at co...
# 2       Meso-structure-based thermomechanical modellin...
# 3       Electrochemical Trifluoromethylselenolation of...
# 4       Faculty Opinions recommendation of On the gene...
# ...                                                   ...
# 937570  The Dissolution Anisotropy of Pyroxenes: Exper...
# 937571  LAUREL FULKERSON, A LITERARY COMMENTARY ON THE...
# 937575              Recycling a genre for news automation
# 937576  Short-term hyperthermia at larval age reduces ...
# 937577  On data lake architectures and metadata manage...
#
#                         journal_issns journal_issn_l  \
# 0                 1040-8398,1549-7852      1040-8398
# 1       0016-5107,1085-8741,1097-6779      0016-5107
# 2                 1359-835X,1878-5840      1359-835X
# 3                 1099-0690,1434-193X      1099-0690
# 4                                None           None
# ...                               ...            ...
# 937570            1932-7447,1932-7455      1932-7447
# 937571            0075-4358,1753-528X      0075-4358
# 937575            1461-0213,1570-5595      1461-0213
# 937576            0044-8435,1297-9678      0044-8435
# 937577            0925-9902,1573-7675      0925-9902
#
#                                              journal_name  ... software_used  \
# 0          Critical Reviews in Food Science and Nutrition  ...          None
# 1                              Gastrointestinal Endoscopy  ...          None
# 2       Composites Part A Applied Science and Manufact...  ...          True
# 3                   European Journal of Organic Chemistry  ...         False
# 4       Faculty Opinions – Post-Publication Peer Revie...  ...          None
# ...                                                   ...  ...           ...
# 937570                The Journal of Physical Chemistry C  ...         False
# 937571                       The Journal of Roman Studies  ...          None
# 937575                                        AILA Review  ...          None
# 937576                                         Apidologie  ...          None
# 937577         Journal of Intelligent Information Systems  ...          True
#
#        software_created software_shared data_used data_created  data_shared  \
# 0                  None            None      None         None         None
# 1                  None            None      None         None         None
# 2                 False           False      True         True        False
# 3                 False           False      True        False        False
# 4                  None            None      None         None         None
# ...                 ...             ...       ...          ...          ...
# 937570            False           False      True         True        False
# 937571             None            None      None         None         None
# 937575             None            None      None         None         None
# 937576             None            None      None         None         None
# 937577             True           False      True         True        False
#
#        missing_doi_in_hal has_doi_in_hal                         doi_in_hal  \
# 0                     NaN              1      10.1080/10408398.2022.2033684
# 1                     NaN           None                               None
# 2                     NaN              1  10.1016/j.compositesa.2022.107165
# 3                     NaN              1             10.1002/ejoc.202200123
# 4                     NaN           None                               None
# ...                   ...            ...                                ...
# 937570                NaN              1           10.1021/acs.jpcc.9b10824
# 937571                NaN           None                               None
# 937575                NaN           None                               None
# 937576                NaN              1         10.1007/s13592-020-00743-8
# 937577                NaN              1         10.1007/s10844-020-00608-7
#
#        bso_country
# 0               fr
# 1             None
# 2         fr,other
# 3         fr,other
# 4               fr
# ...            ...
# 937570    fr,other
# 937571          fr
# 937575      europe
# 937576       other
# 937577    fr,other
#
# [611769 rows x 46 columns]

# %%
### WAITING FOR THE RESPONSE OF THE TECNICAL TEAM

# %% [markdown]
# ### Phase 3: journals analysis

# %%
interest = ['doi', 'publication_year', 'authorships', 'primary_location', 'topics', 'open_access', 'apc_list']
keys = ['doi', 'publication_year', 'field_names', 'journal', 'publisher', 'ins_type', '#_authors', 'oa_status', 'apc_list']
records = []
for year in tqdm(range(2013, 2025)):
    with open(f"../data/interim/FranceInitialAPI/openalex_french_authors_{year}_v2.jsonl", "rb") as f:
        for line in f:
            rec = orjson.loads(line)
            if not rec.get("doi"): # Skip records without DOI
                continue
            filtered = {k: rec.get(k) for k in interest} # Keep only the fields we care about

            # Extract field_names from topics
            topics = filtered.get("topics") or []
            filtered["field_names"] = {c.get("field", {}).get("display_name") for c in topics if c.get("field")}

            # Extract journal and publisher from primary_location
            pl = filtered.get("primary_location") or {}
            source = pl.get("source") or {}
            filtered["journal"] = source.get("display_name")
            filtered["publisher"] = source.get("host_organization_name")

            # Extract institution types and number of authors
            authorships = filtered.get("authorships") or []
            filtered["ins_type"] = {inst.get("type") 
                                    for auth in authorships 
                                    for inst in auth.get("institutions", []) if inst.get("type")}
            filtered["#_authors"] = len(authorships)
            
            o_a = filtered.get("open_access") or {}
            filtered["oa_status"] = o_a.get("oa_status")

            records.append({k: filtered.get(k) for k in keys})

df = pd.DataFrame(records)
df.to_parquet("../data/interim/preliminary/fr_p2_fr_core.parquet", index=False)
df
# Out:
# 100%|██████████| 12/12 [01:21<00:00,  6.78s/it]
#                                                        doi  publication_year  \
# 0              https://doi.org/10.1051/0004-6361/201322068              2013
# 1                      https://doi.org/10.1038/nature12477              2013
# 2             https://doi.org/10.1097/ccm.0b013e31827e83af              2013
# 3                https://doi.org/10.1007/s00134-012-2769-8              2013
# 4                    https://doi.org/10.1038/nnano.2013.46              2013
# ...                                                    ...               ...
# 1243923  https://doi.org/10.20914/2310-1202-2024-4-178-184              2024
# 1243924                  https://doi.org/10.7202/1121520ar              2024
# 1243925                  https://doi.org/10.7202/1121518ar              2024
# 1243926                      https://doi.org/10.4000/11ndt              2024
# 1243927                       https://doi.org/10.2427/5975              2024
#
#                                                field_names  \
# 0                {Physics and Astronomy, Computer Science}
# 1        {Medicine, Biochemistry, Genetics and Molecula...
# 2                                               {Medicine}
# 3                                               {Medicine}
# 4                                      {Materials Science}
# ...                                                    ...
# 1243923  {Environmental Science, Agricultural and Biolo...
# 1243924             {Social Sciences, Arts and Humanities}
# 1243925                                  {Social Sciences}
# 1243926                                  {Social Sciences}
# 1243927  {Health Professions, Economics, Econometrics a...
#
#                                                    journal  \
# 0                               Astronomy and Astrophysics
# 1                                                   Nature
# 2                                   Critical Care Medicine
# 3                                  Intensive Care Medicine
# 4                                    Nature Nanotechnology
# ...                                                    ...
# 1243923  Proceedings of the Voronezh State University o...
# 1243924           Revue d histoire de l Amérique française
# 1243925           Revue d histoire de l Amérique française
# 1243926                                 Histoire Politique
# 1243927                   Italian Journal of Public Health
#
#                                                  publisher  \
# 0                                             EDP Sciences
# 1                                         Nature Portfolio
# 2                            Lippincott Williams & Wilkins
# 3                          Springer Science+Business Media
# 4                                         Nature Portfolio
# ...                                                    ...
# 1243923  Voronezh State University of Engineering Techn...
# 1243924        Institut d'histoire de l'Amérique française
# 1243925        Institut d'histoire de l'Amérique française
# 1243926                                               None
# 1243927                                           Prex spa
#
#                                                   ins_type  #_authors  \
# 0             {education, facility, nonprofit, government}         44
# 1        {education, government, facility, other, healt...         70
# 2                         {education, company, healthcare}         23
# 3                                  {education, healthcare}         23
# 4                                               {facility}          2
# ...                                                    ...        ...
# 1243923                              {education, facility}          5
# 1243924                                        {education}          1
# 1243925                                        {education}          1
# 1243926                                         {facility}          1
# 1243927                                       {government}          1
#
#         oa_status                                           apc_list
# 0          bronze                                               None
# 1          bronze  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 2          closed                                               None
# 3          bronze  {'value': 3690, 'currency': 'EUR', 'value_usd'...
# 4           green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# ...           ...                                                ...
# 1243923   diamond                                               None
# 1243924   diamond                                               None
# 1243925   diamond                                               None
# 1243926    bronze                                               None
# 1243927    hybrid                                               None
#
# [1243928 rows x 9 columns]

# %% [markdown]
# **Industry concentration and indicators**

# %%
interest = 'journal'

grouped = df.groupby(interest).count()[['doi']].sort_values('doi', ascending = False).rename(columns = {'doi' : '# publications'})
grouped['% publications'] = (grouped['# publications'] / df.doi.nunique())
print('The HHF is: ', sum(grouped['% publications']**2))

for year in range(2013, 2025):
    df_year = df[df['publication_year'] == year]
    grouped_year = df_year.groupby(interest).count()[['doi']].sort_values('doi', ascending = False).rename(columns = {'doi' : f'# publications {year}'})
    grouped_year[f'% publications {year}'] = (grouped_year[f'# publications {year}'] / df_year.doi.nunique())
    grouped = grouped.merge(grouped_year, left_index = True, right_index = True, how = 'left').fillna(0)
    print(f'The HHF in {year} is: ', sum(grouped_year[f'% publications {year}']**2))
grouped
# Out:
# The HHF is:  0.0006792579494307851
# The HHF in 2013 is:  0.01995000000000005
# The HHF in 2014 is:  0.0011864172963031473
# The HHF in 2015 is:  0.0009941372296594685
# The HHF in 2016 is:  0.0009819659181103551
# The HHF in 2017 is:  0.0009303393912335911
# The HHF in 2018 is:  0.000820114139809399
# The HHF in 2019 is:  0.000760996965802461
# The HHF in 2020 is:  0.0007493847616581456
# The HHF in 2021 is:  0.00073012000581234
# The HHF in 2022 is:  0.0006970888257855055
# The HHF in 2023 is:  0.0007099792074962256
# The HHF in 2024 is:  0.0007695706597819862
#                                                    # publications  \
# journal
# Scientific Reports                                           9692
# PLoS ONE                                                     8852
# Astronomy and Astrophysics                                   7555
# Monthly Notices of the Royal Astronomical Society            5772
# Journal of Clinical Oncology                                 5754
# ...                                                           ...
# 日本物理学会講演概要集 70.2                                                1
# 日本物理学会講演概要集 70.1                                                1
# 日本消化器がん検診学会雑誌                                                   1
# مجلة کلیة الآداب القاهرة                                        1
# مجلة کلية السياحة والفنادق جامعة المنصورة                       1
#
#                                                    % publications  \
# journal
# Scientific Reports                                   7.791448e-03
# PLoS ONE                                             7.116167e-03
# Astronomy and Astrophysics                           6.073503e-03
# Monthly Notices of the Royal Astronomical Society    4.640140e-03
# Journal of Clinical Oncology                         4.625670e-03
# ...                                                           ...
# 日本物理学会講演概要集 70.2                                     8.039050e-07
# 日本物理学会講演概要集 70.1                                     8.039050e-07
# 日本消化器がん検診学会雑誌                                        8.039050e-07
# مجلة کلیة الآداب القاهرة                             8.039050e-07
# مجلة کلية السياحة والفنادق جامعة المنصورة            8.039050e-07
#
#                                                    # publications 2013  \
# journal
# Scientific Reports                                                 0.0
# PLoS ONE                                                           0.0
# Astronomy and Astrophysics                                         3.0
# Monthly Notices of the Royal Astronomical Society                  0.0
# Journal of Clinical Oncology                                       2.0
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                                   0.0
# 日本物理学会講演概要集 70.1                                                   0.0
# 日本消化器がん検診学会雑誌                                                      0.0
# مجلة کلیة الآداب القاهرة                                           0.0
# مجلة کلية السياحة والفنادق جامعة المنصورة                          0.0
#
#                                                    % publications 2013  \
# journal
# Scientific Reports                                               0.000
# PLoS ONE                                                         0.000
# Astronomy and Astrophysics                                       0.015
# Monthly Notices of the Royal Astronomical Society                0.000
# Journal of Clinical Oncology                                     0.010
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                                 0.000
# 日本物理学会講演概要集 70.1                                                 0.000
# 日本消化器がん検診学会雑誌                                                    0.000
# مجلة کلیة الآداب القاهرة                                         0.000
# مجلة کلية السياحة والفنادق جامعة المنصورة                        0.000
#
#                                                    # publications 2014  \
# journal
# Scientific Reports                                               146.0
# PLoS ONE                                                        1518.0
# Astronomy and Astrophysics                                       663.0
# Monthly Notices of the Royal Astronomical Society                388.0
# Journal of Clinical Oncology                                     551.0
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                                   0.0
# 日本物理学会講演概要集 70.1                                                   0.0
# 日本消化器がん検診学会雑誌                                                      0.0
# مجلة کلیة الآداب القاهرة                                           0.0
# مجلة کلية السياحة والفنادق جامعة المنصورة                          0.0
#
#                                                    % publications 2014  \
# journal
# Scientific Reports                                            0.001341
# PLoS ONE                                                      0.013938
# Astronomy and Astrophysics                                    0.006088
# Monthly Notices of the Royal Astronomical Society             0.003563
# Journal of Clinical Oncology                                  0.005059
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                              0.000000
# 日本物理学会講演概要集 70.1                                              0.000000
# 日本消化器がん検診学会雑誌                                                 0.000000
# مجلة کلیة الآداب القاهرة                                      0.000000
# مجلة کلية السياحة والفنادق جامعة المنصورة                     0.000000
#
#                                                    # publications 2015  \
# journal
# Scientific Reports                                               452.0
# PLoS ONE                                                        1358.0
# Astronomy and Astrophysics                                       690.0
# Monthly Notices of the Royal Astronomical Society                437.0
# Journal of Clinical Oncology                                     532.0
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                                   1.0
# 日本物理学会講演概要集 70.1                                                   1.0
# 日本消化器がん検診学会雑誌                                                      0.0
# مجلة کلیة الآداب القاهرة                                           0.0
# مجلة کلية السياحة والفنادق جامعة المنصورة                          0.0
#
#                                                    % publications 2015  \
# journal
# Scientific Reports                                            0.004153
# PLoS ONE                                                      0.012477
# Astronomy and Astrophysics                                    0.006339
# Monthly Notices of the Royal Astronomical Society             0.004015
# Journal of Clinical Oncology                                  0.004888
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                              0.000009
# 日本物理学会講演概要集 70.1                                              0.000009
# 日本消化器がん検診学会雑誌                                                 0.000000
# مجلة کلیة الآداب القاهرة                                      0.000000
# مجلة کلية السياحة والفنادق جامعة المنصورة                     0.000000
#
#                                                    # publications 2016  \
# journal
# Scientific Reports                                               964.0
# PLoS ONE                                                        1066.0
# Astronomy and Astrophysics                                       705.0
# Monthly Notices of the Royal Astronomical Society                563.0
# Journal of Clinical Oncology                                     530.0
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                                   0.0
# 日本物理学会講演概要集 70.1                                                   0.0
# 日本消化器がん検診学会雑誌                                                      0.0
# مجلة کلیة الآداب القاهرة                                           0.0
# مجلة کلية السياحة والفنادق جامعة المنصورة                          0.0
#
#                                                    % publications 2016  ...  \
# journal                                                                 ...
# Scientific Reports                                            0.008595  ...
# PLoS ONE                                                      0.009504  ...
# Astronomy and Astrophysics                                    0.006286  ...
# Monthly Notices of the Royal Astronomical Society             0.005020  ...
# Journal of Clinical Oncology                                  0.004725  ...
# ...                                                                ...  ...
# 日本物理学会講演概要集 70.2                                              0.000000  ...
# 日本物理学会講演概要集 70.1                                              0.000000  ...
# 日本消化器がん検診学会雑誌                                                 0.000000  ...
# مجلة کلیة الآداب القاهرة                                      0.000000  ...
# مجلة کلية السياحة والفنادق جامعة المنصورة                     0.000000  ...
#
#                                                    # publications 2020  \
# journal
# Scientific Reports                                              1129.0
# PLoS ONE                                                         649.0
# Astronomy and Astrophysics                                       738.0
# Monthly Notices of the Royal Astronomical Society                616.0
# Journal of Clinical Oncology                                     536.0
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                                   0.0
# 日本物理学会講演概要集 70.1                                                   0.0
# 日本消化器がん検診学会雑誌                                                      1.0
# مجلة کلیة الآداب القاهرة                                           0.0
# مجلة کلية السياحة والفنادق جامعة المنصورة                          0.0
#
#                                                    % publications 2020  \
# journal
# Scientific Reports                                            0.009310
# PLoS ONE                                                      0.005352
# Astronomy and Astrophysics                                    0.006085
# Monthly Notices of the Royal Astronomical Society             0.005079
# Journal of Clinical Oncology                                  0.004420
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                              0.000000
# 日本物理学会講演概要集 70.1                                              0.000000
# 日本消化器がん検診学会雑誌                                                 0.000008
# مجلة کلیة الآداب القاهرة                                      0.000000
# مجلة کلية السياحة والفنادق جامعة المنصورة                     0.000000
#
#                                                    # publications 2021  \
# journal
# Scientific Reports                                              1118.0
# PLoS ONE                                                         514.0
# Astronomy and Astrophysics                                       712.0
# Monthly Notices of the Royal Astronomical Society                555.0
# Journal of Clinical Oncology                                     480.0
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                                   0.0
# 日本物理学会講演概要集 70.1                                                   0.0
# 日本消化器がん検診学会雑誌                                                      0.0
# مجلة کلیة الآداب القاهرة                                           0.0
# مجلة کلية السياحة والفنادق جامعة المنصورة                          0.0
#
#                                                    % publications 2021  \
# journal
# Scientific Reports                                            0.009224
# PLoS ONE                                                      0.004241
# Astronomy and Astrophysics                                    0.005875
# Monthly Notices of the Royal Astronomical Society             0.004579
# Journal of Clinical Oncology                                  0.003960
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                              0.000000
# 日本物理学会講演概要集 70.1                                              0.000000
# 日本消化器がん検診学会雑誌                                                 0.000000
# مجلة کلیة الآداب القاهرة                                      0.000000
# مجلة کلية السياحة والفنادق جامعة المنصورة                     0.000000
#
#                                                    # publications 2022  \
# journal
# Scientific Reports                                               869.0
# PLoS ONE                                                         433.0
# Astronomy and Astrophysics                                       722.0
# Monthly Notices of the Royal Astronomical Society                498.0
# Journal of Clinical Oncology                                     520.0
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                                   0.0
# 日本物理学会講演概要集 70.1                                                   0.0
# 日本消化器がん検診学会雑誌                                                      0.0
# مجلة کلیة الآداب القاهرة                                           0.0
# مجلة کلية السياحة والفنادق جامعة المنصورة                          0.0
#
#                                                    % publications 2022  \
# journal
# Scientific Reports                                            0.007429
# PLoS ONE                                                      0.003702
# Astronomy and Astrophysics                                    0.006173
# Monthly Notices of the Royal Astronomical Society             0.004258
# Journal of Clinical Oncology                                  0.004446
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                              0.000000
# 日本物理学会講演概要集 70.1                                              0.000000
# 日本消化器がん検診学会雑誌                                                 0.000000
# مجلة کلیة الآداب القاهرة                                      0.000000
# مجلة کلية السياحة والفنادق جامعة المنصورة                     0.000000
#
#                                                    # publications 2023  \
# journal
# Scientific Reports                                               761.0
# PLoS ONE                                                         416.0
# Astronomy and Astrophysics                                       710.0
# Monthly Notices of the Royal Astronomical Society                596.0
# Journal of Clinical Oncology                                     539.0
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                                   0.0
# 日本物理学会講演概要集 70.1                                                   0.0
# 日本消化器がん検診学会雑誌                                                      0.0
# مجلة کلیة الآداب القاهرة                                           0.0
# مجلة کلية السياحة والفنادق جامعة المنصورة                          0.0
#
#                                                    % publications 2023  \
# journal
# Scientific Reports                                            0.006591
# PLoS ONE                                                      0.003603
# Astronomy and Astrophysics                                    0.006149
# Monthly Notices of the Royal Astronomical Society             0.005162
# Journal of Clinical Oncology                                  0.004668
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                              0.000000
# 日本物理学会講演概要集 70.1                                              0.000000
# 日本消化器がん検診学会雑誌                                                 0.000000
# مجلة کلیة الآداب القاهرة                                      0.000000
# مجلة کلية السياحة والفنادق جامعة المنصورة                     0.000000
#
#                                                    # publications 2024  \
# journal
# Scientific Reports                                               829.0
# PLoS ONE                                                         452.0
# Astronomy and Astrophysics                                       620.0
# Monthly Notices of the Royal Astronomical Society                401.0
# Journal of Clinical Oncology                                     507.0
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                                   0.0
# 日本物理学会講演概要集 70.1                                                   0.0
# 日本消化器がん検診学会雑誌                                                      0.0
# مجلة کلیة الآداب القاهرة                                           1.0
# مجلة کلية السياحة والفنادق جامعة المنصورة                          0.0
#
#                                                    % publications 2024
# journal
# Scientific Reports                                            0.008367
# PLoS ONE                                                      0.004562
# Astronomy and Astrophysics                                    0.006258
# Monthly Notices of the Royal Astronomical Society             0.004047
# Journal of Clinical Oncology                                  0.005117
# ...                                                                ...
# 日本物理学会講演概要集 70.2                                              0.000000
# 日本物理学会講演概要集 70.1                                              0.000000
# 日本消化器がん検診学会雑誌                                                 0.000000
# مجلة کلیة الآداب القاهرة                                      0.000010
# مجلة کلية السياحة والفنادق جامعة المنصورة                     0.000000
#
# [37399 rows x 26 columns]

# %%
interest = 'publisher'

grouped = df.groupby(interest).count()[['doi']].sort_values('doi', ascending = False).rename(columns = {'doi' : '# publications'})
grouped['% publications'] = (grouped['# publications'] / df.doi.nunique())
print('The HHF is: ', sum(grouped['% publications']**2))

for year in range(2013, 2025):
    df_year = df[df['publication_year'] == year]
    grouped_year = df_year.groupby(interest).count()[['doi']].sort_values('doi', ascending = False).rename(columns = {'doi' : f'# publications {year}'})
    grouped_year[f'% publications {year}'] = (grouped_year[f'# publications {year}'] / df_year.doi.nunique())
    grouped = grouped.merge(grouped_year, left_index = True, right_index = True, how = 'left').fillna(0)
    print(f'The HHF in {year} is: ', sum(grouped_year[f'% publications {year}']**2))
grouped
# Out:
# The HHF is:  0.09497703629448288
# The HHF in 2013 is:  0.10260000000000001
# The HHF in 2014 is:  0.1176033106108357
# The HHF in 2015 is:  0.10751485031125216
# The HHF in 2016 is:  0.11040617764655404
# The HHF in 2017 is:  0.1034693339590879
# The HHF in 2018 is:  0.10005418838990834
# The HHF in 2019 is:  0.0894483992017019
# The HHF in 2020 is:  0.09036613952109504
# The HHF in 2021 is:  0.084227597113723
# The HHF in 2022 is:  0.08195356901864419
# The HHF in 2023 is:  0.09026168956903324
# The HHF in 2024 is:  0.08409693451695317
#                                                     # publications  \
# publisher
# Elsevier BV                                                 354662
# Wiley                                                        86170
# Springer Science+Business Media                              71552
# Multidisciplinary Digital Publishing Institute               38107
# Oxford University Press                                      37935
# ...                                                            ...
# Academia Brasileira de Audiologia                                1
# Institución Universitaria Americana                              1
# Innovative Journal Solutions                                     1
# Institut Seni Indonesia (ISI) Surakarta                          1
# suburban : zeitschrift für kritische stadtforsc...               1
#
#                                                     % publications  \
# publisher
# Elsevier BV                                           2.851146e-01
# Wiley                                                 6.927250e-02
# Springer Science+Business Media                       5.752101e-02
# Multidisciplinary Digital Publishing Institute        3.063441e-02
# Oxford University Press                               3.049614e-02
# ...                                                            ...
# Academia Brasileira de Audiologia                     8.039050e-07
# Institución Universitaria Americana                   8.039050e-07
# Innovative Journal Solutions                          8.039050e-07
# Institut Seni Indonesia (ISI) Surakarta               8.039050e-07
# suburban : zeitschrift für kritische stadtforsc...    8.039050e-07
#
#                                                     # publications 2013  \
# publisher
# Elsevier BV                                                        44.0
# Wiley                                                               8.0
# Springer Science+Business Media                                    11.0
# Multidisciplinary Digital Publishing Institute                      0.0
# Oxford University Press                                             9.0
# ...                                                                 ...
# Academia Brasileira de Audiologia                                   0.0
# Institución Universitaria Americana                                 0.0
# Innovative Journal Solutions                                        0.0
# Institut Seni Indonesia (ISI) Surakarta                             0.0
# suburban : zeitschrift für kritische stadtforsc...                  0.0
#
#                                                     % publications 2013  \
# publisher
# Elsevier BV                                                       0.220
# Wiley                                                             0.040
# Springer Science+Business Media                                   0.055
# Multidisciplinary Digital Publishing Institute                    0.000
# Oxford University Press                                           0.045
# ...                                                                 ...
# Academia Brasileira de Audiologia                                 0.000
# Institución Universitaria Americana                               0.000
# Innovative Journal Solutions                                      0.000
# Institut Seni Indonesia (ISI) Surakarta                           0.000
# suburban : zeitschrift für kritische stadtforsc...                0.000
#
#                                                     # publications 2014  \
# publisher
# Elsevier BV                                                     35119.0
# Wiley                                                            7680.0
# Springer Science+Business Media                                  6686.0
# Multidisciplinary Digital Publishing Institute                    371.0
# Oxford University Press                                          2988.0
# ...                                                                 ...
# Academia Brasileira de Audiologia                                   0.0
# Institución Universitaria Americana                                 1.0
# Innovative Journal Solutions                                        0.0
# Institut Seni Indonesia (ISI) Surakarta                             0.0
# suburban : zeitschrift für kritische stadtforsc...                  0.0
#
#                                                     % publications 2014  \
# publisher
# Elsevier BV                                                    0.322459
# Wiley                                                          0.070517
# Springer Science+Business Media                                0.061390
# Multidisciplinary Digital Publishing Institute                 0.003406
# Oxford University Press                                        0.027435
# ...                                                                 ...
# Academia Brasileira de Audiologia                              0.000000
# Institución Universitaria Americana                            0.000009
# Innovative Journal Solutions                                   0.000000
# Institut Seni Indonesia (ISI) Surakarta                        0.000000
# suburban : zeitschrift für kritische stadtforsc...             0.000000
#
#                                                     # publications 2015  \
# publisher
# Elsevier BV                                                     33321.0
# Wiley                                                            7576.0
# Springer Science+Business Media                                  6899.0
# Multidisciplinary Digital Publishing Institute                    518.0
# Oxford University Press                                          2995.0
# ...                                                                 ...
# Academia Brasileira de Audiologia                                   0.0
# Institución Universitaria Americana                                 0.0
# Innovative Journal Solutions                                        0.0
# Institut Seni Indonesia (ISI) Surakarta                             0.0
# suburban : zeitschrift für kritische stadtforsc...                  0.0
#
#                                                     % publications 2015  \
# publisher
# Elsevier BV                                                    0.306135
# Wiley                                                          0.069604
# Springer Science+Business Media                                0.063384
# Multidisciplinary Digital Publishing Institute                 0.004759
# Oxford University Press                                        0.027516
# ...                                                                 ...
# Academia Brasileira de Audiologia                              0.000000
# Institución Universitaria Americana                            0.000000
# Innovative Journal Solutions                                   0.000000
# Institut Seni Indonesia (ISI) Surakarta                        0.000000
# suburban : zeitschrift für kritische stadtforsc...             0.000000
#
#                                                     # publications 2016  \
# publisher
# Elsevier BV                                                     34980.0
# Wiley                                                            7777.0
# Springer Science+Business Media                                  6659.0
# Multidisciplinary Digital Publishing Institute                    678.0
# Oxford University Press                                          3244.0
# ...                                                                 ...
# Academia Brasileira de Audiologia                                   0.0
# Institución Universitaria Americana                                 0.0
# Innovative Journal Solutions                                        0.0
# Institut Seni Indonesia (ISI) Surakarta                             0.0
# suburban : zeitschrift für kritische stadtforsc...                  0.0
#
#                                                     % publications 2016  ...  \
# publisher                                                                ...
# Elsevier BV                                                    0.311879  ...
# Wiley                                                          0.069339  ...
# Springer Science+Business Media                                0.059371  ...
# Multidisciplinary Digital Publishing Institute                 0.006045  ...
# Oxford University Press                                        0.028923  ...
# ...                                                                 ...  ...
# Academia Brasileira de Audiologia                              0.000000  ...
# Institución Universitaria Americana                            0.000000  ...
# Innovative Journal Solutions                                   0.000000  ...
# Institut Seni Indonesia (ISI) Surakarta                        0.000000  ...
# suburban : zeitschrift für kritische stadtforsc...             0.000000  ...
#
#                                                     # publications 2020  \
# publisher
# Elsevier BV                                                     33373.0
# Wiley                                                            8794.0
# Springer Science+Business Media                                  6534.0
# Multidisciplinary Digital Publishing Institute                   5056.0
# Oxford University Press                                          3727.0
# ...                                                                 ...
# Academia Brasileira de Audiologia                                   0.0
# Institución Universitaria Americana                                 0.0
# Innovative Journal Solutions                                        0.0
# Institut Seni Indonesia (ISI) Surakarta                             0.0
# suburban : zeitschrift für kritische stadtforsc...                  0.0
#
#                                                     % publications 2020  \
# publisher
# Elsevier BV                                                    0.275189
# Wiley                                                          0.072514
# Springer Science+Business Media                                0.053878
# Multidisciplinary Digital Publishing Institute                 0.041691
# Oxford University Press                                        0.030732
# ...                                                                 ...
# Academia Brasileira de Audiologia                              0.000000
# Institución Universitaria Americana                            0.000000
# Innovative Journal Solutions                                   0.000000
# Institut Seni Indonesia (ISI) Surakarta                        0.000000
# suburban : zeitschrift für kritische stadtforsc...             0.000000
#
#                                                     # publications 2021  \
# publisher
# Elsevier BV                                                     31824.0
# Wiley                                                            8058.0
# Springer Science+Business Media                                  6753.0
# Multidisciplinary Digital Publishing Institute                   7065.0
# Oxford University Press                                          3587.0
# ...                                                                 ...
# Academia Brasileira de Audiologia                                   0.0
# Institución Universitaria Americana                                 0.0
# Innovative Journal Solutions                                        0.0
# Institut Seni Indonesia (ISI) Surakarta                             0.0
# suburban : zeitschrift für kritische stadtforsc...                  0.0
#
#                                                     % publications 2021  \
# publisher
# Elsevier BV                                                    0.262572
# Wiley                                                          0.066485
# Springer Science+Business Media                                0.055717
# Multidisciplinary Digital Publishing Institute                 0.058292
# Oxford University Press                                        0.029595
# ...                                                                 ...
# Academia Brasileira de Audiologia                              0.000000
# Institución Universitaria Americana                            0.000000
# Innovative Journal Solutions                                   0.000000
# Institut Seni Indonesia (ISI) Surakarta                        0.000000
# suburban : zeitschrift für kritische stadtforsc...             0.000000
#
#                                                     # publications 2022  \
# publisher
# Elsevier BV                                                     30077.0
# Wiley                                                            7462.0
# Springer Science+Business Media                                  6620.0
# Multidisciplinary Digital Publishing Institute                   7521.0
# Oxford University Press                                          3411.0
# ...                                                                 ...
# Academia Brasileira de Audiologia                                   1.0
# Institución Universitaria Americana                                 0.0
# Innovative Journal Solutions                                        1.0
# Institut Seni Indonesia (ISI) Surakarta                             0.0
# suburban : zeitschrift für kritische stadtforsc...                  0.0
#
#                                                     % publications 2022  \
# publisher
# Elsevier BV                                                    0.257134
# Wiley                                                          0.063794
# Springer Science+Business Media                                0.056596
# Multidisciplinary Digital Publishing Institute                 0.064299
# Oxford University Press                                        0.029161
# ...                                                                 ...
# Academia Brasileira de Audiologia                              0.000009
# Institución Universitaria Americana                            0.000000
# Innovative Journal Solutions                                   0.000009
# Institut Seni Indonesia (ISI) Surakarta                        0.000000
# suburban : zeitschrift für kritische stadtforsc...             0.000000
#
#                                                     # publications 2023  \
# publisher
# Elsevier BV                                                     31750.0
# Wiley                                                            7565.0
# Springer Science+Business Media                                  6196.0
# Multidisciplinary Digital Publishing Institute                   6390.0
# Oxford University Press                                          3647.0
# ...                                                                 ...
# Academia Brasileira de Audiologia                                   0.0
# Institución Universitaria Americana                                 0.0
# Innovative Journal Solutions                                        0.0
# Institut Seni Indonesia (ISI) Surakarta                             1.0
# suburban : zeitschrift für kritische stadtforsc...                  0.0
#
#                                                     % publications 2023  \
# publisher
# Elsevier BV                                                    0.274985
# Wiley                                                          0.065520
# Springer Science+Business Media                                0.053663
# Multidisciplinary Digital Publishing Institute                 0.055343
# Oxford University Press                                        0.031586
# ...                                                                 ...
# Academia Brasileira de Audiologia                              0.000000
# Institución Universitaria Americana                            0.000000
# Innovative Journal Solutions                                   0.000000
# Institut Seni Indonesia (ISI) Surakarta                        0.000009
# suburban : zeitschrift für kritische stadtforsc...             0.000000
#
#                                                     # publications 2024  \
# publisher
# Elsevier BV                                                     25348.0
# Wiley                                                            8124.0
# Springer Science+Business Media                                  6172.0
# Multidisciplinary Digital Publishing Institute                   4568.0
# Oxford University Press                                          3668.0
# ...                                                                 ...
# Academia Brasileira de Audiologia                                   0.0
# Institución Universitaria Americana                                 0.0
# Innovative Journal Solutions                                        0.0
# Institut Seni Indonesia (ISI) Surakarta                             0.0
# suburban : zeitschrift für kritische stadtforsc...                  0.0
#
#                                                     % publications 2024
# publisher
# Elsevier BV                                                    0.255849
# Wiley                                                          0.081999
# Springer Science+Business Media                                0.062297
# Multidisciplinary Digital Publishing Institute                 0.046107
# Oxford University Press                                        0.037023
# ...                                                                 ...
# Academia Brasileira de Audiologia                              0.000000
# Institución Universitaria Americana                            0.000000
# Innovative Journal Solutions                                   0.000000
# Institut Seni Indonesia (ISI) Surakarta                        0.000000
# suburban : zeitschrift für kritische stadtforsc...             0.000000
#
# [4106 rows x 26 columns]

# %% [markdown]
# **APC vs non-APC**

# %%
df_apc = df[~df.apc_list.isna()].reset_index(drop = True)
df_apc.to_parquet("../data/interim/preliminary/fr_p3_apc.parquet", index = False)
df_apc.groupby('publication_year').count()[['doi']] / df.groupby('publication_year').count()[['doi']]
# Out:
#                        doi
# publication_year
# 2013              0.605000
# 2014              0.517207
# 2015              0.516005
# 2016              0.517836
# 2017              0.521101
# 2018              0.517852
# 2019              0.531770
# 2020              0.553116
# 2021              0.554517
# 2022              0.558023
# 2023              0.560917
# 2024              0.583907

# %% [markdown]
# **Author sector indicators**

# %%
df_filtered = df[df['ins_type'].apply(lambda x: bool(x & {'company', 'non-profit'}))]
df_filtered.groupby('publication_year').count()[['doi']] / df.groupby('publication_year').count()[['doi']]
# Out:
#                        doi
# publication_year
# 2013              0.255000
# 2014              0.093986
# 2015              0.098407
# 2016              0.097781
# 2017              0.100460
# 2018              0.101256
# 2019              0.104353
# 2020              0.103510
# 2021              0.105799
# 2022              0.105925
# 2023              0.108123
# 2024              0.111018

# %% [markdown]
# **Articles with more than 100 authors**

# %%
df_100 = df[df['#_authors'] == 100].reset_index(drop = True)
df_100.to_parquet("../data/interim/preliminary/fr_p3_fr_gt100_authors.parquet", index = False)
df_100.groupby('publication_year').count()[['doi']] / df.groupby('publication_year').count()[['doi']]
# Out:
#                        doi
# publication_year
# 2013              0.035000
# 2014              0.004710
# 2015              0.004291
# 2016              0.004939
# 2017              0.005014
# 2018              0.004938
# 2019              0.005047
# 2020              0.005261
# 2021              0.005363
# 2022              0.005737
# 2023              0.007197
# 2024              0.007853

# %% [markdown]
# ### Phase 4: Corresponding authors

# %%
interest = ['doi', 'publication_year', 'language', 'authorships', 'primary_location', 'topics', 'open_access', 'apc_list']
keys = ['doi', 'publication_year', 'language', 'field_names', 'journal', 'publisher', 'ins_type', '#_authors', 'oa_status', 'apc_list', 'corresponding', 'countries']
records = []
for year in tqdm(range(2013, 2025)):
    with open(f"../data/interim/FranceInitialAPI/openalex_french_authors_{year}_v2.jsonl", "rb") as f:
        for line in f:
            rec = orjson.loads(line)
            if not rec.get("doi"): # Skip records without DOI
                continue
            filtered = {k: rec.get(k) for k in interest} # Keep only the fields we care about

            # Extract field_names from topics
            topics = filtered.get("topics") or []
            filtered["field_names"] = {c.get("field", {}).get("display_name") for c in topics if c.get("field")}

            # Extract journal and publisher from primary_location
            pl = filtered.get("primary_location") or {}
            source = pl.get("source") or {}
            filtered["journal"] = source.get("display_name")
            filtered["publisher"] = source.get("host_organization_name")

            # Extract institution types and number of authors
            authorships = filtered.get("authorships") or []
            filtered["ins_type"] = {inst.get("type") 
                                    for auth in authorships 
                                    for inst in auth.get("institutions", []) if inst.get("type")}
            filtered["corresponding"] = [auth.get("is_corresponding") for auth in authorships]
            filtered["countries"] = [auth.get("countries") for auth in authorships]
            filtered["#_authors"] = len(authorships)
            
            o_a = filtered.get("open_access") or {}
            filtered["oa_status"] = o_a.get("oa_status")

            records.append({k: filtered.get(k) for k in keys})

df = pd.DataFrame(records)
df
# Out:
# 100%|██████████| 12/12 [01:41<00:00,  8.46s/it]
#                                                        doi  publication_year  \
# 0              https://doi.org/10.1051/0004-6361/201322068              2013
# 1                      https://doi.org/10.1038/nature12477              2013
# 2             https://doi.org/10.1097/ccm.0b013e31827e83af              2013
# 3                https://doi.org/10.1007/s00134-012-2769-8              2013
# 4                    https://doi.org/10.1038/nnano.2013.46              2013
# ...                                                    ...               ...
# 1243923  https://doi.org/10.20914/2310-1202-2024-4-178-184              2024
# 1243924                  https://doi.org/10.7202/1121520ar              2024
# 1243925                  https://doi.org/10.7202/1121518ar              2024
# 1243926                      https://doi.org/10.4000/11ndt              2024
# 1243927                       https://doi.org/10.2427/5975              2024
#
#         language                                        field_names  \
# 0             en          {Physics and Astronomy, Computer Science}
# 1             en  {Medicine, Biochemistry, Genetics and Molecula...
# 2             en                                         {Medicine}
# 3             en                                         {Medicine}
# 4             en                                {Materials Science}
# ...          ...                                                ...
# 1243923     None  {Environmental Science, Agricultural and Biolo...
# 1243924       fr             {Social Sciences, Arts and Humanities}
# 1243925       fr                                  {Social Sciences}
# 1243926       fr                                  {Social Sciences}
# 1243927       en  {Health Professions, Economics, Econometrics a...
#
#                                                    journal  \
# 0                               Astronomy and Astrophysics
# 1                                                   Nature
# 2                                   Critical Care Medicine
# 3                                  Intensive Care Medicine
# 4                                    Nature Nanotechnology
# ...                                                    ...
# 1243923  Proceedings of the Voronezh State University o...
# 1243924           Revue d histoire de l Amérique française
# 1243925           Revue d histoire de l Amérique française
# 1243926                                 Histoire Politique
# 1243927                   Italian Journal of Public Health
#
#                                                  publisher  \
# 0                                             EDP Sciences
# 1                                         Nature Portfolio
# 2                            Lippincott Williams & Wilkins
# 3                          Springer Science+Business Media
# 4                                         Nature Portfolio
# ...                                                    ...
# 1243923  Voronezh State University of Engineering Techn...
# 1243924        Institut d'histoire de l'Amérique française
# 1243925        Institut d'histoire de l'Amérique française
# 1243926                                               None
# 1243927                                           Prex spa
#
#                                                   ins_type  #_authors  \
# 0             {education, facility, nonprofit, government}         44
# 1        {education, government, facility, other, healt...         70
# 2                         {education, company, healthcare}         23
# 3                                  {education, healthcare}         23
# 4                                               {facility}          2
# ...                                                    ...        ...
# 1243923                              {education, facility}          5
# 1243924                                        {education}          1
# 1243925                                        {education}          1
# 1243926                                         {facility}          1
# 1243927                                       {government}          1
#
#         oa_status                                           apc_list  \
# 0          bronze                                               None
# 1          bronze  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 2          closed                                               None
# 3          bronze  {'value': 3690, 'currency': 'EUR', 'value_usd'...
# 4           green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# ...           ...                                                ...
# 1243923   diamond                                               None
# 1243924   diamond                                               None
# 1243925   diamond                                               None
# 1243926    bronze                                               None
# 1243927    hybrid                                               None
#
#                                              corresponding  \
# 0        [False, False, False, False, False, False, Fal...
# 1        [False, False, False, False, False, False, Fal...
# 2        [False, False, False, False, False, False, Fal...
# 3        [True, False, False, False, False, False, Fals...
# 4                                           [False, False]
# ...                                                    ...
# 1243923                 [True, False, False, False, False]
# 1243924                                             [True]
# 1243925                                             [True]
# 1243926                                             [True]
# 1243927                                             [True]
#
#                                                  countries
# 0        [[DE], [US], [FR, US], [FR, US], [FR, US], [US...
# 1        [[GB], [GB], [GB], [CA], [GB], [GB], [GB], [GB...
# 2        [[US], [US], [GB], [FR], [DE], [US], [US], [IL...
# 3        [[US], [US], [GB], [FR], [DE], [US], [US], [IL...
# 4                                               [[], [FR]]
# ...                                                    ...
# 1243923                     [[RU], [RU], [FR], [RU], [RU]]
# 1243924                                             [[FR]]
# 1243925                                             [[FR]]
# 1243926                                             [[FR]]
# 1243927                                             [[FR]]
#
# [1243928 rows x 12 columns]

# %% [markdown]
# **No corresponding**

# %%
df_nocorresponding = df[df['corresponding'].apply(lambda x: all(v is False for v in x))].reset_index(drop = True)
df_nocorresponding
# Out:
#                                                  doi  publication_year  \
# 0        https://doi.org/10.1051/0004-6361/201322068              2013
# 1                https://doi.org/10.1038/nature12477              2013
# 2       https://doi.org/10.1097/ccm.0b013e31827e83af              2013
# 3              https://doi.org/10.1038/nnano.2013.46              2013
# 4                https://doi.org/10.1093/nar/gkt1178              2013
# ...                                              ...               ...
# 614558             https://doi.org/10.7202/1120388ar              2024
# 614559             https://doi.org/10.7202/1120383ar              2024
# 614560             https://doi.org/10.7202/1120375ar              2024
# 614561             https://doi.org/10.7202/1120374ar              2024
# 614562     https://doi.org/10.1017/s0021875825000179              2024
#
#        language                                        field_names  \
# 0            en          {Physics and Astronomy, Computer Science}
# 1            en  {Medicine, Biochemistry, Genetics and Molecula...
# 2            en                                         {Medicine}
# 3            en                                {Materials Science}
# 4            en  {Engineering, Biochemistry, Genetics and Molec...
# ...         ...                                                ...
# 614558       fr                                                 {}
# 614559       fr                                                 {}
# 614560       fr                                                 {}
# 614561       fr                                                 {}
# 614562       en                                                 {}
#
#                             journal                      publisher  \
# 0        Astronomy and Astrophysics                   EDP Sciences
# 1                            Nature               Nature Portfolio
# 2            Critical Care Medicine  Lippincott Williams & Wilkins
# 3             Nature Nanotechnology               Nature Portfolio
# 4            Nucleic Acids Research        Oxford University Press
# ...                             ...                            ...
# 614558         Études/Inuit/Studies                     Q114618608
# 614559         Études/Inuit/Studies                     Q114618608
# 614560         Études/Inuit/Studies                     Q114618608
# 614561         Études/Inuit/Studies                     Q114618608
# 614562  Journal of American Studies     Cambridge University Press
#
#                                                  ins_type  #_authors  \
# 0            {education, facility, nonprofit, government}         44
# 1       {education, government, facility, other, healt...         70
# 2                        {education, company, healthcare}         23
# 3                                              {facility}          2
# 4                                            {government}          5
# ...                                                   ...        ...
# 614558                              {education, facility}          2
# 614559                              {education, facility}          3
# 614560                              {education, facility}          3
# 614561                              {education, facility}          3
# 614562                                        {education}          6
#
#        oa_status                                           apc_list  \
# 0         bronze                                               None
# 1         bronze  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 2         closed                                               None
# 3          green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 4           gold  {'value': 3630, 'currency': 'USD', 'value_usd'...
# ...          ...                                                ...
# 614558   diamond                                               None
# 614559   diamond                                               None
# 614560   diamond                                               None
# 614561   diamond                                               None
# 614562    closed                                               None
#
#                                             corresponding  \
# 0       [False, False, False, False, False, False, Fal...
# 1       [False, False, False, False, False, False, Fal...
# 2       [False, False, False, False, False, False, Fal...
# 3                                          [False, False]
# 4                     [False, False, False, False, False]
# ...                                                   ...
# 614558                                     [False, False]
# 614559                              [False, False, False]
# 614560                              [False, False, False]
# 614561                              [False, False, False]
# 614562         [False, False, False, False, False, False]
#
#                                                 countries
# 0       [[DE], [US], [FR, US], [FR, US], [FR, US], [US...
# 1       [[GB], [GB], [GB], [CA], [GB], [GB], [GB], [GB...
# 2       [[US], [US], [GB], [FR], [DE], [US], [US], [IL...
# 3                                              [[], [FR]]
# 4                          [[FR], [FR], [FR], [FR], [FR]]
# ...                                                   ...
# 614558                                         [[], [FR]]
# 614559                               [[], [CA, FR], [CA]]
# 614560                               [[], [CA, FR], [CA]]
# 614561                               [[], [CA, FR], [CA]]
# 614562                 [[GB], [], [FR], [FR], [FR], [FR]]
#
# [614563 rows x 12 columns]

# %% [markdown]
# One author

# %%
df_nocorresponding_one = df_nocorresponding[df_nocorresponding['#_authors'] == 1].reset_index(drop = True)
df_nocorresponding_one
# Out:
# Empty DataFrame
# Columns: [doi, publication_year, language, field_names, journal, publisher, ins_type, #_authors, oa_status, apc_list, corresponding, countries]
# Index: []

# %% [markdown]
# French language

# %%
df_nocorresponding_french = df_nocorresponding[df_nocorresponding.language == 'fr'].reset_index(drop = True)
df_nocorresponding_french.to_parquet("../data/interim/preliminary/fr_p4B_french_language.parquet", index = False)
df_nocorresponding_french.groupby('publication_year').count()[['doi']] / df.groupby('publication_year').count()[['doi']]
# Out:
#                        doi
# publication_year
# 2013                   NaN
# 2014              0.107566
# 2015              0.064331
# 2016              0.045997
# 2017              0.046472
# 2018              0.052604
# 2019              0.049631
# 2020              0.049648
# 2021              0.048399
# 2022              0.055912
# 2023              0.045071
# 2024              0.040899

# %% [markdown]
# All authors missing country

# %%
df_nocorresponding['missing'] = df_nocorresponding.countries.apply(lambda lst: all(len(x) == 0 for x in lst))
df_nocorresponding_missing = df_nocorresponding[df_nocorresponding['missing'] == True].reset_index(drop = True)
df_nocorresponding_missing
# Out:
# Empty DataFrame
# Columns: [doi, publication_year, language, field_names, journal, publisher, ins_type, #_authors, oa_status, apc_list, corresponding, countries, missing]
# Index: []

# %% [markdown]
# **Corresponding**

# %%
df_corresponding = df[~df.doi.isin(df_nocorresponding.doi)].reset_index(drop = True)
df_corresponding
# Out:
#                                                       doi  publication_year  \
# 0               https://doi.org/10.1007/s00134-012-2769-8              2013
# 1              https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 2           https://doi.org/10.1016/s1474-4422(13)70124-8              2013
# 3                     https://doi.org/10.1038/nature12506              2013
# 4            https://doi.org/10.1016/j.immuni.2013.10.003              2013
# ...                                                   ...               ...
# 629360  https://doi.org/10.20914/2310-1202-2024-4-178-184              2024
# 629361                  https://doi.org/10.7202/1121520ar              2024
# 629362                  https://doi.org/10.7202/1121518ar              2024
# 629363                      https://doi.org/10.4000/11ndt              2024
# 629364                       https://doi.org/10.2427/5975              2024
#
#        language                                        field_names  \
# 0            en                                         {Medicine}
# 1            en                                         {Medicine}
# 2            en                                         {Medicine}
# 3            en  {Medicine, Biochemistry, Genetics and Molecula...
# 4            en            {Medicine, Immunology and Microbiology}
# ...         ...                                                ...
# 629360     None  {Environmental Science, Agricultural and Biolo...
# 629361       fr             {Social Sciences, Arts and Humanities}
# 629362       fr                                  {Social Sciences}
# 629363       fr                                  {Social Sciences}
# 629364       en  {Health Professions, Economics, Econometrics a...
#
#                                                   journal  \
# 0                                 Intensive Care Medicine
# 1                              European Journal of Cancer
# 2                                    The Lancet Neurology
# 3                                                  Nature
# 4                                                Immunity
# ...                                                   ...
# 629360  Proceedings of the Voronezh State University o...
# 629361           Revue d histoire de l Amérique française
# 629362           Revue d histoire de l Amérique française
# 629363                                 Histoire Politique
# 629364                   Italian Journal of Public Health
#
#                                                 publisher  \
# 0                         Springer Science+Business Media
# 1                                             Elsevier BV
# 2                                             Elsevier BV
# 3                                        Nature Portfolio
# 4                                              Cell Press
# ...                                                   ...
# 629360  Voronezh State University of Engineering Techn...
# 629361        Institut d'histoire de l'Amérique française
# 629362        Institut d'histoire de l'Amérique française
# 629363                                               None
# 629364                                           Prex spa
#
#                                                  ins_type  #_authors  \
# 0                                 {education, healthcare}         23
# 1              {government, other, education, healthcare}          8
# 2           {education, facility, government, healthcare}         36
# 3       {education, company, government, facility, hea...         82
# 4           {government, facility, education, healthcare}         17
# ...                                                   ...        ...
# 629360                              {education, facility}          5
# 629361                                        {education}          1
# 629362                                        {education}          1
# 629363                                         {facility}          1
# 629364                                       {government}          1
#
#        oa_status                                           apc_list  \
# 0         bronze  {'value': 3690, 'currency': 'EUR', 'value_usd'...
# 1         bronze  {'value': 3800, 'currency': 'USD', 'value_usd'...
# 2          green  {'value': 6300, 'currency': 'USD', 'value_usd'...
# 3          green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 4         bronze  {'value': 9080, 'currency': 'USD', 'value_usd'...
# ...          ...                                                ...
# 629360   diamond                                               None
# 629361   diamond                                               None
# 629362   diamond                                               None
# 629363    bronze                                               None
# 629364    hybrid                                               None
#
#                                             corresponding  \
# 0       [True, False, False, False, False, False, Fals...
# 1       [True, False, False, False, False, False, Fals...
# 2       [True, False, False, False, False, False, Fals...
# 3       [False, False, False, False, False, False, Fal...
# 4       [False, False, False, False, False, False, Fal...
# ...                                                   ...
# 629360                 [True, False, False, False, False]
# 629361                                             [True]
# 629362                                             [True]
# 629363                                             [True]
# 629364                                             [True]
#
#                                                 countries
# 0       [[US], [US], [GB], [FR], [DE], [US], [US], [IL...
# 1        [[FR], [FR], [FR], [IT], [NL], [IE], [FR], [FR]]
# 2       [[GB], [CA], [NL], [FR], [AT], [CA], [AU], [GB...
# 3       [[MA], [DK], [CN], [MA], [BE], [BE], [MA], [CN...
# 4       [[FR], [FR], [FR], [FR], [DE, FR], [AT], [FR],...
# ...                                                   ...
# 629360                     [[RU], [RU], [FR], [RU], [RU]]
# 629361                                             [[FR]]
# 629362                                             [[FR]]
# 629363                                             [[FR]]
# 629364                                             [[FR]]
#
# [629365 rows x 12 columns]

# %% [markdown]
# One Corresponding

# %%
df_corresponding_one = df_corresponding[df_corresponding['#_authors'] == 1].reset_index(drop = True)
df_corresponding_one.to_parquet("../data/interim/preliminary/fr_p4A_single_CA.parquet", index = False)
df_corresponding_one.groupby('publication_year').count()[['doi']] / df.groupby('publication_year').count()[['doi']]
# Out:
#                        doi
# publication_year
# 2013              0.015000
# 2014              0.138013
# 2015              0.143251
# 2016              0.144384
# 2017              0.144591
# 2018              0.152430
# 2019              0.147988
# 2020              0.138390
# 2021              0.143192
# 2022              0.145148
# 2023              0.137059
# 2024              0.099269

# %% [markdown]
# All authors missing country

# %%
df_corresponding['missing'] = df_corresponding.countries.apply(lambda lst: all(len(x) == 0 for x in lst))
df_corresponding_missing = df_corresponding[df_corresponding['missing'] == True].reset_index(drop = True)
df_corresponding_missing
# Out:
# Empty DataFrame
# Columns: [doi, publication_year, language, field_names, journal, publisher, ins_type, #_authors, oa_status, apc_list, corresponding, countries, missing, whole_french, any_french]
# Index: []

# %% [markdown]
# ### Phase 5: Corresponding with data

# %% [markdown]
# **Corresponding**

# %%
df_corresponding
# Out:
#                                                       doi  publication_year  \
# 0               https://doi.org/10.1007/s00134-012-2769-8              2013
# 1              https://doi.org/10.1016/j.ejca.2012.12.027              2013
# 2           https://doi.org/10.1016/s1474-4422(13)70124-8              2013
# 3                     https://doi.org/10.1038/nature12506              2013
# 4            https://doi.org/10.1016/j.immuni.2013.10.003              2013
# ...                                                   ...               ...
# 629360  https://doi.org/10.20914/2310-1202-2024-4-178-184              2024
# 629361                  https://doi.org/10.7202/1121520ar              2024
# 629362                  https://doi.org/10.7202/1121518ar              2024
# 629363                      https://doi.org/10.4000/11ndt              2024
# 629364                       https://doi.org/10.2427/5975              2024
#
#        language                                        field_names  \
# 0            en                                         {Medicine}
# 1            en                                         {Medicine}
# 2            en                                         {Medicine}
# 3            en  {Medicine, Biochemistry, Genetics and Molecula...
# 4            en            {Medicine, Immunology and Microbiology}
# ...         ...                                                ...
# 629360     None  {Environmental Science, Agricultural and Biolo...
# 629361       fr             {Social Sciences, Arts and Humanities}
# 629362       fr                                  {Social Sciences}
# 629363       fr                                  {Social Sciences}
# 629364       en  {Health Professions, Economics, Econometrics a...
#
#                                                   journal  \
# 0                                 Intensive Care Medicine
# 1                              European Journal of Cancer
# 2                                    The Lancet Neurology
# 3                                                  Nature
# 4                                                Immunity
# ...                                                   ...
# 629360  Proceedings of the Voronezh State University o...
# 629361           Revue d histoire de l Amérique française
# 629362           Revue d histoire de l Amérique française
# 629363                                 Histoire Politique
# 629364                   Italian Journal of Public Health
#
#                                                 publisher  \
# 0                         Springer Science+Business Media
# 1                                             Elsevier BV
# 2                                             Elsevier BV
# 3                                        Nature Portfolio
# 4                                              Cell Press
# ...                                                   ...
# 629360  Voronezh State University of Engineering Techn...
# 629361        Institut d'histoire de l'Amérique française
# 629362        Institut d'histoire de l'Amérique française
# 629363                                               None
# 629364                                           Prex spa
#
#                                                  ins_type  #_authors  \
# 0                                 {education, healthcare}         23
# 1              {government, other, education, healthcare}          8
# 2           {education, facility, government, healthcare}         36
# 3       {education, company, government, facility, hea...         82
# 4           {government, facility, education, healthcare}         17
# ...                                                   ...        ...
# 629360                              {education, facility}          5
# 629361                                        {education}          1
# 629362                                        {education}          1
# 629363                                         {facility}          1
# 629364                                       {government}          1
#
#        oa_status                                           apc_list  \
# 0         bronze  {'value': 3690, 'currency': 'EUR', 'value_usd'...
# 1         bronze  {'value': 3800, 'currency': 'USD', 'value_usd'...
# 2          green  {'value': 6300, 'currency': 'USD', 'value_usd'...
# 3          green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 4         bronze  {'value': 9080, 'currency': 'USD', 'value_usd'...
# ...          ...                                                ...
# 629360   diamond                                               None
# 629361   diamond                                               None
# 629362   diamond                                               None
# 629363    bronze                                               None
# 629364    hybrid                                               None
#
#                                             corresponding  \
# 0       [True, False, False, False, False, False, Fals...
# 1       [True, False, False, False, False, False, Fals...
# 2       [True, False, False, False, False, False, Fals...
# 3       [False, False, False, False, False, False, Fal...
# 4       [False, False, False, False, False, False, Fal...
# ...                                                   ...
# 629360                 [True, False, False, False, False]
# 629361                                             [True]
# 629362                                             [True]
# 629363                                             [True]
# 629364                                             [True]
#
#                                                 countries
# 0       [[US], [US], [GB], [FR], [DE], [US], [US], [IL...
# 1        [[FR], [FR], [FR], [IT], [NL], [IE], [FR], [FR]]
# 2       [[GB], [CA], [NL], [FR], [AT], [CA], [AU], [GB...
# 3       [[MA], [DK], [CN], [MA], [BE], [BE], [MA], [CN...
# 4       [[FR], [FR], [FR], [FR], [DE, FR], [AT], [FR],...
# ...                                                   ...
# 629360                     [[RU], [RU], [FR], [RU], [RU]]
# 629361                                             [[FR]]
# 629362                                             [[FR]]
# 629363                                             [[FR]]
# 629364                                             [[FR]]
#
# [629365 rows x 12 columns]

# %% [markdown]
# All french

# %%
df_corresponding['whole_french'] = df_corresponding.countries.apply(lambda lst: all('FR' in x for x in lst))
df_corresponding_wholefrench = df_corresponding[df_corresponding['whole_french'] == True].reset_index(drop = True)
df_corresponding_wholefrench.to_parquet("../data/interim/preliminary/fr_p5_CA_yes_allFR.parquet", index = False)

total_per_year = df.groupby('publication_year')['doi'].nunique()
total_wholefrench= df_corresponding_wholefrench.groupby('publication_year')['doi'].nunique()

grouped_total = total_wholefrench / total_per_year
grouped_oa = df_corresponding_wholefrench[df_corresponding_wholefrench.oa_status != 'closed'].groupby('publication_year')['doi'].nunique() / total_per_year
grouped_apc = df_corresponding_wholefrench[~df_corresponding_wholefrench.apc_list.isna()].groupby('publication_year')['doi'].nunique() / total_per_year

grouped = pd.concat([grouped_oa.rename('openaccess'), grouped_apc.rename('apc_list'), grouped_total.rename('total')], axis = 1)
grouped
# Out:
#                   openaccess  apc_list     total
# publication_year
# 2013                0.025000  0.040000  0.040000
# 2014                0.096566  0.078294  0.209843
# 2015                0.107346  0.096680  0.242678
# 2016                0.113018  0.127391  0.288671
# 2017                0.116776  0.118893  0.276230
# 2018                0.124614  0.110915  0.276965
# 2019                0.132101  0.100757  0.260052
# 2020                0.136865  0.103189  0.250649
# 2021                0.140337  0.102813  0.257803
# 2022                0.136445  0.099761  0.252800
# 2023                0.136782  0.112705  0.260252
# 2024                0.105719  0.087238  0.191846

# %% [markdown]
# One or more french

# %%
df_corresponding['any_french_or_missing'] = df_corresponding['countries'].apply(lambda lst: all(all(c == 'FR' for c in inner) or len(inner) == 0 for inner in lst))
df_corresponding_anyfrenchormissing = df_corresponding[df_corresponding['any_french_or_missing'] == True].reset_index(drop = True)
df_corresponding_anyfrenchormissing.to_parquet("../data/interim/preliminary/fr_p5_CA_yes_FR_plus_missing.parquet", index = False)

total_per_year = df.groupby('publication_year')['doi'].nunique()
total_anyfrenchormissing= df_corresponding_anyfrenchormissing.groupby('publication_year')['doi'].nunique()

grouped_total = total_anyfrenchormissing / total_per_year
grouped_oa = df_corresponding_anyfrenchormissing[df_corresponding_anyfrenchormissing.oa_status != 'closed'].groupby('publication_year')['doi'].nunique() / total_per_year
grouped_apc = df_corresponding_anyfrenchormissing[~df_corresponding_anyfrenchormissing.apc_list.isna()].groupby('publication_year')['doi'].nunique() / total_per_year

grouped = pd.concat([grouped_oa.rename('openaccess'), grouped_apc.rename('apc_list'), grouped_total.rename('total')], axis = 1)
grouped
# Out:
#                   openaccess  apc_list     total
# publication_year
# 2013                0.030000  0.040000  0.040000
# 2014                0.089927  0.082958  0.207437
# 2015                0.098269  0.106207  0.243192
# 2016                0.103630  0.143885  0.294992
# 2017                0.109403  0.133756  0.282481
# 2018                0.115958  0.126184  0.283090
# 2019                0.126984  0.113892  0.263278
# 2020                0.131538  0.117421  0.254212
# 2021                0.135378  0.115832  0.262844
# 2022                0.129939  0.110781  0.253287
# 2023                0.130754  0.127212  0.265743
# 2024                0.104356  0.098038  0.196580

# %%
df_corresponding['any_french'] = df_corresponding.countries.apply(lambda lst: any('FR' in x for x in lst))
df_corresponding_anyfrench = df_corresponding[df_corresponding['any_french'] == True].reset_index(drop = True)
df_corresponding_anyfrench.to_parquet("../data/interim/preliminary/fr_p5_CA_yes_FR_inclussive.parquet", index = False)

total_per_year = df.groupby('publication_year')['doi'].nunique()
total_anyfrench= df_corresponding_anyfrench.groupby('publication_year')['doi'].nunique()

grouped_total = total_anyfrench / total_per_year
grouped_oa = df_corresponding_anyfrench[df_corresponding_anyfrench.oa_status != 'closed'].groupby('publication_year')['doi'].nunique() / total_per_year
grouped_apc = df_corresponding_anyfrench[~df_corresponding_anyfrench.apc_list.isna()].groupby('publication_year')['doi'].nunique() / total_per_year

grouped = pd.concat([grouped_oa.rename('openaccess'), grouped_apc.rename('apc_list'), grouped_total.rename('total')], axis = 1)
grouped
# Out:
#                   openaccess  apc_list     total
# publication_year
# 2013                0.245000  0.270000  0.360000
# 2014                0.161179  0.163199  0.332991
# 2015                0.190741  0.212818  0.408153
# 2016                0.239036  0.318717  0.545984
# 2017                0.254532  0.310018  0.535802
# 2018                0.275691  0.312887  0.554585
# 2019                0.309568  0.304223  0.539771
# 2020                0.333157  0.319469  0.541167
# 2021                0.340179  0.320501  0.550540
# 2022                0.336804  0.320800  0.537651
# 2023                0.332026  0.339985  0.553616
# 2024                0.277126  0.276026  0.439177

# %% [markdown]
# **No corresponding**

# %%
df_nocorresponding
# Out:
#                                                  doi  publication_year  \
# 0        https://doi.org/10.1051/0004-6361/201322068              2013
# 1                https://doi.org/10.1038/nature12477              2013
# 2       https://doi.org/10.1097/ccm.0b013e31827e83af              2013
# 3              https://doi.org/10.1038/nnano.2013.46              2013
# 4                https://doi.org/10.1093/nar/gkt1178              2013
# ...                                              ...               ...
# 614558             https://doi.org/10.7202/1120388ar              2024
# 614559             https://doi.org/10.7202/1120383ar              2024
# 614560             https://doi.org/10.7202/1120375ar              2024
# 614561             https://doi.org/10.7202/1120374ar              2024
# 614562     https://doi.org/10.1017/s0021875825000179              2024
#
#        language                                        field_names  \
# 0            en          {Physics and Astronomy, Computer Science}
# 1            en  {Medicine, Biochemistry, Genetics and Molecula...
# 2            en                                         {Medicine}
# 3            en                                {Materials Science}
# 4            en  {Biochemistry, Genetics and Molecular Biology,...
# ...         ...                                                ...
# 614558       fr                                                 {}
# 614559       fr                                                 {}
# 614560       fr                                                 {}
# 614561       fr                                                 {}
# 614562       en                                                 {}
#
#                             journal                      publisher  \
# 0        Astronomy and Astrophysics                   EDP Sciences
# 1                            Nature               Nature Portfolio
# 2            Critical Care Medicine  Lippincott Williams & Wilkins
# 3             Nature Nanotechnology               Nature Portfolio
# 4            Nucleic Acids Research        Oxford University Press
# ...                             ...                            ...
# 614558         Études/Inuit/Studies                     Q114618608
# 614559         Études/Inuit/Studies                     Q114618608
# 614560         Études/Inuit/Studies                     Q114618608
# 614561         Études/Inuit/Studies                     Q114618608
# 614562  Journal of American Studies     Cambridge University Press
#
#                                                  ins_type  #_authors  \
# 0            {education, nonprofit, facility, government}         44
# 1       {healthcare, nonprofit, other, education, gove...         70
# 2                        {education, healthcare, company}         23
# 3                                              {facility}          2
# 4                                            {government}          5
# ...                                                   ...        ...
# 614558                              {education, facility}          2
# 614559                              {education, facility}          3
# 614560                              {education, facility}          3
# 614561                              {education, facility}          3
# 614562                                        {education}          6
#
#        oa_status                                           apc_list  \
# 0         bronze                                               None
# 1         bronze  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 2         closed                                               None
# 3          green  {'value': 9750, 'currency': 'EUR', 'value_usd'...
# 4           gold  {'value': 3630, 'currency': 'USD', 'value_usd'...
# ...          ...                                                ...
# 614558   diamond                                               None
# 614559   diamond                                               None
# 614560   diamond                                               None
# 614561   diamond                                               None
# 614562    closed                                               None
#
#                                             corresponding  \
# 0       [False, False, False, False, False, False, Fal...
# 1       [False, False, False, False, False, False, Fal...
# 2       [False, False, False, False, False, False, Fal...
# 3                                          [False, False]
# 4                     [False, False, False, False, False]
# ...                                                   ...
# 614558                                     [False, False]
# 614559                              [False, False, False]
# 614560                              [False, False, False]
# 614561                              [False, False, False]
# 614562         [False, False, False, False, False, False]
#
#                                                 countries  missing  \
# 0       [[DE], [US], [FR, US], [FR, US], [FR, US], [US...    False
# 1       [[GB], [GB], [GB], [CA], [GB], [GB], [GB], [GB...    False
# 2       [[US], [US], [GB], [FR], [DE], [US], [US], [IL...    False
# 3                                              [[], [FR]]    False
# 4                          [[FR], [FR], [FR], [FR], [FR]]    False
# ...                                                   ...      ...
# 614558                                         [[], [FR]]    False
# 614559                               [[], [CA, FR], [CA]]    False
# 614560                               [[], [CA, FR], [CA]]    False
# 614561                               [[], [CA, FR], [CA]]    False
# 614562                 [[GB], [], [FR], [FR], [FR], [FR]]    False
#
#         whole_french
# 0              False
# 1              False
# 2              False
# 3              False
# 4               True
# ...              ...
# 614558         False
# 614559         False
# 614560         False
# 614561         False
# 614562         False
#
# [614563 rows x 14 columns]

# %% [markdown]
# All french

# %%
df_nocorresponding['whole_french'] = df_nocorresponding.countries.apply(lambda lst: all('FR' in x for x in lst))
df_nocorresponding_wholefrench = df_nocorresponding[df_nocorresponding['whole_french'] == True].reset_index(drop = True)
df_nocorresponding_wholefrench.to_parquet("../data/interim/preliminary/fr_p5_CA_no_allFR.parquet", index = False)

total_per_year = df.groupby('publication_year')['doi'].nunique()
total_wholefrench= df_nocorresponding_wholefrench.groupby('publication_year')['doi'].nunique()

grouped_total = total_wholefrench / total_per_year
grouped_oa = df_nocorresponding_wholefrench[df_nocorresponding_wholefrench.oa_status != 'closed'].groupby('publication_year')['doi'].nunique() / total_per_year
grouped_apc = df_nocorresponding_wholefrench[~df_nocorresponding_wholefrench.apc_list.isna()].groupby('publication_year')['doi'].nunique() / total_per_year

grouped = pd.concat([grouped_oa.rename('openaccess'), grouped_apc.rename('apc_list'), grouped_total.rename('total')], axis = 1)
grouped
# Out:
#                   openaccess  apc_list     total
# publication_year
# 2013                0.040000  0.060000  0.085000
# 2014                0.092149  0.139308  0.262134
# 2015                0.094585  0.109459  0.219920
# 2016                0.086689  0.069553  0.167503
# 2017                0.093607  0.074448  0.165930
# 2018                0.095873  0.071975  0.157639
# 2019                0.108978  0.077669  0.159365
# 2020                0.115698  0.081461  0.158667
# 2021                0.114215  0.081691  0.155659
# 2022                0.113679  0.082072  0.159870
# 2023                0.101922  0.071253  0.145963
# 2024                0.113996  0.093254  0.175535

# %% [markdown]
# One or more french

# %%
df_nocorresponding['any_french_or_missing'] = df_nocorresponding['countries'].apply(lambda lst: all(all(c == 'FR' for c in inner) or len(inner) == 0 for inner in lst))
df_nocorresponding_anyfrenchormissing = df_nocorresponding[df_nocorresponding['any_french_or_missing'] == True].reset_index(drop = True)
df_nocorresponding_anyfrenchormissing.to_parquet("../data/interim/preliminary/fr_p5_CA_no_FR_plus_missing.parquet", index = False)

total_per_year = df.groupby('publication_year')['doi'].nunique()
total_anyfrenchormissing= df_nocorresponding_anyfrenchormissing.groupby('publication_year')['doi'].nunique()

grouped_total = total_anyfrenchormissing / total_per_year
grouped_oa = df_nocorresponding_anyfrenchormissing[df_nocorresponding_anyfrenchormissing.oa_status != 'closed'].groupby('publication_year')['doi'].nunique() / total_per_year
grouped_apc = df_nocorresponding_anyfrenchormissing[~df_nocorresponding_anyfrenchormissing.apc_list.isna()].groupby('publication_year')['doi'].nunique() / total_per_year

grouped = pd.concat([grouped_oa.rename('openaccess'), grouped_apc.rename('apc_list'), grouped_total.rename('total')], axis = 1)
grouped
# Out:
#                   openaccess  apc_list     total
# publication_year
# 2013                0.040000  0.065000  0.080000
# 2014                0.104912  0.164090  0.312827
# 2015                0.107153  0.129231  0.259353
# 2016                0.102783  0.089837  0.206564
# 2017                0.110847  0.095428  0.206230
# 2018                0.114981  0.090568  0.196946
# 2019                0.129428  0.097733  0.198393
# 2020                0.136147  0.100789  0.196458
# 2021                0.134652  0.100131  0.192680
# 2022                0.134411  0.103796  0.201351
# 2023                0.119270  0.087735  0.179853
# 2024                0.139108  0.119143  0.222087

# %%
df_nocorresponding['any_french'] = df_nocorresponding.countries.apply(lambda lst: any('FR' in x for x in lst))
df_nocorresponding_anyfrench = df_nocorresponding[df_nocorresponding['any_french'] == True].reset_index(drop = True)
df_nocorresponding_anyfrench.to_parquet("../data/interim/preliminary/fr_p5_CA_no_FR_inclussive.parquet", index = False)

total_per_year = df.groupby('publication_year')['doi'].nunique()
total_anyfrench= df_nocorresponding_anyfrench.groupby('publication_year')['doi'].nunique()

grouped_total = total_anyfrench / total_per_year
grouped_oa = df_nocorresponding_anyfrench[df_nocorresponding_anyfrench.oa_status != 'closed'].groupby('publication_year')['doi'].nunique() / total_per_year
grouped_apc = df_nocorresponding_anyfrench[~df_nocorresponding_anyfrench.apc_list.isna()].groupby('publication_year')['doi'].nunique() / total_per_year

grouped = pd.concat([grouped_oa.rename('openaccess'), grouped_apc.rename('apc_list'), grouped_total.rename('total')], axis = 1)
grouped
# Out:
#                   openaccess  apc_list     total
# publication_year
# 2013                0.440000  0.335000  0.640000
# 2014                0.286604  0.354008  0.667009
# 2015                0.289451  0.303186  0.591847
# 2016                0.253167  0.199119  0.454016
# 2017                0.275718  0.211083  0.464198
# 2018                0.280351  0.204965  0.445415
# 2019                0.315011  0.227547  0.460229
# 2020                0.329768  0.233646  0.458833
# 2021                0.323793  0.234016  0.449460
# 2022                0.324844  0.237223  0.462349
# 2023                0.316583  0.220932  0.446384
# 2024                0.369391  0.307881  0.560823
